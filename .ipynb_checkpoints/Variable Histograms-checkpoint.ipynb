# %%
import numpy as np
import matplotlib.pyplot as plt 
import h5py

# %%
be = h5py.File('variablestt_be1.h5','r')
bmu = h5py.File('variablestt_bmu1.h5','r')

print(be.keys())
print( '')
print(bmu.keys())
# Out:
# <KeysViewHDF5 ['j1_eta', 'j1_isbtag', 'j1_m', 'j1_phi', 'j1_pt', 'j2_eta', 'j2_isbtag', 'j2_m', 'j2_phi', 'j2_pt', 'j3_eta', 'j3_isbtag', 'j3_m', 'j3_phi', 'j3_pt', 'j4_eta', 'j4_isbtag', 'j4_m', 'j4_phi', 'j4_pt', 'j5_eta', 'j5_isbtag', 'j5_m', 'j5_phi', 'j5_pt', 'j6_eta', 'j6_isbtag', 'j6_m', 'j6_phi', 'j6_pt', 'j7_eta', 'j7_isbtag', 'j7_m', 'j7_phi', 'j7_pt', 'j8_eta', 'j8_isbtag', 'j8_m', 'j8_phi', 'j8_pt', 'lep_eta', 'lep_m', 'lep_phi', 'lep_pt', 'met_met', 'met_phi', 'mttReco', 'mttTrue']>
#
# ...

# %%
# for key in be.keys():
    
#     plt.figure(figsize=(12,8))
    
#     plt.subplot(121)
#     hist, bin_edges = np.histogram(np.array(be.get(key)))
#     plt.bar(bin_edges[:-1], hist, width = 0.5)
#     plt.xlim(min(bin_edges), max(bin_edges))
#     plt.grid(axis='y', alpha=0.75)
#     plt.xlabel('Value',fontsize=15)
#     plt.ylabel('Frequency',fontsize=15)
#     plt.xticks(fontsize=15)
#     plt.yticks(fontsize=15)
#     plt.title(key,fontsize=15)
    
#     plt.subplot(122)
#     hist, bin_edges = np.histogram(np.array(bmu.get(key)))
#     plt.bar(bin_edges[:-1], hist, width = 0.5)
#     plt.xlim(min(bin_edges), max(bin_edges))
#     plt.grid(axis='y', alpha=0.75)
#     plt.xlabel('Value',fontsize=15)
#     plt.ylabel('Frequency',fontsize=15)
#     plt.xticks(fontsize=15)
#     plt.yticks(fontsize=15)
#     plt.title(key,fontsize=15)

# %%
key = 'lep_pt'
plt.figure(figsize=(12,8))


hist, bin_edges = np.histogram(np.array(be.get(key)), 20)
plt.bar(bin_edges[:-1], hist, width = 45, fill=False, ec='r', label='Electron')
hist, bin_edges = np.histogram(np.array(bmu.get(key)), bin_edges)
plt.bar(bin_edges[:-1], hist, width = 45, fill=False, ec='b',label='Muon')
plt.xlim(min(bin_edges)-30, max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Lepton pT',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend()
plt.title('Lepton pT',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Lepton pT')

# %%
colors = ['r', 'b', 'g', 'c', 'm', 'y', 'k', 'pink', 'orange']

Hist, Edges = [], []

plt.figure(figsize=(16,12))
for i in range(1,9):
    key = "j{0}_m".format(i)
    hist, bin_edges = np.histogram((np.array(be.get(key))), 20)
    plt.bar(bin_edges[:-1], hist, fill=False, ec=colors[i-1], label=key)
    Hist.append(hist)
    Edges.append(bin_edges)


plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend()
plt.title(key,fontsize=15)
# Out:
#   File "<ipython-input-54-cd5475cd2036>", line 13
#     Edges[0][i+1-i] for i in range(len(Edges)-1)
#                       ^
# SyntaxError: invalid syntax

# %%
key = 'mttTrue'
plt.figure(figsize=(12,8))

plt.subplot(121)
hist, bin_edges = np.histogram(np.array(be.get(key)))
print(hist)
plt.bar(bin_edges[:-1], hist, width = 80)
plt.xlim(min(bin_edges)-100, max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title(key,fontsize=15)

plt.subplot(122)
hist, bin_edges = np.histogram(np.array(bmu.get(key)))
plt.bar(bin_edges[:-1], hist, width = 80)
plt.xlim(min(bin_edges)-100, max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title(key,fontsize=15)
# Out:
# [ 2395 40660 54942 11897  2389   524   119    34     6     5]
# Text(0.5, 1.0, 'mttTrue')

# %%
key = 'mttReco'
plt.figure(figsize=(12,8))

plt.subplot(121)
hist, bin_edges = np.histogram(np.array(be.get(key)))
print(hist)
plt.bar(bin_edges[:-1], hist, width = 80)
plt.xlim(min(bin_edges)-100, max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title(key,fontsize=15)

plt.subplot(122)
hist, bin_edges = np.histogram(np.array(bmu.get(key)))
plt.bar(bin_edges[:-1], hist, width = 80)
plt.xlim(min(bin_edges)-100, max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title(key,fontsize=15)
# Out:
# [34644 65200 10865  1818   340    81    11     9     2     1]
# Text(0.5, 1.0, 'mttReco')

# %%
key = 'met_met'
plt.figure(figsize=(12,8))

plt.subplot(121)
hist, bin_edges = np.histogram(np.array(be.get(key)))
print(hist)
plt.bar(bin_edges[:-1], hist, width = 80)
plt.xlim(min(bin_edges)-100, max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title(key,fontsize=15)

plt.subplot(122)
hist, bin_edges = np.histogram(np.array(bmu.get(key)))
plt.bar(bin_edges[:-1], hist, width = 80)
plt.xlim(min(bin_edges)-100, max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title(key,fontsize=15)
# Out:
# [63821 37185  9795  1664   381    77    23    14     8     3]
# Text(0.5, 1.0, 'met_met')

# %%
key = 'j8_phi'
plt.figure(figsize=(12,8))

plt.subplot(121)
hist, bin_edges = np.histogram(np.array(be.get(key)))
print(hist)
plt.bar(bin_edges[:-1], hist, width = 0.3)
plt.xlim(min(bin_edges), max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.yscale('log')
plt.title(key,fontsize=15)

plt.subplot(122)
hist, bin_edges = np.histogram(np.array(bmu.get(key)))
plt.bar(bin_edges[:-1], hist, width = 0.3)
plt.xlim(min(bin_edges), max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.yscale('log')
plt.title(key,fontsize=15)
# Out:
# [   782    737    781    744    743 106102    817    772    747    746]
# Text(0.5, 1.0, 'j8_phi')
