# %%
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import os 
import h5py
import sys
# %matplotlib inline

# %%
model_name = "3Layers_Scaling_Faster_morenodes.h5py"

# %%
# Throw away lepton mass 
# os.chdir('./../../../../../data/hongtao')
be = h5py.File('./../../../../../data/hongtao/variables_tt_re.h5','r')
bmu = h5py.File('./../../../../../data/hongtao/variables_tt_rmu.h5','r')
be1 = h5py.File('./../../../../../data/hongtao/variables_tt_re1.h5','r')
print(be.keys())
print('')
print(be1.keys())
dataset = be1
# Out:
# <KeysViewHDF5 ['j1_eta', 'j1_isbtag', 'j1_m', 'j1_phi', 'j1_pt', 'j2_eta', 'j2_isbtag', 'j2_m', 'j2_phi', 'j2_pt', 'j3_eta', 'j3_isbtag', 'j3_m', 'j3_phi', 'j3_pt', 'j4_eta', 'j4_isbtag', 'j4_m', 'j4_phi', 'j4_pt', 'j5_eta', 'j5_isbtag', 'j5_m', 'j5_phi', 'j5_pt', 'j6_eta', 'j6_isbtag', 'j6_m', 'j6_phi', 'j6_pt', 'j7_eta', 'j7_isbtag', 'j7_m', 'j7_phi', 'j7_pt', 'j8_eta', 'j8_isbtag', 'j8_m', 'j8_phi', 'j8_pt', 'lep_eta', 'lep_m', 'lep_phi', 'lep_pt', 'met_met', 'met_phi', 'mttReco', 'mttTrue']>
#
# <KeysViewHDF5 ['bh_eta', 'bh_phi', 'bh_pt', 'bl_eta', 'bl_phi', 'bl_pt', 'j1_DL1r', 'j1_eta', 'j1_isbtag', 'j1_m', 'j1_phi', 'j1_pt', 'j2_DL1r', 'j2_eta', 'j2_isbtag', 'j2_m', 'j2_phi', 'j2_pt', 'j3_DL1r', 'j3_eta', 'j3_isbtag', 'j3_m', 'j3_phi', 'j3_pt', 'j4_DL1r', 'j4_eta', 'j4_isbtag', 'j4_m', 'j4_phi', 'j4_pt', 'j5_DL1r', 'j5_eta', 'j5_isbtag', 'j5_m', 'j5_phi', 'j5_pt', 'j6_DL1r', 'j6_eta', 'j6_isbtag', 'j6_m', 'j6_phi', 'j6_pt', 'j7_DL1r', 'j7_eta', 'j7_isbtag', 'j7_m', 'j7_phi', 'j7_pt', 'j8_DL1r', 'j8_eta', 'j8_isbtag', 'j8_m', 'j8_phi', 'j8_pt', 'lep_eta', 'lep_m', 'lep_phi', 'lep_pt', 'met_met', 'met_phi', 'mttReco', 'mttTrue', 'th_eta', 'th_phi', 'th_pt', 'tl_eta', 'tl_phi', 'tl_pt', 'wh_eta', 'wh_phi', 'wh_pt', 'wl_eta', 'wl_phi', 'wl_pt']>

# %%
input_keys = ['j1_pt', 'j1_eta', 'j1_phi', 'j1_m', 'j1_DL1r', 'j2_pt', 'j2_eta', 'j2_phi', 'j2_m', 'j2_DL1r', 'j3_pt', 'j3_eta', 'j3_phi', 'j3_m', 'j3_DL1r', 'j4_pt', 'j4_eta', 'j4_phi', 'j4_m', 'j4_DL1r', 'j5_pt', 'j5_eta', 'j5_phi', 'j5_m', 'j5_DL1r', 'j6_pt', 'j6_eta', 'j6_phi', 'j6_m', 'j6_DL1r', 'j7_pt', 'j7_eta', 'j7_phi','j7_m', 'j7_DL1r', 'j8_pt', 'j8_eta', 'j8_phi','j8_m', 'j8_DL1r', 'lep_pt', 'lep_eta', 'lep_phi', 'met_met', 'met_phi'] 
output_keys = ['th_pt', 'th_eta','th_phi', 'tl_pt', 'tl_eta', 'tl_phi']
# output_keys = ['th_eta','th_phi', 'tl_eta', 'tl_phi']

output_length = len(output_keys)
input_length = len(input_keys)

# %%
# plt.figure(figsize=(8,8*input_length))
# for i in range(0, input_length):
#     plt.subplot(input_length, 1, i+1)
#     histo, bin_edges = np.histogram(dataset.get(input_keys[i]))
#     plt.hist(dataset.get(input_keys[i]), bin_edges, histtype='step')
#     plt.xlabel(input_keys[i])
#     plt.ylabel('Frequency')

# %%
i = 'met_phi' 
var = dataset.get(i)
v2 = var-np.mean(var)
v3 = v2/np.max(v2)
plt.hist(v3, histtype='step')
# Out:
# (array([432341., 439423., 444292., 445645., 442098., 437930., 432495.,
#         429988., 428128., 428529.]),
#  array([-0.98962464, -0.79066217, -0.59169971, -0.39273724, -0.19377478,
#          0.00518768,  0.20415015,  0.40311261,  0.60207507,  0.80103754,
#          1.        ]),
#  <a list of 1 Patch objects>)

# %%
# Convert into numpy arrays and mean normalize
crop =  100000

input_arrays = []
output_arrays = [] 
in_max = []
in_mean = []
out_max = []
out_mean = []

# for key in input_keys:
#     exec(key + ' = np.array(dataset.get(key))[0:crop].reshape((1,-1))')
#     exec('{0} = ({0} - np.mean({0}))/np.std({0})'.format(key))
#     exec('input_arrays.append({0})'.format(key))

    
def convert_normalize(keys, maxim, mean, total):
    for x in keys:
        var = np.array(dataset.get(x))[0:crop]
        mu = np.mean(var)
        var = (var - mu)
        maxi = np.max(np.abs(var))
        var = var/maxi
        total.append(var)
        maxim.append(maxi)
        mean.append(mu)

    
convert_normalize(input_keys, in_max, in_mean, input_arrays)
convert_normalize(output_keys, out_max, out_mean, output_arrays)

out_max = np.array(out_max).reshape((1,-1))
out_mean = np.array(out_mean).reshape((1,-1))
in_max = np.array(in_max).reshape((1,-1))
in_mean = np.array(in_mean).reshape((1,-1))

# %%
# Create input and test array
split = int(np.floor(0.8*crop)) # 80/20 split 
shuffle = False

total_input = np.stack(input_arrays,axis=0).T
total_output = np.stack(output_arrays,axis=0).T
if shuffle:
    rng_state = np.random.get_state()
    np.random.shuffle(total_input)
    np.random.set_state(rng_state)
    np.random.shuffle(total_output)
    
# size = total_input.shape
# total_input = np.array(np.random.normal(size=total_input.shape))

train_input, test_input = total_input[0:split, :], total_input[split:,:]
train_output, test_output = total_output[0:split,:], total_output[split:,:]

# %%
print(train_input.shape, train_output.shape)
print(test_input.shape, test_output.shape)
# Out:
# (80000, 45) (80000, 6)
# (20000, 45) (20000, 6)

# %%
# Histograms 
show = False 

if show:
    plt.figure(figsize=(8,8*input_length))
    for i in range(0, input_length):
        plt.subplot(input_length, 1, i+1)
        plt.hist(train_input[:,i], histtype='step')
        plt.xlabel(input_keys[i])
        plt.ylabel('Frequency')

# %%
# Build model

# optimizer = keras.optimizers.RMSprop(learning_rate = 1e-5)
optimizer = keras.optimizers.Adam(learning_rate=1e-6)
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)


def build_model():
    model = keras.Sequential([
        layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0001),
                     input_shape=[len(input_keys)]),
        layers.Dense(256,  activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
        layers.Dense(256,  activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
        layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
        layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
        layers.Dense(len(output_keys),  activation='linear')
    ])
    
    model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    return model 

# def build_model():
#     model = keras.Sequential([
#         layers.Dense(6, activation='linear', 
#                      input_shape=[len(input_keys)])])
    
#     model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    
#     return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               23552
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 270,854
# Trainable params: 270,854
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model

Epochs= 4096

history = model.fit(train_input, train_output, verbose=1, epochs=Epochs, 
                   validation_split=0.2, shuffle=True, callbacks=[callback],
                   batch_size=512)
# Out:
# Epoch 1/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2351 - mse: 0.1374 - val_loss: 0.2341 - val_mse: 0.1364
# Epoch 2/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2333 - mse: 0.1357 - val_loss: 0.2325 - val_mse: 0.1349
# Epoch 3/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2318 - mse: 0.1343 - val_loss: 0.2311 - val_mse: 0.1336
# Epoch 4/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2305 - mse: 0.1330 - val_loss: 0.2299 - val_mse: 0.1325
# Epoch 5/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2293 - mse: 0.1319 - val_loss: 0.2287 - val_mse: 0.1315
# Epoch 6/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2281 - mse: 0.1309 - val_loss: 0.2276 - val_mse: 0.1305
# Epoch 7/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2270 - mse: 0.1299 - val_loss: 0.2265 - val_mse: 0.1295
# Epoch 8/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2259 - mse: 0.1289 - val_loss: 0.2254 - val_mse: 0.1285
# Epoch 9/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2247 - mse: 0.1278 - val_loss: 0.2243 - val_mse: 0.1274
# Epoch 10/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2235 - mse: 0.1268 - val_loss: 0.2231 - val_mse: 0.1264
# Epoch 11/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2223 - mse: 0.1256 - val_loss: 0.2218 - val_mse: 0.1252
# Epoch 12/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2209 - mse: 0.1244 - val_loss: 0.2205 - val_mse: 0.1240
# Epoch 13/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2196 - mse: 0.1232 - val_loss: 0.2191 - val_mse: 0.1228
# Epoch 14/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2182 - mse: 0.1219 - val_loss: 0.2178 - val_mse: 0.1215
# Epoch 15/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2167 - mse: 0.1205 - val_loss: 0.2163 - val_mse: 0.1202
# Epoch 16/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2153 - mse: 0.1191 - val_loss: 0.2149 - val_mse: 0.1188
# Epoch 17/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2138 - mse: 0.1177 - val_loss: 0.2134 - val_mse: 0.1175
# Epoch 18/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2123 - mse: 0.1163 - val_loss: 0.2120 - val_mse: 0.1161
# Epoch 19/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2108 - mse: 0.1150 - val_loss: 0.2105 - val_mse: 0.1148
# Epoch 20/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2093 - mse: 0.1136 - val_loss: 0.2091 - val_mse: 0.1134
# Epoch 21/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2079 - mse: 0.1122 - val_loss: 0.2077 - val_mse: 0.1121
# Epoch 22/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2064 - mse: 0.1109 - val_loss: 0.2064 - val_mse: 0.1109
# Epoch 23/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2051 - mse: 0.1096 - val_loss: 0.2051 - val_mse: 0.1097
# Epoch 24/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2038 - mse: 0.1084 - val_loss: 0.2039 - val_mse: 0.1086
# Epoch 25/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2025 - mse: 0.1073 - val_loss: 0.2027 - val_mse: 0.1075
# Epoch 26/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2013 - mse: 0.1062 - val_loss: 0.2016 - val_mse: 0.1065
# Epoch 27/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2002 - mse: 0.1052 - val_loss: 0.2006 - val_mse: 0.1056
# Epoch 28/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1992 - mse: 0.1043 - val_loss: 0.1997 - val_mse: 0.1048
# Epoch 29/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.
4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1642 - mse: 0.0857 - val_loss: 0.1669 - val_mse: 0.0884
# Epoch 202/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1641 - mse: 0.0856 - val_loss: 0.1668 - val_mse: 0.0884
# Epoch 203/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1640 - mse: 0.0856 - val_loss: 0.1667 - val_mse: 0.0883
# Epoch 204/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1639 - mse: 0.0856 - val_loss: 0.1665 - val_mse: 0.0883
# Epoch 205/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1637 - mse: 0.0855 - val_loss: 0.1664 - val_mse: 0.0883
# Epoch 206/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1636 - mse: 0.0855 - val_loss: 0.1663 - val_mse: 0.0882
# Epoch 207/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1635 - mse: 0.0855 - val_loss: 0.1662 - val_mse: 0.0882
# Epoch 208/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1634 - mse: 0.0854 - val_loss: 0.1661 - val_mse: 0.0882
# Epoch 209/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1633 - mse: 0.0854 - val_loss: 0.1660 - val_mse: 0.0882
# Epoch 210/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1632 - mse: 0.0854 - val_loss: 0.1659 - val_mse: 0.0881
# Epoch 211/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1631 - mse: 0.0853 - val_loss: 0.1658 - val_mse: 0.0881
# Epoch 212/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1630 - mse: 0.0853 - val_loss: 0.1657 - val_mse: 0.0881
# Epoch 213/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1629 - mse: 0.0853 - val_loss: 0.1656 - val_mse: 0.0881
# Epoch 214/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1628 - mse: 0.0853 - val_loss: 0.1655 - val_mse: 0.0880
# Epoch 215/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1627 - mse: 0.0852 - val_loss: 0.1654 - val_mse: 0.0880
# Epoch 216/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1626 - mse: 0.0852 - val_loss: 0.1653 - val_mse: 0.0880
# Epoch 217/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1625 - mse: 0.0852 - val_loss: 0.1652 - val_mse: 0.0880
# Epoch 218/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1623 - mse: 0.0851 - val_loss: 0.1651 - val_mse: 0.0879
# Epoch 219/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1622 - mse: 0.0851 - val_loss: 0.1650 - val_mse: 0.0879
# Epoch 220/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1621 - mse: 0.0851 - val_loss: 0.1649 - val_mse: 0.0879
# Epoch 221/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1620 - mse: 0.0850 - val_loss: 0.1648 - val_mse: 0.0879
# Epoch 222/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1619 - mse: 0.0850 - val_loss: 0.1647 - val_mse: 0.0878
# Epoch 223/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1618 - mse: 0.0850 - val_loss: 0.1646 - val_mse: 0.0878
# Epoch 224/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1617 - mse: 0.0850 - val_loss: 0.1645 - val_mse: 0.0878
# Epoch 225/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1616 - mse: 0.0849 - val_loss: 0.1644 - val_mse: 0.0877
# Epoch 226/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1615 - mse: 0.0849 - val_loss: 0.1643 - val_mse: 0.0877
# Epoch 227/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1614 - mse: 0.0849 - val_loss: 0.1642 - val_mse: 0.0877
# Epoch 228/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1613 - mse: 0.0848 - val_loss: 0.1641 - val_mse: 0.0877
# Epoch 229/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1612 - mse: 0.0848 - val_loss: 0.1640 - val_mse: 0.0876
# Epoch 230/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1611 - mse: 0.0848 - val_loss: 0.1639 - val_mse: 0.0876
# Epoch 231/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1610 - mse: 0.0847 - val_loss: 0.1638 - val_mse: 0.0876
# Epoch 232/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1609 - mse: 0.0847 - val_loss: 0.1637 - val_mse: 0.0876
# Epoch 233/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1608 - mse: 0.0847 - val_loss: 0.1636 - val_mse: 0.0875
# Epoch 234/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1607 - mse: 0.0847 - val_loss: 0.1635 - val_mse: 0.0875
# Epoch 235/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1606 - mse: 0.0846 - val_loss: 0.1634 - val_mse: 0.0875
# Epoch 236/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1605 - mse: 0.0846 - val_loss: 0.1633 - val_mse: 0.0875
# Epoch 237/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1604 - mse: 0.0846 - val_loss: 0.1632 - val_mse: 0.0875
# Epoch 238/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1603 - mse: 0.0845 - val_loss: 0.1631 - val_mse: 0.0874
# Epoch 239/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1602 - mse: 0.0845 - val_loss: 0.1630 - val_mse: 0.0874
# Epoch 240/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1601 - mse: 0.0845 - val_loss: 0.1629 - val_mse: 0.0874
# Epoch 241/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1600 - mse: 0.0845 - val_loss: 0.1629 - val_mse: 0.0874
# Epoch 242/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1599 - mse: 0.0844 - val_loss: 0.1628 - val_mse: 0.0873
# Epoch 243/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1598 - mse: 0.0844 - val_loss: 0.1627 - val_mse: 0.0873
# Epoch 244/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1597 - mse: 0.0844 - val_loss: 0.1626 - val_mse: 0.0873
# Epoch 245/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1596 - mse: 0.0844 - val_loss: 0.1625 - val_mse: 0.0873
# Epoch 246/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1595 - mse: 0.0843 - val_loss: 0.1624 - val_mse: 0.0872
# Epoch 247/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1594 - mse: 0.0843 - val_loss: 0.1623 - val_mse: 0.0872
# Epoch 248/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1593 - mse: 0.0843 - val_loss: 0.1622 - val_mse: 0.0872
# Epoch 249/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1592 - mse: 0.0842 - val_loss: 0.1621 - val_mse: 0.0872
# Epoch 250/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1591 - mse: 0.0842 - val_loss: 0.1620 - val_mse: 0.0872
# Epoch 251/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1590 - mse: 0.0842 - val_loss: 0.1619 - val_mse: 0.0871
# Epoch 252/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1589 - mse: 0.0842 - val_loss: 0.1618 - val_mse: 0.0871
# Epoch 253/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1588 - mse: 0.0841 - val_loss: 0.1617 - val_mse: 0.0871
# Epoch 254/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1587 - mse: 0.0841 - val_loss: 0.1616 - val_mse: 0.0871
# Epoch 255/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1586 - mse: 0.0841 - val_loss: 0.1616 - val_mse: 0.0870
# Epoch 256/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1585 - mse: 0.0841 - val_loss: 0.1615 - val_mse: 0.0870
# Epoch 257/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1584 - mse: 0.0840 - val_loss: 0.1614 - val_mse: 0.0870
# Epoch 258/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1584 - mse: 0.0840 - val_loss: 0.1613 - val_mse: 0.0870
# Epoch 259/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1583 - mse: 0.0840 - val_loss: 0.1612 - val_mse: 0.0869
# Epoch 260/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1582 - mse: 0.0840 - val_loss: 0.1611 - val_mse: 0.0869
# Epoch 261/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1581 - mse: 0.0839 - val_loss: 0.1610 - val_mse: 0.0869
# Epoch 262/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1580 - mse: 0.0839 - val_loss: 0.1609 - val_mse: 0.0869
# Epoch 263/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1579 - mse: 0.0839 - val_loss: 0.1608 - val_mse: 0.0869
# Epoch 264/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1578 - mse: 0.0838 - val_loss: 0.1607 - val_mse: 0.0868
# Epoch 265/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1577 - mse: 0.0838 - val_loss: 0.1607 - val_mse: 0.0868
# Epoch 266/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1576 - mse: 0.0838 - val_loss: 0.1606 - val_mse: 0.0868
# Epoch 267/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1575 - mse: 0.0838 - val_loss: 0.1605 - val_mse: 0.0868
# Epoch 268/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1574 - mse: 0.0837 - val_loss: 0.1604 - val_mse: 0.0868
# Epoch 269/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.
4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1514 - mse: 0.0820 - val_loss: 0.1546 - val_mse: 0.0853
# Epoch 339/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1513 - mse: 0.0820 - val_loss: 0.1546 - val_mse: 0.0853
# Epoch 340/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1512 - mse: 0.0819 - val_loss: 0.1545 - val_mse: 0.0852
# Epoch 341/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1511 - mse: 0.0819 - val_loss: 0.1544 - val_mse: 0.0852
# Epoch 342/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1510 - mse: 0.0819 - val_loss: 0.1543 - val_mse: 0.0852
# Epoch 343/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1510 - mse: 0.0819 - val_loss: 0.1543 - val_mse: 0.0852
# Epoch 344/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1509 - mse: 0.0818 - val_loss: 0.1542 - val_mse: 0.0852
# Epoch 345/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1508 - mse: 0.0818 - val_loss: 0.1541 - val_mse: 0.0851
# Epoch 346/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1507 - mse: 0.0818 - val_loss: 0.1540 - val_mse: 0.0851
# Epoch 347/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1506 - mse: 0.0818 - val_loss: 0.1540 - val_mse: 0.0851
# Epoch 348/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1506 - mse: 0.0817 - val_loss: 0.1539 - val_mse: 0.0851
# Epoch 349/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1505 - mse: 0.0817 - val_loss: 0.1538 - val_mse: 0.0851
# Epoch 350/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1504 - mse: 0.0817 - val_loss: 0.1537 - val_mse: 0.0850
# Epoch 351/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1503 - mse: 0.0817 - val_loss: 0.1537 - val_mse: 0.0850
# Epoch 352/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1503 - mse: 0.0816 - val_loss: 0.1536 - val_mse: 0.0850
# Epoch 353/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1502 - mse: 0.0816 - val_loss: 0.1535 - val_mse: 0.0850
# Epoch 354/4096
# ...
# Epoch 3066/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0946 - mse: 0.0583 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3067/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0946 - mse: 0.0583 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3068/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0946 - mse: 0.0583 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3069/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0946 - mse: 0.0583 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3070/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0946 - mse: 0.0583 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3071/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0946 - mse: 0.0583 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3072/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0583 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3073/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0583 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3074/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0583 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3075/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0583 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3076/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0583 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3077/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0582 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3078/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0582 - val_loss: 0.1137 - val_mse: 0.0774
# Epoch 3079/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3080/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3081/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3082/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3083/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0945 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3084/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3085/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3086/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3087/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3088/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3089/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3090/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3091/4096
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3092/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3093/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0944 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3094/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0582 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3095/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3096/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3097/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3098/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3099/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3100/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3101/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3102/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3103/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3104/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3105/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0943 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3106/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3107/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3108/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3109/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3110/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3111/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3112/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0581 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3113/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3114/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3115/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3116/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0942 - mse: 0.0580 - val_loss: 0.1135 - val_mse: 0.0774
# Epoch 3117/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3118/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3119/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0774
# Epoch 3120/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1135 - val_mse: 0.0774
# Epoch 3121/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3122/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3123/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1135 - val_mse: 0.0774
# Epoch 3124/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3125/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3126/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3127/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0941 - mse: 0.0580 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3128/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3129/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0580 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3130/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0580 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3131/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0580 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3132/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0579 - val_loss: 0.1136 - val_mse: 0.0775
# Epoch 3133/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3134/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3135/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3136/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3137/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3138/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3139/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3140/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3141/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3142/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3143/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1136 - val_mse: 0.0776
# Epoch 3144/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3145/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3146/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3147/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3148/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0579 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3149/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0939 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3150/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3151/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3152/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3153/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3154/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3155/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3156/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3157/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3158/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3159/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3160/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3161/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0938 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3162/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3163/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3164/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3165/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3166/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0578 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3167/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3168/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0776
# Epoch 3169/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3170/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3171/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3172/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0937 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0776
# Epoch 3173/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0776
# Epoch 3174/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0776
# Epoch 3175/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3176/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3177/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3178/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3179/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775
# Epoch 3180/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0776
# Epoch 3181/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0577 - val_loss: 0.1135 - val_mse: 0.0775

# %%
history.history.keys()
model.save(model_name)
# Out:
# WARNING:tensorflow:From /home/hongtao/miniconda3/envs/top-ml/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: 3Layers_Scaling_Faster_morenodes.h5py/assets

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('mse loss')
plt.legend()
plt.title('MSE loss')
# Out:
# Text(0.5, 1.0, 'MSE loss')

# %%
predictions = model.predict(test_input)

# %%
# Training 
crop = 100 

train_small = model.predict(train_input[0:100,:])
output_small = train_output[0:100,:]

def comparison_plot(compare, true):
    plt.figure(figsize=(8,8*output_length))
    for i in range(0,output_length):
        plt.subplot(output_length,1,i+1)
        plt.plot(range(0,crop), compare[:,i], 'bo', markersize=3, label = 'Predictions')
        plt.plot(range(0,crop), true[:,i], 'ro', markersize=3, label = 'True Value')
        ym, yM = plt.ylim()
        for x in range(100):
            plt.vlines(x, color='g', linestyle='-', alpha=0.2, ymin= 
                        min(compare[x,i], true[x,i]), 
                        ymax= max(compare[x,i], true[x,i]))
        plt.hlines(np.mean(true[:,i]), xmin=-20, xmax=crop+20, alpha=0.5)
        MSE = 1/compare[:,i].size*np.sum((compare[:,i]- true[:,i])**2)
        plt.xlabel('Epoch')
        plt.ylabel(output_keys[i])
        plt.xlim(0, crop)
        plt.title(output_keys[i] + " MSE: " + str(MSE))
        plt.legend()

comparison_plot(train_small, output_small)

# %%
# Predictions

predictions_small = predictions[0:100,:]
test_output_small = test_output[0:100,:]

MSE = 1/predictions.size*np.sum((predictions- test_output)**2)
print("total MSE: " + str(MSE))

for i in range(output_length):
    MSE = 1/predictions[:,i].size*np.sum((predictions[:,i] -test_output[:,i])**2)
    print("{0} MSE : ".format(output_keys[i]), '%.10f'%MSE)
# Out:
# total MSE: 0.07448962994589571
# th_pt MSE :  0.0073310845
# th_eta MSE :  0.0127916619
# th_phi MSE :  0.2211058044
# tl_pt MSE :  0.0053194359
# tl_eta MSE :  0.0105143172
# tl_phi MSE :  0.1898754758

# %%
comparison_plot(predictions_small, test_output_small)

# %%
# # Histograms 

# def histograms_true(true):
#     plt.figure(figsize=(8,8*input_length))
#     for i in range(0, input_length):
#         plt.subplot(input_length,1,i+1)
#         histo, bin_edges = np.histogram(true[:,i],20)
#         plt.hist(true[:,i], bin_edges, histtype = 'step', color='r', label='True Value')
#         plt.xlabel(input_keys[i])
#         plt.ylabel('Frequency')
#         plt.title(input_keys[i])
#         plt.legend()

# histograms_true(test_input)

# %%
# Back to original units 

scaled_predictions = predictions*out_max + out_mean
scaled_output = test_output*out_max + out_mean

scaled_predictions_small = scaled_predictions[0:crop,:]
scaled_output_small = scaled_output[0:crop,:]

comparison_plot(scaled_predictions_small, scaled_output_small)

# %%
# Histograms 

def histograms(compare, true):
    plt.figure(figsize=(8,8*output_length))
    for i in range(0, output_length):
        plt.subplot(output_length,1,i+1)
        histo, bin_edges = np.histogram(compare[:,i],20)
        plt.hist(compare[:,i], bin_edges, histtype = 'step', color='b', label='Predictions')
        plt.hist(true[:,i], bin_edges, histtype = 'step', color='r', label='True Value')
        plt.xlabel(output_keys[i])
        plt.ylabel('Frequency')
        plt.title(output_keys[i])
        plt.legend()

histograms(scaled_predictions, scaled_output)

# %%
# Histograms 

def histograms_true(compare, true):
    plt.figure(figsize=(8,8*output_length))
    for i in range(0, output_length):
        plt.subplot(output_length,1,i+1)
        histo, bin_edges = np.histogram(true[:,i],20)
        plt.hist(compare[:,i], bin_edges, histtype = 'step', color='b', label='Predictions')
        plt.hist(true[:,i], bin_edges, histtype = 'step', color='r', label='True Value')
        plt.xlabel(output_keys[i])
        plt.ylabel('Frequency')
        plt.title(output_keys[i])
        plt.legend()

histograms_true(scaled_predictions, scaled_output)
