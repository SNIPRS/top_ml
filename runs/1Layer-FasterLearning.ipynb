# %%
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import os 
import h5py
import sys
# %matplotlib inline

# %%
model_name = "1LayerFasterLearning.h5py"

# %%
# os.chdir('./../../../../../data/hongtao')
be = h5py.File('./../../../../../data/hongtao/variables_tt_re.h5','r')
bmu = h5py.File('./../../../../../data/hongtao/variables_tt_rmu.h5','r')
be1 = h5py.File('./../../../../../data/hongtao/variables_tt_re1.h5','r')
print(be.keys())
print('')
print(be1.keys())
dataset = be1
# Out:
# <KeysViewHDF5 ['j1_eta', 'j1_isbtag', 'j1_m', 'j1_phi', 'j1_pt', 'j2_eta', 'j2_isbtag', 'j2_m', 'j2_phi', 'j2_pt', 'j3_eta', 'j3_isbtag', 'j3_m', 'j3_phi', 'j3_pt', 'j4_eta', 'j4_isbtag', 'j4_m', 'j4_phi', 'j4_pt', 'j5_eta', 'j5_isbtag', 'j5_m', 'j5_phi', 'j5_pt', 'j6_eta', 'j6_isbtag', 'j6_m', 'j6_phi', 'j6_pt', 'j7_eta', 'j7_isbtag', 'j7_m', 'j7_phi', 'j7_pt', 'j8_eta', 'j8_isbtag', 'j8_m', 'j8_phi', 'j8_pt', 'lep_eta', 'lep_m', 'lep_phi', 'lep_pt', 'met_met', 'met_phi', 'mttReco', 'mttTrue']>
#
# <KeysViewHDF5 ['bh_eta', 'bh_phi', 'bh_pt', 'bl_eta', 'bl_phi', 'bl_pt', 'j1_DL1r', 'j1_eta', 'j1_isbtag', 'j1_m', 'j1_phi', 'j1_pt', 'j2_DL1r', 'j2_eta', 'j2_isbtag', 'j2_m', 'j2_phi', 'j2_pt', 'j3_DL1r', 'j3_eta', 'j3_isbtag', 'j3_m', 'j3_phi', 'j3_pt', 'j4_DL1r', 'j4_eta', 'j4_isbtag', 'j4_m', 'j4_phi', 'j4_pt', 'j5_DL1r', 'j5_eta', 'j5_isbtag', 'j5_m', 'j5_phi', 'j5_pt', 'j6_DL1r', 'j6_eta', 'j6_isbtag', 'j6_m', 'j6_phi', 'j6_pt', 'j7_DL1r', 'j7_eta', 'j7_isbtag', 'j7_m', 'j7_phi', 'j7_pt', 'j8_DL1r', 'j8_eta', 'j8_isbtag', 'j8_m', 'j8_phi', 'j8_pt', 'lep_eta', 'lep_m', 'lep_phi', 'lep_pt', 'met_met', 'met_phi', 'mttReco', 'mttTrue', 'th_eta', 'th_phi', 'th_pt', 'tl_eta', 'tl_phi', 'tl_pt', 'wh_eta', 'wh_phi', 'wh_pt', 'wl_eta', 'wl_phi', 'wl_pt']>

# %%
input_keys = ['j1_pt', 'j1_eta', 'j1_phi', 'j1_m', 'j1_DL1r', 'j2_pt', 'j2_eta', 'j2_phi', 'j2_m', 'j2_DL1r', 'j3_pt', 'j3_eta', 'j3_phi', 'j3_m', 'j3_DL1r', 'j4_pt', 'j4_eta', 'j4_phi', 'j4_m', 'j4_DL1r', 'j5_pt', 'j5_eta', 'j5_phi', 'j5_m', 'j5_DL1r', 'j6_pt', 'j6_eta', 'j6_phi', 'j6_m', 'j6_DL1r', 'j7_pt', 'j7_eta', 'j7_phi','j7_m', 'j7_DL1r', 'j8_pt', 'j8_eta', 'j8_phi','j8_m', 'j8_DL1r', 'lep_pt', 'lep_eta', 'lep_phi', 'lep_m', 'met_met', 'met_phi'] 
output_keys = ['th_pt', 'th_eta','th_phi', 'tl_pt', 'tl_eta', 'tl_phi']
# output_keys = ['th_eta','th_phi', 'tl_eta', 'tl_phi']

output_length = len(output_keys)

# %%
# Original variables

plt.figure(figsize=(8,8*output_length))
for i in range(0, output_length):
    plt.subplot(output_length,1,i+1)
    plt.hist(dataset.get(output_keys[i]), 20, histtype = 'step', color='r')
    plt.xlabel(output_keys[i])
    plt.ylabel('Frequency')
    plt.title(output_keys[i])

# %%
# Convert into numpy arrays and mean normalize
crop =  100000

input_arrays = []
output_arrays = [] 
in_std = []
in_mean = []
out_std = []
out_mean = []

# for key in input_keys:
#     exec(key + ' = np.array(dataset.get(key))[0:crop].reshape((1,-1))')
#     exec('{0} = ({0} - np.mean({0}))/np.std({0})'.format(key))
#     exec('input_arrays.append({0})'.format(key))

    
def convert_normalize(keys, std, mean, total):
    for x in keys:
        var = np.array(dataset.get(x))[0:crop].reshape((1,-1))
        sig = np.std(var)
        mu = np.mean(var)
        std.append(sig)
        mean.append(mu)
        var = (var - mu)/sig 
        total.append(var)

    
convert_normalize(input_keys, in_std, in_mean, input_arrays)
convert_normalize(output_keys, out_std, out_mean, output_arrays)

out_std = np.array(out_std).reshape((1,-1))
out_mean = np.array(out_mean).reshape((1,-1))
in_std = np.array(in_std).reshape((1,-1))
in_mean = np.array(in_mean).reshape((1,-1))

# %%
# Create input and test array
split = int(np.floor(0.8*crop)) # 80/20 split 
shuffle = True
    
total_input = np.stack(input_arrays).reshape((crop, len(input_keys)))
total_output = np.stack(output_arrays).reshape((crop, len(output_keys)))

if shuffle:
    rng_state = np.random.get_state()
    np.random.shuffle(total_input)
    np.random.set_state(rng_state)
    np.random.shuffle(total_output)
    
# size = total_input.shape
# total_input = np.array(np.random.normal(size=total_input.shape))

train_input, test_input = total_input[0:split, :], total_input[split:, :]
train_output, test_output = total_output[0:split,:], total_output[split:,:]

# %%
print(train_input.shape, train_output.shape)
print(test_input.shape, test_output.shape)
# Out:
# (80000, 46) (80000, 6)
# (20000, 46) (20000, 6)

# %%
# Build model

# optimizer = keras.optimizers.RMSprop(learning_rate = 1e-5)
optimizer = keras.optimizers.Adam(learning_rate=1e-4)
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)


def build_model():
    model = keras.Sequential([
        layers.Dense(64,  input_shape=[len(input_keys)], activation='relu'),
        layers.Dense(len(output_keys), activation='linear')
    ])
    
    model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    return model 

# def build_model():
#     model = keras.Sequential([
#         layers.Dense(6, activation='linear', 
#                      input_shape=[len(input_keys)])])
    
#     model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    
#     return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                3008
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 3,398
# Trainable params: 3,398
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model

Epochs= 4096

history = model.fit(train_input, train_output, verbose=1, epochs=Epochs, 
                   validation_split=0.2, shuffle=True, callbacks=[callback],
                   batch_size=512)
# Out:
# Epoch 1/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.5406 - mse: 1.5406 - val_loss: 1.4218 - val_mse: 1.4218
# Epoch 2/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.3444 - mse: 1.3444 - val_loss: 1.2866 - val_mse: 1.2866
# Epoch 3/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.2401 - mse: 1.2401 - val_loss: 1.2081 - val_mse: 1.2081
# Epoch 4/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.1766 - mse: 1.1766 - val_loss: 1.1588 - val_mse: 1.1588
# Epoch 5/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.1359 - mse: 1.1359 - val_loss: 1.1269 - val_mse: 1.1269
# Epoch 6/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.1091 - mse: 1.1091 - val_loss: 1.1056 - val_mse: 1.1056
# Epoch 7/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0909 - mse: 1.0909 - val_loss: 1.0911 - val_mse: 1.0911
# Epoch 8/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0782 - mse: 1.0782 - val_loss: 1.0808 - val_mse: 1.0808
# Epoch 9/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0689 - mse: 1.0689 - val_loss: 1.0731 - val_mse: 1.0731
# Epoch 10/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0617 - mse: 1.0617 - val_loss: 1.0672 - val_mse: 1.0672
# Epoch 11/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0560 - mse: 1.0560 - val_loss: 1.0624 - val_mse: 1.0624
# Epoch 12/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0512 - mse: 1.0512 - val_loss: 1.0584 - val_mse: 1.0584
# Epoch 13/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0472 - mse: 1.0472 - val_loss: 1.0549 - val_mse: 1.0549
# Epoch 14/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 1.0518 - val_mse: 1.0518
# Epoch 15/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0403 - mse: 1.0403 - val_loss: 1.0491 - val_mse: 1.0491
# Epoch 16/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0374 - mse: 1.0374 - val_loss: 1.0465 - val_mse: 1.0465
# Epoch 17/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0347 - mse: 1.0347 - val_loss: 1.0442 - val_mse: 1.0442
# Epoch 18/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0322 - mse: 1.0322 - val_loss: 1.0421 - val_mse: 1.0421
# Epoch 19/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0299 - mse: 1.0299 - val_loss: 1.0401 - val_mse: 1.0401
# Epoch 20/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0278 - mse: 1.0278 - val_loss: 1.0382 - val_mse: 1.0382
# Epoch 21/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0258 - mse: 1.0258 - val_loss: 1.0366 - val_mse: 1.0366
# Epoch 22/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0239 - mse: 1.0239 - val_loss: 1.0350 - val_mse: 1.0350
# Epoch 23/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0222 - mse: 1.0222 - val_loss: 1.0335 - val_mse: 1.0335
# Epoch 24/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0206 - mse: 1.0206 - val_loss: 1.0322 - val_mse: 1.0322
# Epoch 25/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0191 - mse: 1.0191 - val_loss: 1.0308 - val_mse: 1.0308
# Epoch 26/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0177 - mse: 1.0177 - val_loss: 1.0297 - val_mse: 1.0297
# Epoch 27/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0164 - mse: 1.0164 - val_loss: 1.0285 - val_mse: 1.0285
# Epoch 28/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0151 - mse: 1.0151 - val_loss: 1.0275 - val_mse: 1.0275
# Epoch 29/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0140 - mse: 1.0140 - val_loss: 1.0265 - val_mse: 1.0265
# Epoch 30/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0129 - mse: 1.0129 - val_loss: 1.0256 - val_mse: 1.0256
# Epoch 31/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0119 - mse: 1.0119 - val_loss: 1.0247 - val_mse: 1.0247
# Epoch 32/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0110 - mse: 1.0110 - val_loss: 1.0239 - val_mse: 1.0239
# Epoch 33/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0101 - mse: 1.0101 - val_loss: 1.0231 - val_mse: 1.0231
# Epoch 34/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0092 - mse: 1.0092 - val_loss: 1.0224 - val_mse: 1.0224
# Epoch 35/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0085 - mse: 1.0085 - val_loss: 1.0217 - val_mse: 1.0217
# Epoch 36/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0077 - mse: 1.0077 - val_loss: 1.0210 - val_mse: 1.0210
# Epoch 37/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0070 - mse: 1.0070 - val_loss: 1.0205 - val_mse: 1.0205
# Epoch 38/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0064 - mse: 1.0064 - val_loss: 1.0199 - val_mse: 1.0199
# Epoch 39/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0057 - mse: 1.0057 - val_loss: 1.0194 - val_mse: 1.0194
# Epoch 40/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0051 - mse: 1.0051 - val_loss: 1.0189 - val_mse: 1.0189
# Epoch 41/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0046 - mse: 1.0046 - val_loss: 1.0184 - val_mse: 1.0184
# Epoch 42/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0041 - mse: 1.0041 - val_loss: 1.0180 - val_mse: 1.0180
# Epoch 43/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0036 - mse: 1.0036 - val_loss: 1.0176 - val_mse: 1.0176
# Epoch 44/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0031 - mse: 1.0031 - val_loss: 1.0172 - val_mse: 1.0172
# Epoch 45/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0027 - mse: 1.0027 - val_loss: 1.0169 - val_mse: 1.0169
# Epoch 46/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0023 - mse: 1.0023 - val_loss: 1.0165 - val_mse: 1.0165
# Epoch 47/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0019 - mse: 1.0019 - val_loss: 1.0162 - val_mse: 1.0162
# Epoch 48/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0015 - mse: 1.0015 - val_loss: 1.0159 - val_mse: 1.0159
# Epoch 49/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0012 - mse: 1.0012 - val_loss: 1.0156 - val_mse: 1.0156
# Epoch 50/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0008 - mse: 1.0008 - val_loss: 1.0153 - val_mse: 1.0153
# Epoch 51/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0005 - mse: 1.0005 - val_loss: 1.0151 - val_mse: 1.0151
# Epoch 52/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 1.0002 - mse: 1.0002 - val_loss: 1.0148 - val_mse: 1.0148
# Epoch 53/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9999 - mse: 0.9999 - val_loss: 1.0146 - val_mse: 1.0146
# Epoch 54/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9996 - mse: 0.9996 - val_loss: 1.0144 - val_mse: 1.0144
# Epoch 55/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9994 - mse: 0.9994 - val_loss: 1.0142 - val_mse: 1.0142
# Epoch 56/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9991 - mse: 0.9991 - val_loss: 1.0139 - val_mse: 1.0139
# Epoch 57/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9989 - mse: 0.9989 - val_loss: 1.0138 - val_mse: 1.0138
# Epoch 58/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9986 - mse: 0.9986 - val_loss: 1.0136 - val_mse: 1.0136
# Epoch 59/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9984 - mse: 0.9984 - val_loss: 1.0134 - val_mse: 1.0134
# Epoch 60/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9982 - mse: 0.9982 - val_loss: 1.0133 - val_mse: 1.0133
# Epoch 61/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9980 - mse: 0.9980 - val_loss: 1.0132 - val_mse: 1.0132
# Epoch 62/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9978 - mse: 0.9978 - val_loss: 1.0130 - val_mse: 1.0130
# Epoch 63/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9976 - mse: 0.9976 - val_loss: 1.0128 - val_mse: 1.0128
# Epoch 64/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9974 - mse: 0.9974 - val_loss: 1.0128 - val_mse: 1.0128
# Epoch 65/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9973 - mse: 0.9973 - val_loss: 1.0126 - val_mse: 1.0126
# Epoch 66/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9971 - mse: 0.9971 - val_loss: 1.0126 - val_mse: 1.0126
# Epoch 67/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9969 - mse: 0.9969 - val_loss: 1.0124 - val_mse: 1.0124
# Epoch 68/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9968 - mse: 0.9968 - val_loss: 1.0123 - val_mse: 1.0123
# Epoch 69/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9967 - mse: 0.9967 - val_loss: 1.0122 - val_mse: 1.0122
# Epoch 70/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9965 - mse: 0.9965 - val_loss: 1.0121 - val_mse: 1.0121
# Epoch 71/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9964 - mse: 0.9964 - val_loss: 1.0121 - val_mse: 1.0121
# Epoch 72/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9963 - mse: 0.9963 - val_loss: 1.0120 - val_mse: 1.0120
# Epoch 73/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9961 - mse: 0.9961 - val_loss: 1.0119 - val_mse: 1.0119
# Epoch 74/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9960 - mse: 0.9960 - val_loss: 1.0118 - val_mse: 1.0118
# Epoch 75/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9959 - mse: 0.9959 - val_loss: 1.0117 - val_mse: 1.0117
# Epoch 76/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9958 - mse: 0.9958 - val_loss: 1.0117 - val_mse: 1.0117
# Epoch 77/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9956 - mse: 0.9956 - val_loss: 1.0116 - val_mse: 1.0116
# Epoch 78/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9955 - mse: 0.9955 - val_loss: 1.0115 - val_mse: 1.0115
# Epoch 79/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9954 - mse: 0.9954 - val_loss: 1.0115 - val_mse: 1.0115
# Epoch 80/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9953 - mse: 0.9953 - val_loss: 1.0114 - val_mse: 1.0114
# Epoch 81/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9952 - mse: 0.9952 - val_loss: 1.0114 - val_mse: 1.0114
# Epoch 82/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9951 - mse: 0.9951 - val_loss: 1.0113 - val_mse: 1.0113
# Epoch 83/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9950 - mse: 0.9950 - val_loss: 1.0112 - val_mse: 1.0112
# Epoch 84/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9949 - mse: 0.9949 - val_loss: 1.0112 - val_mse: 1.0112
# Epoch 85/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9949 - mse: 0.9949 - val_loss: 1.0112 - val_mse: 1.0112
# Epoch 86/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9948 - mse: 0.9948 - val_loss: 1.0111 - val_mse: 1.0111
# Epoch 87/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9947 - mse: 0.9947 - val_loss: 1.0111 - val_mse: 1.0111
# Epoch 88/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9946 - mse: 0.9946 - val_loss: 1.0110 - val_mse: 1.0110
# Epoch 89/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9945 - mse: 0.9945 - val_loss: 1.0109 - val_mse: 1.0109
# Epoch 90/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9945 - mse: 0.9945 - val_loss: 1.0109 - val_mse: 1.0109
# Epoch 91/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9944 - mse: 0.9944 - val_loss: 1.0109 - val_mse: 1.0109
# Epoch 92/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9943 - mse: 0.9943 - val_loss: 1.0108 - val_mse: 1.0108
# Epoch 93/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9942 - mse: 0.9942 - val_loss: 1.0108 - val_mse: 1.0108
# Epoch 94/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9942 - mse: 0.9942 - val_loss: 1.0108 - val_mse: 1.0108
# Epoch 95/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9941 - mse: 0.9941 - val_loss: 1.0108 - val_mse: 1.0108
# Epoch 96/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9940 - mse: 0.9940 - val_loss: 1.0108 - val_mse: 1.0108
# Epoch 97/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9940 - mse: 0.9940 - val_loss: 1.0107 - val_mse: 1.0107
# Epoch 98/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9939 - mse: 0.9939 - val_loss: 1.0107 - val_mse: 1.0107
# Epoch 99/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9938 - mse: 0.9938 - val_loss: 1.0107 - val_mse: 1.0107
# Epoch 100/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9938 - mse: 0.9938 - val_loss: 1.0107 - val_mse: 1.0107
# Epoch 101/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9937 - mse: 0.9937 - val_loss: 1.0107 - val_mse: 1.0107
# Epoch 102/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9937 - mse: 0.9937 - val_loss: 1.0106 - val_mse: 1.0106
# Epoch 103/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9936 - mse: 0.9936 - val_loss: 1.0106 - val_mse: 1.0106
# Epoch 104/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9936 - mse: 0.9936 - val_loss: 1.0106 - val_mse: 1.0106
# Epoch 105/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9935 - mse: 0.9935 - val_loss: 1.0106 - val_mse: 1.0106
# Epoch 106/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9935 - mse: 0.9935 - val_loss: 1.0106 - val_mse: 1.0106
# Epoch 107/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9934 - mse: 0.9934 - val_loss: 1.0106 - val_mse: 1.0106
# Epoch 108/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9933 - mse: 0.9933 - val_loss: 1.0106 - val_mse: 1.0106
# Epoch 109/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9933 - mse: 0.9933 - val_loss: 1.0105 - val_mse: 1.0105
# Epoch 110/4096
# 125/125 [==============================] - 0s 4ms/step - loss: 0.9933 - mse: 0.9933 - val_loss: 1.0105 - val_mse: 1.0105
# Epoch 111/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9932 - mse: 0.9932 - val_loss: 1.0105 - val_mse: 1.0105
# Epoch 112/4096
# 125/125 [==============================] - 0s 3ms/step - loss: 0.9932 - mse: 0.9932 - val_loss: 1.0105 - val_mse: 1.0105

# %%
history.history.keys()
model.save(model_name)
# Out:
# WARNING:tensorflow:From /home/hongtao/miniconda3/envs/top-ml/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: 1LayerFasterLearning.h5py/assets

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('mse loss')
plt.legend()
plt.title('MSE loss')
# Out:
# Text(0.5, 1.0, 'MSE loss')

# %%
predictions = model.predict(test_input)

# %%
# Training 
crop = 100 

train_small = model.predict(train_input[0:100,:])
output_small = train_output[0:100,:]

def comparison_plot(compare, true):
    plt.figure(figsize=(8,8*output_length))
    for i in range(0,output_length):
        plt.subplot(output_length,1,i+1)
        plt.plot(range(0,crop), compare[:,i], 'bo', markersize=3, label = 'Predictions')
        plt.plot(range(0,crop), true[:,i], 'ro', markersize=3, label = 'True Value')
        ym, yM = plt.ylim()
        for x in range(100):
            plt.vlines(x, color='g', linestyle='-', alpha=0.2, ymin= 
                        min(compare[x,i], true[x,i]), 
                        ymax= max(compare[x,i], true[x,i]))
        plt.hlines(np.mean(true[:,i]), xmin=-20, xmax=crop+20, alpha=0.5)
        MSE = 1/compare[:,i].size*np.sum((compare[:,i]- true[:,i])**2)
        plt.xlabel('Epoch')
        plt.ylabel(output_keys[i])
        plt.xlim(0, crop)
        plt.title(output_keys[i] + " MSE: " + str(MSE))
        plt.legend()

comparison_plot(train_small, output_small)

# %%
# Predictions

predictions_small = predictions[0:crop,:]
test_output_small = test_output[0:crop,:]

MSE = 1/predictions.size*np.sum((predictions- test_output)**2)
print("total MSE: " + str(MSE))

for i in range(output_length):
    MSE = 1/predictions[:,i].size*np.sum((predictions[:,i] -test_output[:,i])**2)
    print("{0} MSE : ".format(output_keys[i]), '%.10f'%MSE)
# Out:
# total MSE: 1.0059365944416543
# th_pt MSE :  1.0060578797
# th_eta MSE :  1.0145506797
# th_phi MSE :  0.9930537456
# tl_pt MSE :  1.0018269440
# tl_eta MSE :  1.0129883960
# tl_phi MSE :  1.0071419216

# %%
comparison_plot(predictions_small, test_output_small)

# %%
# Back to original units 

scaled_predictions = predictions*out_std + out_mean
scaled_output = test_output*out_std + out_mean

comparison_plot(scaled_predictions[0:crop,:], scaled_output[0:crop,:])

# %%
# Histograms 

def histograms(compare, true):
    plt.figure(figsize=(8,8*output_length))
    for i in range(0, output_length):
        plt.subplot(output_length,1,i+1)
        histo, bin_edges = np.histogram(compare[:,i],20)
        plt.hist(compare[:,i], bin_edges, histtype = 'step', color='b', label='Predictions')
        plt.hist(true[:,i], bin_edges, histtype = 'step', color='r', label='True Value')
        plt.xlabel(output_keys[i])
        plt.ylabel('Frequency')
        plt.title(output_keys[i])
        plt.legend()

histograms(scaled_predictions, scaled_output)
