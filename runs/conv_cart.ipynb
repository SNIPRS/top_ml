# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import concatenate
from tensorflow.keras import regularizers 
from tensorflow.keras import initializers
import h5py
from utilities import Utilities 
import os 
os.environ["CUDA_VISIBLE_DEVICES"]="1"


# %matplotlib inline 

dataset = h5py.File('./../../../../../data/hongtao/variables_tt_re2.h5','r')

X_keys = ['j1_pt', 'j1_eta', 'j1_phi', 'j1_m', 'j1_DL1r', 'j2_pt', 'j2_eta', 'j2_phi', 'j2_m', 'j2_DL1r', 'j3_pt', 'j3_eta', 'j3_phi', 'j3_m', 'j3_DL1r', 'j4_pt', 'j4_eta', 'j4_phi', 'j4_m', 'j4_DL1r', 'j5_pt', 'j5_eta', 'j5_phi', 'j5_m', 'j5_DL1r', 'j6_pt', 'j6_eta', 'j6_phi', 'j6_m', 'j6_DL1r', 'lep_pt', 'lep_eta', 'lep_phi', 'met_met', 'met_phi']
Y_keys = ['th_pt', 'th_eta','th_phi', 'tl_pt', 'tl_eta', 'tl_phi', 'wl_pt', 'wl_eta', 'wl_phi']
phi_keys = ['j1_phi', 'j2_phi', 'j3_phi','j4_phi','j5_phi','j6_phi', 'lep_phi', 'met_phi', 'th_phi', 'tl_phi', 'wl_phi']
eta_keys = ['j1_eta', 'j2_eta', 'j3_eta', 'j4_eta', 'j5_eta', 'j5_phi', 'j6_eta', 'lep_eta', 'th_eta', 'tl_eta', 'wl_eta']
pt_keys = ['j1_pt', 'j2_pt','j3_pt','j4_pt','j5_pt','j6_pt','lep_pt','th_pt', 'tl_pt', 'wl_pt']
m_keys = ['j1_m','j2_m', 'j3_m', 'j4_m', 'j5_m', 'j6_m', 'wl_m']
DL1r_keys = ['j1_DL1r','j2_DL1r','j3_DL1r','j4_DL1r','j5_DL1r','j6_DL1r']


Y_length = len(Y_keys)
X_length = len(X_keys)
crop0 =  100000

# %%
import scale_variables

# How to scale each input/output
def get_methods(keys):
    types = {'pt':'cart', 'eta':'meanmax', 'phi':'sincos', 'DL1r':'meanmax', 'm':'boxcox', 'met':'meanmax'}
    var_types = [key.split('_')[1] for key in keys]
    methods = [types[var] for var in var_types]
    return methods

X_methods = get_methods(X_keys)
Y_methods = get_methods(Y_keys)

Scaler = scale_variables.Scale_variables()
(X_total, X_maxmean), X_names = Scaler.scale_arrays(X_keys, X_methods, True)
(Y_total, Y_maxmean), Y_names = Scaler.scale_arrays(Y_keys, Y_methods, True)

error = Scaler.test_inverse(Y_keys, Y_methods, True)
print('Max scaling error: {}'.format(error))
# Out:
# Max scaling error: 1.7053025658242404e-13

# %%
# Create X and test array
split = int(np.floor(0.8*crop0)) # 80/20 split 
shuffle = False

if shuffle:
    rng_state = np.random.get_state()
    np.random.shuffle(X_total)
    np.random.set_state(rng_state)
    np.random.shuffle(Y_total)

trainX, testX = X_total[0:split, :], X_total[split:,:]
trainY, testY = Y_total[0:split,:], Y_total[split:,:]

timestep_builder = scale_variables.Shape_timesteps()
trainX_jets, trainX_other = timestep_builder.reshape_X(trainX, X_names, False)
testX_jets, testX_other = timestep_builder.reshape_X(testX, X_names, False)

# Save some memory 
del trainX
del testX 

print(trainX_jets.shape, trainX_other.shape, trainY.shape)
print(testX_jets.shape, testX_other.shape, testY.shape)
# Out:
# (80000, 6, 5) (80000, 6) (80000, 9)
# (20000, 6, 5) (20000, 6) (20000, 9)

# %%
# Histograms of total  Y variables 
show = True

other_bins = np.linspace(-1, 1, 40)
phi_bins = np.linspace(-0.1, 0.1, 40)
pt_bins = np.linspace(-0.3, 1, 40)
Y_bins = [phi_bins if 'phi' in name else pt_bins if 'pt' in name else other_bins for name in Y_names]

if show:
    plt.figure(figsize=(6,6*trainY.shape[1]))
    for i in range(0, trainY.shape[1]):
        plt.subplot(trainY.shape[1], 1, i+1)
        bins = Y_bins[i]
        plt.hist(Y_total[:,i], bins, histtype='step')
        plt.xlabel(Y_names[i])
        plt.ylabel('Frequency')

# %%
# Histograms of X variables 
show = False

if show:
    plt.figure(figsize=(6,6*X_total.shape[1]))
    for i in range(0, X_total.shape[1]):
        plt.subplot(X_total.shape[1], 1, i+1)
        plt.hist(X_total[:,i], 20, histtype='step')
        plt.xlabel(X_names[i])
        plt.ylabel('Frequency')

# %%
# Build model

def build_model():
    jet_input = Input(shape=(trainX_jets.shape[1], trainX_jets.shape[2]))
    Conv11 = Conv1D(filters=64, kernel_size=2, activation='relu', kernel_initializer=initializers.he_uniform())(jet_input)
    Conv12 = Conv1D(filters=64, kernel_size=1, activation='relu', kernel_initializer=initializers.he_uniform())(Conv11)
    flat_jets = Flatten()(Conv11)
    
    other_input = Input(shape=(trainX_other.shape[1]))
    Dense21 = Dense(64, activation='relu')(other_input)
    Dense22 = Dense(32, activation='relu')(Dense21)
    flat_other = Flatten()(Dense21)
    
    concat = concatenate([flat_other, flat_jets])
    dense1 = Dense(128, activation='relu')(concat)
    dense2 = Dense(64, activation='relu')(dense1)
    dense3 = Dense(32, activation='relu')(dense2)
    output = Dense(len(Y_names), activation='linear')(dense3)
    
    model = keras.models.Model(inputs=[jet_input, other_input], outputs=output)
    optimizer = keras.optimizers.Adam(learning_rate=5e-6)
    model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    
    return model 

model = build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 6, 5)]       0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           448         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6, 64)        384         input_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 384)          0           conv1d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 448)          0           flatten_1[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          57472       concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           8256        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           2080        dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 9)            297         dense_4[0][0]
# ==================================================================================================
# Total params: 68,937
# Trainable params: 68,937
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model

callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

Epochs= 2048

del X_total
del Y_total

history = model.fit([trainX_jets, trainX_other], trainY, verbose=1, epochs=Epochs, 
                   validation_split=0.2, shuffle=False, callbacks=[callback],
                   batch_size=512)
# Out:
# Train on 64000 samples, validate on 16000 samples
# Epoch 1/2048
# 64000/64000 [==============================] - 4s 65us/sample - loss: 0.0288 - mse: 0.0288 - val_loss: 0.0252 - val_mse: 0.0252
# Epoch 2/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0239 - mse: 0.0239 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 3/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0216 - mse: 0.0216 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 4/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 5/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 6/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 7/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 8/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 9/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 10/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 11/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 12/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 13/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 14/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 15/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 16/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 17/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 18/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 19/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 20/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 21/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 22/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 23/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 24/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 25/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 26/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 27/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 28/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 29/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 30/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 31/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 32/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 33/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 34/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 35/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 36/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 37/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 38/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 39/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 40/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 41/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 42/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 43/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 44/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 45/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 46/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 47/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 48/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 49/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 50/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 51/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 52/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 53/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 54/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 55/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 56/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 57/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 58/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 59/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 60/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 61/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 62/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 63/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 64/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 65/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 66/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 67/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 68/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 69/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 70/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 71/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 72/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 73/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 74/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 75/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 76/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 77/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 78/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 79/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 80/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 81/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 82/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 83/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 84/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 85/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 86/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 87/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 88/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 89/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 90/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 91/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 92/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 93/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 94/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 95/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 96/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 97/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 98/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 99/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 100/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 101/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 102/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 103/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 104/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 105/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 106/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 107/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 108/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 109/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 110/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 111/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 112/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 113/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 114/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 115/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 116/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 117/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 118/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 119/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 120/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 121/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 122/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 123/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 124/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 125/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 126/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 127/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 128/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 129/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 130/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 131/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 132/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 133/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 134/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 135/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 136/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 137/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 138/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 139/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 140/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 141/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 142/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 143/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 144/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 145/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 146/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 147/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 148/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 149/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 150/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 151/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 152/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 153/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 154/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 155/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 156/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 157/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 158/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 159/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 160/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 161/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 162/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 163/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 164/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 165/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 166/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 167/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 168/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 169/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 170/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 171/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 172/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 173/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 174/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 175/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 176/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 177/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 178/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 179/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 180/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 181/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 182/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 183/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 184/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 185/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 186/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 187/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 188/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 189/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 190/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 191/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 192/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 193/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 194/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 195/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 196/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 197/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 198/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 199/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 200/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 201/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 202/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 203/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 204/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 205/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 206/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 207/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 208/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 209/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 210/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 211/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 212/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 213/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 214/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 215/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 216/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 217/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 218/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 219/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 220/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 221/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 222/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 223/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 224/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 225/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 226/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 227/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 228/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 229/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 230/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 231/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 232/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 233/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 234/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 235/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 236/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 237/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 238/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 239/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 240/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 241/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 242/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 243/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 244/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 245/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 246/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 247/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 248/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 249/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 250/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 251/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 252/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 253/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 254/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 255/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 256/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 257/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 258/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 259/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 260/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 261/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 262/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 263/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 264/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 265/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 266/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 267/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 268/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 269/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 270/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 271/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 272/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 273/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 274/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 275/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 276/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 277/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 278/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 279/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 280/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 281/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 282/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 283/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 284/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 285/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 286/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 287/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 288/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 289/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 290/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 291/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 292/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 293/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 294/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 295/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 296/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 297/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 298/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 299/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 300/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 301/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 302/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 303/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 304/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 305/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 306/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 307/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 308/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 309/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 310/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 311/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 312/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 313/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 314/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 315/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 316/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 317/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 318/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 319/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 320/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 321/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 322/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 323/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 324/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 325/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 326/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 327/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 328/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 329/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 330/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 331/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 332/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 333/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 334/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 335/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 336/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# ...
# Epoch 1938/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1939/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1940/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1941/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1942/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1943/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1944/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1945/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1946/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1947/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1948/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1949/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1950/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1951/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1952/2048
# 64000/64000 [==============================] - 1s 11us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1953/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1954/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1955/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1956/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1957/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1958/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1959/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1960/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1961/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1962/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1963/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1964/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1965/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1966/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1967/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1968/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1969/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1970/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1971/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1972/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1973/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1974/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1975/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1976/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1977/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1978/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1979/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1980/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1981/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1982/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1983/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1984/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1985/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1986/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1987/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1988/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1989/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1990/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1991/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1992/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1993/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1994/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1995/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1996/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1997/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1998/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 1999/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2000/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2001/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2002/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2003/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2004/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2005/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2006/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2007/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2008/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2009/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2010/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2011/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2012/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2013/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2014/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2015/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2016/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2017/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2018/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2019/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2020/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2021/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2022/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2023/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2024/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2025/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2026/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2027/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2028/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2029/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2030/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2031/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2032/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2033/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2034/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2035/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2036/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2037/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2038/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2039/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2040/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2041/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2042/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2043/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2044/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2045/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2046/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2047/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 2048/2048
# 64000/64000 [==============================] - 1s 10us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('mse loss')
plt.legend()
plt.title('MSE loss')
# Out:
# Text(0.5, 1.0, 'MSE loss')

# %%
class Analysis:
    def __init__(self):
        self.crop = 100
        self.fsize = 6
        self.histogram_bins = 40
        
    def wrap_phi(self, var):
        var = var%(2*np.pi)
        var = var - 2*np.pi*(var > np.pi)
        return var
        
    def predictions_vs_sample(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2, self.fsize*len(names)))
        for i in range(0, len(names)):
            compare_small = compare[:self.crop,i]
            true_small = true[:self.crop,i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            plt.subplot(len(names), 1, i+1)
            plt.plot(range(0,self.crop), compare_small, 'bo', markersize=3, label = 'Predictions')
            plt.plot(range(0,self.crop), true_small, 'ro', markersize=3, label = 'True Value')
            ym, yM = plt.ylim()
            for x in range(self.crop):
                plt.vlines(x, color='g', linestyle='-', alpha=0.2, ymin= 
                            min(compare_small[x], true_small[x]), 
                            ymax= max(compare_small[x], true_small[x]))
            plt.hlines(np.mean(true[:,i]), xmin=-20, xmax=self.crop+20, alpha=0.5)
            MSE = 1/compare[:,i].size*np.sum((compare[:,i]- true[:,i])**2)
            plt.xlabel('Sample')
            plt.xlim(0, self.crop)
            plt.ylabel(names[i])
            plt.title(names[i] + " MSE: " + str(MSE))
            plt.legend()
    
    def display_errors(self, compare, true, names, wrap_phi):
        MSE = 1/compare.size*np.sum((compare- true)**2)
        print("total MSE: " + str(MSE))
        print(" ")
        for i in range(len(names)):
            diff = compare[:,i] -true[:,i]
            if wrap_phi and "phi" in names[i]:
                diff = self.wrap_phi(diff)
            MSE = 1/compare[:,i].size*np.sum((diff)**2)
            print("{0} MSE : ".format(names[i]), '%.10f'%MSE)
    
    def difference_histogram(self, compare, true, names, wrap_phi, bins):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            diff = true[:,i] - compare[:,i]
            hist0, bin_edges = np.histogram(true[:, i], bins=40)
            if bins[i] is None:
                hbins = bin_edges
            else:
                hbins = bins[i]
            plt.hist(diff, hbins, histtype='step', color='purple', label='true - predicted', density=True)
            plt.xlabel("Difference (Mean: {0}, Std: {1})".format(np.mean(diff), np.std(diff)))
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
            
    def variable_histogram(self, compare, true, names, wrap_phi, bins): 
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            compare_small = compare[:, i]
            true_small = true[:, i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            hist0, bin_edges = np.histogram(true[:, i], bins=40)
            
            if bins[i] is None:
                hbins = bin_edges
            else:
                hbins = bins[i]
                
            plt.hist(true_small, hbins, histtype='step', color='b', label='true values', density=False)
            plt.hist(compare_small, hbins, histtype='step', color='r', label='predictions', density=False)
            plt.xlabel(names[i])
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
    
    def difference_vs_variable(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], true[:, i]-compare[:, i], 'o', color='purple', label='True - Predicted', markersize=2)
            plt.xlabel('True ' + names[i])
            plt.legend()
            plt.ylabel('Difference')
    
    def predicted_vs_true(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], compare[:, i], 'o', color='g', markersize=2)
            line = np.linspace(np.min(true[:, i]), np.max(true[:, i]), 100)
            plt.plot(line, line, color='b')
            plt.xlabel('True')
            plt.title(names[i])
            plt.ylabel('Predicted')

# %%
display = Analysis()

predictions_unscaled = model.predict([testX_jets, testX_other])
true_unscaled = testY 

total_predictions = model.predict([np.append(trainX_jets,testX_jets,axis=0), np.append(trainX_other,testX_other,axis=0)])
(Y_total, TO_maxmean0), _ = Scaler.scale_arrays(Y_keys, Y_methods, True)

predictions_origscale = Scaler.invscale_arrays(Y_keys, total_predictions, _, Y_methods, TO_maxmean0)[split:,:]
true_origscale = Scaler.invscale_arrays(Y_keys, Y_total, _, Y_methods, TO_maxmean0)[split:,:]

del Y_total
del TO_maxmean0
del _
del total_predictions

# %% [markdown]
# # Training scale plots

# %%
display.display_errors(predictions_unscaled, true_unscaled, Y_names, False)
# Out:
# total MSE: 0.005255889063900631
#
# th_px MSE :  0.0063446300
# th_py MSE :  0.0089371161
# th_pz MSE :  0.0019382766
# tl_px MSE :  0.0048573404
# tl_py MSE :  0.0113900412
# tl_pz MSE :  0.0028297862
# wl_px MSE :  0.0017948189
# wl_py MSE :  0.0074440631
# wl_pz MSE :  0.0017669289

# %%
display.predictions_vs_sample(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.variable_histogram(predictions_unscaled, true_unscaled, Y_names, False, Y_bins)

# %%
display.difference_histogram(predictions_unscaled, true_unscaled, Y_names, False, Y_bins)

# %%
display.predicted_vs_true(predictions_unscaled, true_unscaled, Y_names, False)

# %% [markdown]
#  # Original scale plots

# %%
display.display_errors(predictions_origscale, true_origscale, Y_keys, True)
# Out:
# total MSE: 623.9547887846986
#
# th_pt MSE :  3056.8498295105
# th_eta MSE :  1.1395491545
# th_phi MSE :  0.9799241168
# tl_pt MSE :  1898.7107326398
# tl_eta MSE :  0.6838813160
# tl_phi MSE :  0.6227956339
# wl_pt MSE :  650.8867061625
# wl_eta MSE :  0.3968188519
# wl_phi MSE :  0.1968839071

# %%
display.predictions_vs_sample(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.variable_histogram(predictions_origscale, true_origscale, Y_keys, True, [None for name in Y_names])

# %%
display.predicted_vs_true(predictions_origscale, true_origscale, Y_keys, True)
