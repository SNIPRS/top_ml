# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Input, concatenate, Masking, LSTM, TimeDistributed
from tensorflow.keras import regularizers 
from tensorflow.keras import initializers
import h5py 
import os 
os.environ["CUDA_VISIBLE_DEVICES"]="1"


# %matplotlib inline 

dataset = h5py.File('./../../../../../data/hongtao/variables_tt_re2.h5','r')

X_keys = ['j1_pt', 'j1_eta', 'j1_phi', 'j1_m', 'j1_DL1r', 'j2_pt', 'j2_eta', 'j2_phi', 'j2_m', 'j2_DL1r', 'j3_pt', 'j3_eta', 'j3_phi', 'j3_m', 'j3_DL1r', 'j4_pt', 'j4_eta', 'j4_phi', 'j4_m', 'j4_DL1r', 'j5_pt', 'j5_eta', 'j5_phi', 'j5_m', 'j5_DL1r', 'j6_pt', 'j6_eta', 'j6_phi', 'j6_m', 'j6_DL1r', 'lep_pt', 'lep_eta', 'lep_phi', 'met_met', 'met_phi']
Y_keys = ['th_pt', 'th_eta','th_phi', 'tl_pt', 'tl_eta', 'tl_phi', 'wl_pt', 'wl_eta', 'wl_phi']
phi_keys = ['j1_phi', 'j2_phi', 'j3_phi','j4_phi','j5_phi','j6_phi', 'lep_phi', 'met_phi', 'th_phi', 'tl_phi', 'wl_phi']
eta_keys = ['j1_eta', 'j2_eta', 'j3_eta', 'j4_eta', 'j5_eta', 'j5_phi', 'j6_eta', 'lep_eta', 'th_eta', 'tl_eta', 'wl_eta']
pt_keys = ['j1_pt', 'j2_pt','j3_pt','j4_pt','j5_pt','j6_pt','lep_pt','th_pt', 'tl_pt', 'wl_pt']
m_keys = ['j1_m','j2_m', 'j3_m', 'j4_m', 'j5_m', 'j6_m', 'wl_m']
DL1r_keys = ['j1_DL1r','j2_DL1r','j3_DL1r','j4_DL1r','j5_DL1r','j6_DL1r']


Y_length = len(Y_keys)
X_length = len(X_keys)
crop0 =  100000

# %%
import scale_variables
import shape_timesteps

# How to scale each input/output
def get_methods(keys):
    types = {'pt':'cartbox', 'eta':'meanmax', 'phi':'sincos', 'DL1r':'meanmax', 'm':'boxcox', 'met':'meanmax'}
    var_types = [key.split('_')[1] for key in keys]
    methods = [types[var] for var in var_types]
    return methods

X_methods = get_methods(X_keys)
Y_methods = get_methods(Y_keys)

Scaler = scale_variables.Scale_variables()
(X_total, X_maxmean), X_names = Scaler.scale_arrays(X_keys, X_methods, True)
(Y_total, Y_maxmean), Y_names = Scaler.scale_arrays(Y_keys, Y_methods, True)

error = Scaler.test_inverse(Y_keys, Y_methods, True)
print('Max scaling error: {}'.format(error))
# Out:
# Max scaling error: 7.958078640513122e-13

# %%
# Create X and test array
split = int(np.floor(0.8*crop0)) # 80/20 split 

trainY, testY = Y_total[0:split,:], Y_total[split:,:]

timestep_builder = shape_timesteps.Shape_timesteps()
totalX_jets, totalX_other = timestep_builder.reshape_X(X_total, X_names, False,True)

trainX_jets, testX_jets = totalX_jets[0:split,:,:], totalX_jets[split:,:,:]
trainX_other, testX_other = totalX_other[0:split,:], totalX_other[split:,:]

# Save some memory 
del totalX_jets
del totalX_other 

print(trainX_jets.shape, trainX_other.shape, trainY.shape)
print(testX_jets.shape, testX_other.shape, testY.shape)
# Out:
# (80000, 6, 5) (80000, 6) (80000, 9)
# (20000, 6, 5) (20000, 6) (20000, 9)

# %%
# Histograms of total  Y variables 
show = True

other_bins = np.linspace(-1, 1, 40)
phi_bins = np.linspace(-0.1, 0.1, 40)
pt_bins = np.linspace(-0.3, 1, 40)
Y_bins = [phi_bins if 'phi' in name else pt_bins if 'pt' in name else other_bins for name in Y_names]

if show:
    plt.figure(figsize=(6,6*trainY.shape[1]))
    for i in range(0, trainY.shape[1]):
        plt.subplot(trainY.shape[1], 1, i+1)
        bins = Y_bins[i]
        plt.hist(Y_total[:,i], bins, histtype='step')
        plt.xlabel(Y_names[i])
        plt.ylabel('Frequency')

# %%
# Histograms of X variables (without the mask)
show = False

if show:
    plt.figure(figsize=(6,6*X_total.shape[1]))
    for i in range(0, X_total.shape[1]):
        plt.subplot(X_total.shape[1], 1, i+1)
        plt.hist(X_total[:,i], 40, histtype='step')
        plt.xlabel(X_names[i])
        plt.ylabel('Frequency')

# %%
# Build model

def build_model():
    jet_input = Input(shape=(trainX_jets.shape[1], trainX_jets.shape[2]))
    Mask = Masking(-2)(jet_input)
    LSTM11 = LSTM(64, return_sequences=True)(Mask)
    LSTM12 = LSTM(64, return_sequences=True)(LSTM11)
    
    flat_jets = Flatten()(LSTM12)
    
    other_input = Input(shape=(trainX_other.shape[1]))
    Dense21 = Dense(64, activation='relu')(other_input)
    flat_other = Flatten()(Dense21)
    
    concat = concatenate([flat_other, flat_jets])
    dense1 = Dense(256, activation='relu')(concat)
    dense2 = Dense(128, activation='relu')(dense1)
    output = Dense(len(Y_names), activation='linear')(dense2)
    
    model = keras.models.Model(inputs=[jet_input, other_input], outputs=output)
    optimizer = keras.optimizers.Adam(learning_rate=5e-5)
    model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    
    return model 

model = build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6, 5)]       0
# __________________________________________________________________________________________________
# masking (Masking)               (None, 6, 5)         0           input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 6, 64)        17920       masking[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           448         input_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 6, 64)        33024       lstm[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 384)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 448)          0           flatten_1[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          114944      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 9)            1161        dense_2[0][0]
# ==================================================================================================
# Total params: 200,393
# Trainable params: 200,393
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model

callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

Epochs= 512

# del X_total
# del Y_total

history = model.fit([trainX_jets, trainX_other], trainY, verbose=1, epochs=Epochs, 
                   validation_split=0.2, shuffle=False, callbacks=[callback],
                   batch_size=512)
# Out:
# Train on 64000 samples, validate on 16000 samples
# Epoch 1/512
# 64000/64000 [==============================] - 14s 219us/sample - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 2/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 3/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 4/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 5/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 6/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 7/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 8/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 9/512
# 64000/64000 [==============================] - 2s 38us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 10/512
# 64000/64000 [==============================] - 2s 38us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 11/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 12/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 13/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 14/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 15/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 16/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 17/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 18/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 19/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 20/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 21/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 22/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 23/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 24/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 25/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 26/512
# 64000/64000 [==============================] - 2s 38us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 27/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 28/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 29/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 30/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 31/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 32/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 33/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 34/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 35/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 36/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 37/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 38/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 39/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 40/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 41/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 42/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 43/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 44/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 45/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 46/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 47/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 48/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 49/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 50/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 51/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 52/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 53/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 54/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 55/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 56/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 57/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 58/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 59/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 60/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 61/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 62/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 63/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 64/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 65/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 66/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 67/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 68/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 69/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 70/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 71/512
# 64000/64000 [==============================] - 2s 38us/sample - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 72/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 73/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 74/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 75/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 76/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 77/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 78/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 79/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 80/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 81/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 82/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 83/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 84/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 85/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 86/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 87/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 88/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 89/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 90/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 91/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 92/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 93/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 94/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 95/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 96/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 97/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 98/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 99/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 100/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 101/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 102/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 103/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 104/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 105/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 106/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 107/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 108/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 109/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 110/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 111/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 112/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 113/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 114/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 115/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 116/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 117/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 118/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 119/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 120/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 121/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 122/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 123/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 124/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 125/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 126/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 127/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 128/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 129/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 130/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 131/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 132/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 133/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 134/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 135/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 136/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 137/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 138/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 139/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 140/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 141/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 142/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 143/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 144/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 145/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 146/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 147/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 148/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 149/512
# 64000/64000 [==============================] - 2s 38us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 150/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 151/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 152/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 153/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 154/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 155/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 156/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 157/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 158/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 159/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 160/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 161/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 162/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 163/512
# 64000/64000 [==============================] - 2s 38us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 164/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 165/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 166/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 167/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 168/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 169/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 170/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 171/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 172/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 173/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 174/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 175/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 176/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 177/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 178/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 179/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 180/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 181/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 182/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 183/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 184/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 185/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 186/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 187/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 188/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 189/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 190/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 191/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 192/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 193/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 194/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 195/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 196/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 197/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 198/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 199/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 200/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 201/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 202/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 203/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 204/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 205/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 206/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 207/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 208/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 209/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 210/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 211/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 212/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 213/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 214/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 215/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 216/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 217/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 218/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 219/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 220/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 221/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 222/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 223/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 224/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 225/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 226/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 227/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 228/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 229/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 230/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 231/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 232/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 233/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 234/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 235/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 236/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 237/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 238/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 239/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 240/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 241/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 242/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 243/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 244/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 245/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 246/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 247/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 248/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 249/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 250/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 251/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 252/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 253/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 254/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 255/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 256/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 257/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 258/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 259/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 260/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 261/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 262/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 263/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 264/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 265/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 266/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 267/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 268/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 269/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 270/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 271/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 272/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 273/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 274/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 275/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 276/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 277/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 278/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 279/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 280/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 281/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 282/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 283/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 284/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 285/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 286/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 287/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 288/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 289/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 290/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 291/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 292/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 293/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 294/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 295/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 296/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 297/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 298/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 299/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 300/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 301/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 302/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 303/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 304/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 305/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 306/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 307/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 308/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 309/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 310/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 311/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 312/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 313/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 314/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 315/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 316/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 317/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 318/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 319/512
# 64000/64000 [==============================] - 2s 35us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 320/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 321/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 322/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 323/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 324/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 325/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 326/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 327/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 328/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 329/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 330/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 331/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 332/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 333/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 334/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 335/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 336/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 337/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 338/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 339/512
# ...
# Epoch 401/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 402/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 403/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 404/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 405/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 406/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 407/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 408/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 409/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 410/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 411/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 412/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 413/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 414/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 415/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 416/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 417/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 418/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 419/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 420/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 421/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 422/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 423/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 424/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 425/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 426/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 427/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 428/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 429/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 430/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 431/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 432/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 433/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 434/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 435/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 436/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 437/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 438/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 439/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 440/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 441/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 442/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 443/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 444/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 445/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 446/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 447/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 448/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 449/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 450/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 451/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 452/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 453/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 454/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 455/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 456/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 457/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 458/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 459/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 460/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 461/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 462/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 463/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 464/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 465/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 466/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 467/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 468/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 469/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 470/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 471/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 472/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 473/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 474/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 475/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 476/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 477/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 478/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 479/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 480/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 481/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 482/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 483/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 484/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 485/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 486/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 487/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 488/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 489/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 490/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 491/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 492/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 493/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 494/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 495/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 496/512
# 64000/64000 [==============================] - 2s 36us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 497/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 498/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 499/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 500/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 501/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 502/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 503/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 504/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 505/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 506/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 507/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 508/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 509/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 510/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 511/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 512/512
# 64000/64000 [==============================] - 2s 37us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0049 - val_mse: 0.0049

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('mse loss')
plt.legend()
plt.title('MSE loss')
# Out:
# Text(0.5, 1.0, 'MSE loss')

# %%
class Analysis:
    def __init__(self):
        self.crop = 100
        self.fsize = 6
        self.histogram_bins = 40
        
    def wrap_phi(self, var):
        var = var%(2*np.pi)
        var = var - 2*np.pi*(var > np.pi)
        return var
        
    def predictions_vs_sample(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2, self.fsize*len(names)))
        for i in range(0, len(names)):
            compare_small = compare[:self.crop,i]
            true_small = true[:self.crop,i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            plt.subplot(len(names), 1, i+1)
            plt.plot(range(0,self.crop), compare_small, 'bo', markersize=3, label = 'Predictions')
            plt.plot(range(0,self.crop), true_small, 'ro', markersize=3, label = 'True Value')
            ym, yM = plt.ylim()
            for x in range(self.crop):
                plt.vlines(x, color='g', linestyle='-', alpha=0.2, ymin= 
                            min(compare_small[x], true_small[x]), 
                            ymax= max(compare_small[x], true_small[x]))
            plt.hlines(np.mean(true[:,i]), xmin=-20, xmax=self.crop+20, alpha=0.5)
            MSE = 1/compare[:,i].size*np.sum((compare[:,i]- true[:,i])**2)
            plt.xlabel('Sample')
            plt.xlim(0, self.crop)
            plt.ylabel(names[i])
            plt.title(names[i] + " MSE: " + str(MSE))
            plt.legend()
    
    def display_errors(self, compare, true, names, wrap_phi):
        MSE = 1/compare.size*np.sum((compare- true)**2)
        print("total MSE: " + str(MSE))
        print(" ")
        for i in range(len(names)):
            diff = compare[:,i] -true[:,i]
            if wrap_phi and "phi" in names[i]:
                diff = self.wrap_phi(diff)
            MSE = 1/compare[:,i].size*np.sum((diff)**2)
            print("{0} MSE : ".format(names[i]), '%.10f'%MSE)
    
    def difference_histogram(self, compare, true, names, wrap_phi, bins):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            diff = true[:,i] - compare[:,i]
            hist0, bin_edges = np.histogram(true[:, i], bins=40)
            if bins[i] is None:
                hbins = bin_edges
            else:
                hbins = bins[i]
            plt.hist(diff, hbins, histtype='step', color='purple', label='true - predicted', density=True)
            plt.xlabel("Difference (Mean: {0}, Std: {1})".format(np.mean(diff), np.std(diff)))
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
            
    def variable_histogram(self, compare, true, names, wrap_phi, bins): 
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            compare_small = compare[:, i]
            true_small = true[:, i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            hist0, bin_edges = np.histogram(true[:, i], bins=40)
            
            if bins[i] is None:
                hbins = bin_edges
            else:
                hbins = bins[i]
                
            plt.hist(true_small, hbins, histtype='step', color='b', label='true values', density=False)
            plt.hist(compare_small, hbins, histtype='step', color='r', label='predictions', density=False)
            plt.xlabel(names[i])
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
    
    def difference_vs_variable(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], true[:, i]-compare[:, i], 'o', color='purple', label='True - Predicted', markersize=2)
            plt.xlabel('True ' + names[i])
            plt.legend()
            plt.ylabel('Difference')
    
    def predicted_vs_true(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], compare[:, i], 'o', color='g', markersize=2)
            line = np.linspace(np.min(true[:, i]), np.max(true[:, i]), 100)
            plt.plot(line, line, color='b')
            plt.xlabel('True')
            plt.title(names[i])
            plt.ylabel('Predicted')

# %%
display = Analysis()

predictions_unscaled = model.predict([testX_jets, testX_other])
true_unscaled = testY 

total_predictions = model.predict([np.append(trainX_jets,testX_jets,axis=0), np.append(trainX_other,testX_other,axis=0)])
(Y_total, TO_maxmean0), _ = Scaler.scale_arrays(Y_keys, Y_methods, True)

predictions_origscale = Scaler.invscale_arrays(Y_keys, total_predictions, _, Y_methods, TO_maxmean0)[split:,:]
true_origscale = Scaler.invscale_arrays(Y_keys, Y_total, _, Y_methods, TO_maxmean0)[split:,:]

del Y_total
del TO_maxmean0
del _
del total_predictions

# %% [markdown]
# # Training scale plots

# %%
display.display_errors(predictions_unscaled, true_unscaled, Y_names, False)
# Out:
# total MSE: 0.0048808690025579325
#
# th_px MSE :  0.0027085378
# th_py MSE :  0.0029323694
# th_eta MSE :  0.0105406274
# tl_px MSE :  0.0017025326
# tl_py MSE :  0.0044391149
# tl_eta MSE :  0.0088949034
# wl_px MSE :  0.0011954848
# wl_py MSE :  0.0029125206
# wl_eta MSE :  0.0086017301

# %%
display.predictions_vs_sample(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.variable_histogram(predictions_unscaled, true_unscaled, Y_names, False, Y_bins)

# %%
display.difference_histogram(predictions_unscaled, true_unscaled, Y_names, False, Y_bins)

# %%
display.predicted_vs_true(predictions_unscaled, true_unscaled, Y_names, False)

# %% [markdown]
#  # Original scale plots

# %%
display.display_errors(predictions_origscale, true_origscale, Y_keys, True)
# Out:
# total MSE: 508.0763509276348
#
# th_pt MSE :  2302.2491821135
# th_eta MSE :  0.5798385230
# th_phi MSE :  0.9504290918
# tl_pt MSE :  1633.4308554604
# tl_eta MSE :  0.4451110314
# tl_phi MSE :  0.6002139195
# wl_pt MSE :  628.7540702821
# wl_eta MSE :  0.3073992685
# wl_phi MSE :  0.2179830095

# %%
display.predictions_vs_sample(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.variable_histogram(predictions_origscale, true_origscale, Y_keys, True, [None for name in Y_names])

# %%
display.predicted_vs_true(predictions_origscale, true_origscale, Y_keys, True)
