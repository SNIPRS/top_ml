# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers 
from tensorflow.keras.initializers import Constant
import h5py


# %matplotlib inline 

dataset = h5py.File('./../../../../../data/hongtao/variables_tt_re2.h5','r')

X_keys = ['j1_pt', 'j1_eta', 'j1_phi', 'j1_m', 'j1_DL1r', 'j2_pt', 'j2_eta', 'j2_phi', 'j2_m', 'j2_DL1r', 'j3_pt', 'j3_eta', 'j3_phi', 'j3_m', 'j3_DL1r', 'j4_pt', 'j4_eta', 'j4_phi', 'j4_m', 'j4_DL1r', 'j5_pt', 'j5_eta', 'j5_phi', 'j5_m', 'j5_DL1r', 'j6_pt', 'j6_eta', 'j6_phi', 'j6_m', 'j6_DL1r', 'lep_pt', 'lep_eta', 'met_met', 'met_phi'] 
Y_keys = ['th_pt', 'th_eta','th_phi', 'tl_pt', 'tl_eta', 'tl_phi', 'wl_eta', 'wl_phi', 'wl_pt']
phi_keys = ['j1_phi', 'j2_phi', 'j3_phi','j4_phi','j5_phi','j6_phi', 'lep_phi', 'met_phi', 'th_phi', 'tl_phi', 'wl_phi']
eta_keys = ['j1_eta', 'j2_eta', 'j3_eta', 'j4_eta', 'j5_eta', 'j5_phi', 'j6_eta', 'lep_eta', 'th_eta', 'tl_eta', 'wl_eta']
pt_keys = ['j1_pt', 'j2_pt','j3_pt','j4_pt','j5_pt','j6_pt','lep_pt','th_pt', 'tl_pt', 'wl_pt']
m_keys = ['j1_m','j2_m', 'j3_m', 'j4_m', 'j5_m', 'j6_m', 'wl_m']
DL1r_keys = ['j1_DL1r','j2_DL1r','j3_DL1r','j4_DL1r','j5_DL1r','j6_DL1r']


Y_length = len(Y_keys)
X_length = len(X_keys)
crop0 =  200000

# %%
import scale_variables

# How to scale each input/output
def get_methods(keys):
    types = {'pt':'boxcox', 'eta':'meanmax', 'phi':'sincos', 'DL1r':'meanmax', 'm':'boxcox', 'met':'meanmax'}
    var_types = [key.split('_')[1] for key in keys]
    methods = [types[var] for var in var_types]
    return methods

X_methods = get_methods(X_keys)
Y_methods = get_methods(Y_keys)

Scaler = scale_variables.Scale_variables()
(X_total, X_maxmean), X_names = Scaler.scale_arrays(X_keys, X_methods, True)
(Y_total, Y_maxmean), Y_names = Scaler.scale_arrays(Y_keys, Y_methods, True)

error = Scaler.test_inverse(Y_keys, Y_methods, True)
print('Max scaling error: {}'.format(error))
# Out:
# Max scaling error: 9.094947017729282e-13

# %%
# Create X and test array
split = int(np.floor(0.8*crop0))
shuffle = False

if shuffle:
    rng_state = np.random.get_state()
    np.random.shuffle(X_total)
    np.random.set_state(rng_state)
    np.random.shuffle(Y_total)

trainX, testX = X_total[0:split, :], X_total[split:,:]
trainY, testY = Y_total[0:split,:], Y_total[split:,:]

print(trainX.shape, trainY.shape)
print(testX.shape, testY.shape)
# Out:
# (160000, 41) (160000, 12)
# (40000, 41) (40000, 12)

# %%
# Histograms of total  Y variables 
show = True

other_bins = np.linspace(-1, 1, 40)
phi_bins = np.linspace(-0.1, 0.1, 40)
pt_bins = np.linspace(-0.3, 1, 40)
Y_bins = [phi_bins if 'phi' in name else pt_bins if 'pt' in name else other_bins for name in Y_names]

if show:
    plt.figure(figsize=(6,6*trainY.shape[1]))
    for i in range(0, trainY.shape[1]):
        plt.subplot(trainY.shape[1], 1, i+1)
        bins = Y_bins[i]
        plt.hist(Y_total[:,i], bins, histtype='step')
        plt.xlabel(Y_names[i])
        plt.ylabel('Frequency')

# %%
# Histograms of total X variables 
show = True

X_bins = [phi_bins if 'phi' in name else pt_bins if 'pt' in name else other_bins for name in X_names]

if show:
    plt.figure(figsize=(6,6*trainX.shape[1]))
    for i in range(0, trainX.shape[1]):
        plt.subplot(trainX.shape[1], 1, i+1)
        bins = X_bins[i]
        plt.hist(X_total[:,i], bins, histtype='step')
        plt.xlabel(X_names[i])
        plt.ylabel('Frequency')

# %%
# Build model

# optimizer = keras.optimizers.RMSprop(learning_rate = 1e-5)
optimizer = keras.optimizers.Adam(learning_rate=1e-5)
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)


def build_model():
    model = keras.Sequential([
        layers.Dense(256,
                     input_shape=[len(X_names)]),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(128),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(128),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(64),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(64),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(32),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(32),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(32),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(32),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(32),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(32),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(32),
        layers.PReLU(alpha_initializer=Constant(value=0.1)),
        layers.Dense(32, activation='linear'),
        layers.Dense(len(Y_names),  activation='linear')
    ])
    
    model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               10752
# _________________________________________________________________
# p_re_lu (PReLU)              (None, 256)               256
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# p_re_lu_1 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# p_re_lu_2 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# p_re_lu_3 (PReLU)            (None, 64)                64
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# p_re_lu_4 (PReLU)            (None, 64)                64
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# p_re_lu_5 (PReLU)            (None, 32)                32
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# p_re_lu_6 (PReLU)            (None, 32)                32
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                1056
# _________________________________________________________________
# p_re_lu_7 (PReLU)            (None, 32)                32
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                1056
# _________________________________________________________________
# p_re_lu_8 (PReLU)            (None, 32)                32
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                1056
# _________________________________________________________________
# p_re_lu_9 (PReLU)            (None, 32)                32
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# p_re_lu_10 (PReLU)           (None, 32)                32
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                1056
# _________________________________________________________________
# p_re_lu_11 (PReLU)           (None, 32)                32
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_13 (Dense)             (None, 12)                396
# =================================================================
# Total params: 83,308
# Trainable params: 83,308
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model

Epochs= 512

history = model.fit(trainX, trainY, verbose=1, epochs=Epochs, 
                   validation_split=0.2, shuffle=False, callbacks=[callback],
                   batch_size=512)
# Out:
# Train on 128000 samples, validate on 32000 samples
# Epoch 1/512
# 128000/128000 [==============================] - 4s 34us/sample - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 2/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 3/512
# 128000/128000 [==============================] - 2s 19us/sample - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 4/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 5/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 6/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 7/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 8/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 9/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 10/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 11/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 12/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 13/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 14/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 15/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 16/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 17/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 18/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 19/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 20/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 21/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 22/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 23/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 24/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 25/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 26/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 27/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 28/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 29/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 30/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 31/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 32/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 33/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 34/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 35/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 36/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 37/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 38/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 39/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 40/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 41/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 42/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 43/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 44/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 45/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 46/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 47/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 48/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 49/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 50/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 51/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 52/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 53/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 54/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 55/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 56/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 57/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 58/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 59/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 60/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 61/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 62/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 63/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 64/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 65/512
# 128000/128000 [==============================] - 2s 16us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 66/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 67/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 68/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 69/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 70/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 71/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 72/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 73/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 74/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 75/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 76/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 77/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 78/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 79/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 80/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 81/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 82/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 83/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 84/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 85/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 86/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 87/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 88/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 89/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 90/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 91/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 92/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 93/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 94/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 95/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 96/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 97/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 98/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 99/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 100/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 101/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 102/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 103/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 104/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 105/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 106/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 107/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 108/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 109/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 110/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 111/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 112/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 113/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 114/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 115/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 116/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 117/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 118/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 119/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 120/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 121/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 122/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 123/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 124/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 125/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 126/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 127/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 128/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 129/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 130/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 131/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 132/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 133/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 134/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 135/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 136/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 137/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 138/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 139/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 140/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 141/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 142/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 143/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 144/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 145/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 146/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 147/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 148/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 149/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 150/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 151/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 152/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 153/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 154/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 155/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 156/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 157/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 158/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 159/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 160/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 161/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 162/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 163/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 164/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 165/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 166/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 167/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 168/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 169/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 170/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 171/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 172/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 173/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 174/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 175/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 176/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 177/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 178/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 179/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 180/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 181/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 182/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 183/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 184/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 185/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 186/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 187/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 188/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 189/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 190/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 191/512
# 128000/128000 [==============================] - 2s 16us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 192/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 193/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 194/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 195/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 196/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 197/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 198/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 199/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 200/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 201/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 202/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 203/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 204/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 205/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 206/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 207/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 208/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 209/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 210/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 211/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 212/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 213/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 214/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 215/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 216/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 217/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 218/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 219/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 220/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 221/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 222/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 223/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 224/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 225/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 226/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 227/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 228/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 229/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 230/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 231/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 232/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 233/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 234/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 235/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 236/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 237/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 238/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 239/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 240/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 241/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 242/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 243/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 244/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 245/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 246/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 247/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 248/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 249/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 250/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 251/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 252/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 253/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 254/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 255/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 256/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 257/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 258/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 259/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 260/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 261/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 262/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 263/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 264/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 265/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 266/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 267/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 268/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 269/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 270/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 271/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 272/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 273/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 274/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 275/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 276/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 277/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 278/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 279/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 280/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 281/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 282/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 283/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 284/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 285/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 286/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 287/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 288/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 289/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 290/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 291/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 292/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 293/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 294/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 295/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 296/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 297/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 298/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 299/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 300/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 301/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 302/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 303/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 304/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 305/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 306/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 307/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 308/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 309/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 310/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 311/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 312/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 313/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 314/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 315/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 316/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 317/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 318/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 319/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 320/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 321/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 322/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 323/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 324/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 325/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 326/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 327/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 328/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 329/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 330/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 331/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 332/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 333/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 334/512
# ...
# Epoch 402/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 403/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 404/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 405/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 406/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 407/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 408/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 409/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 410/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 411/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 412/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 413/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 414/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 415/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 416/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 417/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 418/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 419/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 420/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 421/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 422/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 423/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 424/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 425/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 426/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 427/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 428/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 429/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 430/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 431/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 432/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 433/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 434/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 435/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 436/512
# 128000/128000 [==============================] - 2s 16us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 437/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 438/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 439/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 440/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 441/512
# 128000/128000 [==============================] - 2s 16us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 442/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 443/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 444/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 445/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 446/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 447/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 448/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 449/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 450/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 451/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 452/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 453/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 454/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 455/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 456/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 457/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 458/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 459/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 460/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 461/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 462/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 463/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 464/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 465/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 466/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 467/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 468/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 469/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 470/512
# 128000/128000 [==============================] - 2s 16us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 471/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 472/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 473/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 474/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 475/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 476/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 477/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 478/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 479/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 480/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 481/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 482/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 483/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 484/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 485/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 486/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 487/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 488/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 489/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 490/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 491/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 492/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 493/512
# 128000/128000 [==============================] - 2s 16us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 494/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 495/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 496/512
# 128000/128000 [==============================] - 2s 16us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 497/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 498/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 499/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 500/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 501/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 502/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 503/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 504/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 505/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 506/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 507/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 508/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 509/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 510/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 511/512
# 128000/128000 [==============================] - 2s 17us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 512/512
# 128000/128000 [==============================] - 2s 18us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('mse loss')
plt.legend()
plt.title('MSE loss')
# Out:
# Text(0.5, 1.0, 'MSE loss')

# %%
class Analysis:
    def __init__(self):
        self.crop = 100
        self.fsize = 6
        self.histogram_bins = 40
        
    def wrap_phi(self, var):
        var = var%(2*np.pi)
        var = var - 2*np.pi*(var > np.pi)
        return var
        
    def predictions_vs_sample(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2, self.fsize*len(names)))
        for i in range(0, len(names)):
            compare_small = compare[:self.crop,i]
            true_small = true[:self.crop,i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            plt.subplot(len(names), 1, i+1)
            plt.plot(range(0,self.crop), compare_small, 'bo', markersize=3, label = 'Predictions')
            plt.plot(range(0,self.crop), true_small, 'ro', markersize=3, label = 'True Value')
            ym, yM = plt.ylim()
            for x in range(self.crop):
                plt.vlines(x, color='g', linestyle='-', alpha=0.2, ymin= 
                            min(compare_small[x], true_small[x]), 
                            ymax= max(compare_small[x], true_small[x]))
            plt.hlines(np.mean(true[:,i]), xmin=-20, xmax=self.crop+20, alpha=0.5)
            MSE = 1/compare[:,i].size*np.sum((compare[:,i]- true[:,i])**2)
            plt.xlabel('Sample')
            plt.xlim(0, self.crop)
            plt.ylabel(names[i])
            plt.title(names[i] + " MSE: " + str(MSE))
            plt.legend()
    
    def display_errors(self, compare, true, names, wrap_phi):
        MSE = 1/compare.size*np.sum((compare- true)**2)
        print("total MSE: " + str(MSE))
        print(" ")
        for i in range(len(names)):
            diff = compare[:,i] -true[:,i]
            if wrap_phi and "phi" in names[i]:
                diff = self.wrap_phi(diff)
            MSE = 1/compare[:,i].size*np.sum((diff)**2)
            print("{0} MSE : ".format(names[i]), '%.10f'%MSE)
    
    def difference_histogram(self, compare, true, names, wrap_phi, bins):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            diff = true[:,i] - compare[:,i]
            hist0, bin_edges = np.histogram(true[:, i], bins=40)
            if bins[i] is None:
                hbins = bin_edges
            else:
                hbins = bins[i]
            plt.hist(diff, hbins, histtype='step', color='purple', label='true - predicted', density=True)
            plt.xlabel("Difference (Mean: {0}, Std: {1})".format(np.mean(diff), np.std(diff)))
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
            
    def variable_histogram(self, compare, true, names, wrap_phi, bins): 
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            compare_small = compare[:, i]
            true_small = true[:, i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            hist0, bin_edges = np.histogram(true[:, i], bins=40)
            
            if bins[i] is None:
                hbins = bin_edges
            else:
                hbins = bins[i]
                
            plt.hist(true_small, hbins, histtype='step', color='b', label='true values', density=False)
            plt.hist(compare_small, hbins, histtype='step', color='r', label='predictions', density=False)
            plt.xlabel(names[i])
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
    
    def difference_vs_variable(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], true[:, i]-compare[:, i], 'o', color='purple', label='True - Predicted', markersize=2)
            plt.xlabel('True ' + names[i])
            plt.legend()
            plt.ylabel('Difference')
    
    def predicted_vs_true(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], compare[:, i], 'o', color='g', markersize=2)
            line = np.linspace(np.min(true[:, i]), np.max(true[:, i]), 100)
            plt.plot(line, line, color='b')
            plt.xlabel('True')
            plt.title(names[i])
            plt.ylabel('Predicted')

# %%
display = Analysis()

predictions_unscaled = model.predict([testX])
true_unscaled = testY 

total_predictions = model.predict([np.append(trainX,testX,axis=0)])
(Y_total, TO_maxmean0), _ = Scaler.scale_arrays(Y_keys, Y_methods, True)

predictions_origscale = Scaler.invscale_arrays(Y_keys, total_predictions, _, Y_methods, TO_maxmean0)[split:,:]
true_origscale = Scaler.invscale_arrays(Y_keys, Y_total, _, Y_methods, TO_maxmean0)[split:,:]

# del Y_total
# del TO_maxmean0
# del _
# del total_predictions

# %% [markdown]
# # Training scale plots

# %%
display.display_errors(predictions_unscaled, true_unscaled, Y_names, False)
# Out:
# total MSE: 0.004011352696855501
#
# th_pt MSE :  0.0044505355
# th_eta MSE :  0.0095526704
# th_phi-sin MSE :  0.0021000854
# th_phi-cos MSE :  0.0017232421
# tl_pt MSE :  0.0060508825
# tl_eta MSE :  0.0073562508
# tl_phi-sin MSE :  0.0016456221
# tl_phi-cos MSE :  0.0011659287
# wl_eta MSE :  0.0085616069
# wl_phi-sin MSE :  0.0007364139
# wl_phi-cos MSE :  0.0004818612
# wl_pt MSE :  0.0043111330

# %%
display.predictions_vs_sample(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.variable_histogram(predictions_unscaled, true_unscaled, Y_names, False, Y_bins)

# %%
display.difference_histogram(predictions_unscaled, true_unscaled, Y_names, False, Y_bins)

# %%
display.predicted_vs_true(predictions_unscaled, true_unscaled, Y_names, False)

# %% [markdown]
#  # Original scale plots

# %%
display.display_errors(predictions_origscale, true_origscale, Y_keys, True)
# Out:
# total MSE: 453.0515743965953
#
# th_pt MSE :  1921.0228524728
# th_eta MSE :  0.5661093657
# th_phi MSE :  1.1552893205
# tl_pt MSE :  1501.8064179637
# tl_eta MSE :  0.4363902984
# tl_phi MSE :  0.7649074322
# wl_eta MSE :  0.3063639292
# wl_phi MSE :  0.2538189085
# wl_pt MSE :  644.9041281432

# %%
display.predictions_vs_sample(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.variable_histogram(predictions_origscale, true_origscale, Y_keys, True, [None for name in Y_names])

# %%
display.predicted_vs_true(predictions_origscale, true_origscale, Y_keys, True)
