# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers 
from tensorflow.keras.utils import plot_model
import scipy.stats as stats
import os 
import h5py
import sys
import re

# %matplotlib inline 

dataset = h5py.File('./../../../../../data/hongtao/variables_tt_re2.h5','r')

X_keys = ['j1_pt', 'j1_eta', 'j1_phi', 'j1_m', 'j1_DL1r', 'j2_pt', 'j2_eta', 'j2_phi', 'j2_m', 'j2_DL1r', 'j3_pt', 'j3_eta', 'j3_phi', 'j3_m', 'j3_DL1r', 'j4_pt', 'j4_eta', 'j4_phi', 'j4_m', 'j4_DL1r', 'j5_pt', 'j5_eta', 'j5_phi', 'j5_m', 'j5_DL1r', 'j6_pt', 'j6_eta', 'j6_phi', 'j6_m', 'j6_DL1r', 'j7_pt', 'lep_pt', 'lep_eta', 'lep_phi', 'met_met', 'met_phi'] 
Y_keys = ['th_pt', 'th_eta','th_phi', 'tl_pt', 'tl_eta', 'tl_phi', 'wl_eta', 'wl_phi', 'wl_pt']
phi_keys = ['j1_phi', 'j2_phi', 'j3_phi','j4_phi','j5_phi','j6_phi', 'lep_phi', 'met_phi', 'th_phi', 'tl_phi', 'wl_phi']
eta_keys = ['j1_eta', 'j2_eta', 'j3_eta', 'j4_eta', 'j5_eta', 'j5_phi', 'j6_eta', 'lep_eta', 'th_eta', 'tl_eta', 'wl_eta']
pt_keys = ['j1_pt', 'j2_pt','j3_pt','j4_pt','j5_pt','j6_pt','lep_pt','th_pt', 'tl_pt', 'wl_pt']
m_keys = ['j1_m','j2_m', 'j3_m', 'j4_m', 'j5_m', 'j6_m', 'wl_m']
DL1r_keys = ['j1_DL1r','j2_DL1r','j3_DL1r','j4_DL1r','j5_DL1r','j6_DL1r']

Y_length = len(Y_keys)
X_length = len(X_keys)
crop0 =  500000

# %%
import scale_variables

# How to scale each input/output
def get_methods(keys):
    types = {'pt':'boxcox', 'eta':'meanmax', 'phi':'linear_sincos_orig', 'DL1r':'meanmax', 'm':'boxcox', 'met':'meanmax'}
    var_types = [key.split('_')[1] for key in keys]
    methods = [types[var] for var in var_types]
    return methods

X_methods = get_methods(X_keys)
Y_methods = get_methods(Y_keys)

Scaler = scale_variables.Scale_variables()
(X_total, X_maxmean), X_names = Scaler.scale_arrays(X_keys, X_methods, True)
(Y_total, Y_maxmean), Y_names = Scaler.scale_arrays(Y_keys, Y_methods, True)

error = Scaler.test_inverse(X_keys, X_methods, True)
print('Max scaling error: {}'.format(error))
# Out:
# Max scaling error: 1.4495071809506044e-12

# %%
# Create X and test array
split = int(np.floor(0.95*crop0))
shuffle = False

if shuffle:
    rng_state = np.random.get_state()
    np.random.shuffle(X_total)
    np.random.set_state(rng_state)
    np.random.shuffle(Y_total)

trainX, testX = X_total[0:split, :], X_total[split:,:]
trainY, testY = Y_total[0:split,:], Y_total[split:,:]

print(trainX.shape, trainY.shape)
print(testX.shape, testY.shape)
# Out:
# (475000, 52) (475000, 15)
# (25000, 52) (25000, 15)

# %%
# Histograms of Y variables 
show = True

if show:
    plt.figure(figsize=(6,6*trainY.shape[1]))
    for i in range(0, trainY.shape[1]):
        plt.subplot(trainY.shape[1], 1, i+1)
        plt.hist(trainY[:,i], 20, histtype='step')
        plt.xlabel(Y_names[i])
        plt.ylabel('Frequency')

# %%
# Histograms of X variables 
show = True

if show:
    plt.figure(figsize=(6,6*trainX.shape[1]))
    for i in range(0, trainX.shape[1]):
        plt.subplot(trainX.shape[1], 1, i+1)
        plt.hist(trainX[:,i], 20, histtype='step')
        plt.xlabel(X_names[i])
        plt.ylabel('Frequency')

# %%
# Build model

# optimizer = keras.optimizers.RMSprop(learning_rate = 1e-5)
optimizer = keras.optimizers.Adam(learning_rate=1e-5)
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)


def build_model():
    model = keras.Sequential([
        layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0001),
                     input_shape=[len(X_names)]),
        layers.Dense(256,  activation='relu'),
        layers.Dense(256,  activation='relu'),
        layers.Dense(256,  activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(len(Y_names),  activation='linear')
    ])
    
    model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    return model 

# def build_model():
#     model = keras.Sequential([
#         layers.Dense(6, activation='linear', 
#                      X_shape=[len(X_keys)])])
    
#     model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    
#     return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               27136
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_7 (Dense)              (None, 15)                1935
# =================================================================
# Total params: 357,903
# Trainable params: 357,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model

Epochs= 1024

history = model.fit(trainX, trainY, verbose=1, epochs=Epochs, 
                   validation_split=0.2, shuffle=False, callbacks=[callback],
                   batch_size=512)
# Out:
# Train on 380000 samples, validate on 95000 samples
# Epoch 1/1024
# 380000/380000 [==============================] - 7s 19us/sample - loss: 0.0884 - mse: 0.0793 - val_loss: 0.0757 - val_mse: 0.0670
# Epoch 2/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0722 - mse: 0.0637 - val_loss: 0.0690 - val_mse: 0.0608
# Epoch 3/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0677 - mse: 0.0597 - val_loss: 0.0660 - val_mse: 0.0582
# Epoch 4/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0654 - mse: 0.0577 - val_loss: 0.0644 - val_mse: 0.0568
# Epoch 5/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0640 - mse: 0.0565 - val_loss: 0.0632 - val_mse: 0.0558
# Epoch 6/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0629 - mse: 0.0557 - val_loss: 0.0622 - val_mse: 0.0551
# Epoch 7/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0620 - mse: 0.0550 - val_loss: 0.0614 - val_mse: 0.0545
# Epoch 8/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0612 - mse: 0.0544 - val_loss: 0.0607 - val_mse: 0.0540
# Epoch 9/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0605 - mse: 0.0538 - val_loss: 0.0601 - val_mse: 0.0535
# Epoch 10/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0599 - mse: 0.0533 - val_loss: 0.0595 - val_mse: 0.0531
# Epoch 11/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0593 - mse: 0.0529 - val_loss: 0.0590 - val_mse: 0.0527
# Epoch 12/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0588 - mse: 0.0525 - val_loss: 0.0586 - val_mse: 0.0523
# Epoch 13/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0583 - mse: 0.0521 - val_loss: 0.0581 - val_mse: 0.0520
# Epoch 14/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0579 - mse: 0.0518 - val_loss: 0.0578 - val_mse: 0.0518
# Epoch 15/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0575 - mse: 0.0515 - val_loss: 0.0574 - val_mse: 0.0515
# Epoch 16/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0571 - mse: 0.0512 - val_loss: 0.0571 - val_mse: 0.0513
# Epoch 17/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0568 - mse: 0.0510 - val_loss: 0.0568 - val_mse: 0.0511
# Epoch 18/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0564 - mse: 0.0508 - val_loss: 0.0565 - val_mse: 0.0509
# Epoch 19/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0561 - mse: 0.0505 - val_loss: 0.0563 - val_mse: 0.0507
# Epoch 20/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0559 - mse: 0.0503 - val_loss: 0.0561 - val_mse: 0.0506
# Epoch 21/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0556 - mse: 0.0501 - val_loss: 0.0558 - val_mse: 0.0504
# Epoch 22/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0554 - mse: 0.0500 - val_loss: 0.0556 - val_mse: 0.0503
# Epoch 23/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0551 - mse: 0.0498 - val_loss: 0.0554 - val_mse: 0.0501
# Epoch 24/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0549 - mse: 0.0496 - val_loss: 0.0552 - val_mse: 0.0500
# Epoch 25/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0547 - mse: 0.0495 - val_loss: 0.0550 - val_mse: 0.0499
# Epoch 26/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0545 - mse: 0.0493 - val_loss: 0.0549 - val_mse: 0.0498
# Epoch 27/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0542 - mse: 0.0492 - val_loss: 0.0547 - val_mse: 0.0496
# Epoch 28/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0541 - mse: 0.0490 - val_loss: 0.0545 - val_mse: 0.0495
# Epoch 29/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0539 - mse: 0.0489 - val_loss: 0.0544 - val_mse: 0.0494
# Epoch 30/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0537 - mse: 0.0488 - val_loss: 0.0542 - val_mse: 0.0493
# Epoch 31/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0535 - mse: 0.0486 - val_loss: 0.0541 - val_mse: 0.0492
# Epoch 32/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0533 - mse: 0.0485 - val_loss: 0.0539 - val_mse: 0.0491
# Epoch 33/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0532 - mse: 0.0484 - val_loss: 0.0538 - val_mse: 0.0490
# Epoch 34/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0530 - mse: 0.0483 - val_loss: 0.0536 - val_mse: 0.0490
# Epoch 35/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0528 - mse: 0.0482 - val_loss: 0.0535 - val_mse: 0.0489
# Epoch 36/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0527 - mse: 0.0481 - val_loss: 0.0534 - val_mse: 0.0488
# Epoch 37/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0525 - mse: 0.0480 - val_loss: 0.0533 - val_mse: 0.0487
# Epoch 38/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0524 - mse: 0.0479 - val_loss: 0.0532 - val_mse: 0.0486
# Epoch 39/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0523 - mse: 0.0478 - val_loss: 0.0531 - val_mse: 0.0486
# Epoch 40/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0521 - mse: 0.0477 - val_loss: 0.0529 - val_mse: 0.0485
# Epoch 41/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0520 - mse: 0.0476 - val_loss: 0.0528 - val_mse: 0.0484
# Epoch 42/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0519 - mse: 0.0475 - val_loss: 0.0527 - val_mse: 0.0484
# Epoch 43/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0517 - mse: 0.0474 - val_loss: 0.0526 - val_mse: 0.0483
# Epoch 44/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0516 - mse: 0.0473 - val_loss: 0.0525 - val_mse: 0.0483
# Epoch 45/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0515 - mse: 0.0472 - val_loss: 0.0525 - val_mse: 0.0482
# Epoch 46/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0514 - mse: 0.0471 - val_loss: 0.0524 - val_mse: 0.0482
# Epoch 47/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0513 - mse: 0.0471 - val_loss: 0.0523 - val_mse: 0.0481
# Epoch 48/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0512 - mse: 0.0470 - val_loss: 0.0522 - val_mse: 0.0480
# Epoch 49/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0510 - mse: 0.0469 - val_loss: 0.0521 - val_mse: 0.0480
# Epoch 50/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0509 - mse: 0.0468 - val_loss: 0.0520 - val_mse: 0.0479
# Epoch 51/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0508 - mse: 0.0468 - val_loss: 0.0520 - val_mse: 0.0479
# Epoch 52/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0507 - mse: 0.0467 - val_loss: 0.0519 - val_mse: 0.0479
# Epoch 53/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0506 - mse: 0.0466 - val_loss: 0.0518 - val_mse: 0.0478
# Epoch 54/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0505 - mse: 0.0465 - val_loss: 0.0517 - val_mse: 0.0478
# Epoch 55/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0504 - mse: 0.0465 - val_loss: 0.0517 - val_mse: 0.0477
# Epoch 56/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0503 - mse: 0.0464 - val_loss: 0.0516 - val_mse: 0.0477
# Epoch 57/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0502 - mse: 0.0463 - val_loss: 0.0515 - val_mse: 0.0476
# Epoch 58/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0502 - mse: 0.0463 - val_loss: 0.0515 - val_mse: 0.0476
# Epoch 59/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0501 - mse: 0.0462 - val_loss: 0.0514 - val_mse: 0.0476
# Epoch 60/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0500 - mse: 0.0462 - val_loss: 0.0513 - val_mse: 0.0475
# Epoch 61/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0499 - mse: 0.0461 - val_loss: 0.0513 - val_mse: 0.0475
# Epoch 62/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0498 - mse: 0.0460 - val_loss: 0.0512 - val_mse: 0.0475
# Epoch 63/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0497 - mse: 0.0460 - val_loss: 0.0512 - val_mse: 0.0474
# Epoch 64/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0496 - mse: 0.0459 - val_loss: 0.0511 - val_mse: 0.0474
# Epoch 65/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0496 - mse: 0.0459 - val_loss: 0.0511 - val_mse: 0.0474
# Epoch 66/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0495 - mse: 0.0458 - val_loss: 0.0510 - val_mse: 0.0473
# Epoch 67/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0494 - mse: 0.0457 - val_loss: 0.0510 - val_mse: 0.0473
# Epoch 68/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0493 - mse: 0.0457 - val_loss: 0.0509 - val_mse: 0.0473
# Epoch 69/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0493 - mse: 0.0456 - val_loss: 0.0509 - val_mse: 0.0472
# Epoch 70/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0492 - mse: 0.0456 - val_loss: 0.0508 - val_mse: 0.0472
# Epoch 71/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0491 - mse: 0.0455 - val_loss: 0.0508 - val_mse: 0.0472
# Epoch 72/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0490 - mse: 0.0455 - val_loss: 0.0507 - val_mse: 0.0472
# Epoch 73/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0490 - mse: 0.0454 - val_loss: 0.0507 - val_mse: 0.0471
# Epoch 74/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0489 - mse: 0.0454 - val_loss: 0.0506 - val_mse: 0.0471
# Epoch 75/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0488 - mse: 0.0453 - val_loss: 0.0506 - val_mse: 0.0471
# Epoch 76/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0488 - mse: 0.0453 - val_loss: 0.0505 - val_mse: 0.0471
# Epoch 77/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0487 - mse: 0.0452 - val_loss: 0.0505 - val_mse: 0.0470
# Epoch 78/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0486 - mse: 0.0452 - val_loss: 0.0504 - val_mse: 0.0470
# Epoch 79/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0486 - mse: 0.0451 - val_loss: 0.0504 - val_mse: 0.0470
# Epoch 80/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0485 - mse: 0.0451 - val_loss: 0.0504 - val_mse: 0.0470
# Epoch 81/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0484 - mse: 0.0451 - val_loss: 0.0503 - val_mse: 0.0470
# Epoch 82/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0484 - mse: 0.0450 - val_loss: 0.0503 - val_mse: 0.0469
# Epoch 83/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0483 - mse: 0.0450 - val_loss: 0.0503 - val_mse: 0.0469
# Epoch 84/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0482 - mse: 0.0449 - val_loss: 0.0502 - val_mse: 0.0469
# Epoch 85/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0482 - mse: 0.0449 - val_loss: 0.0502 - val_mse: 0.0469
# Epoch 86/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0481 - mse: 0.0448 - val_loss: 0.0502 - val_mse: 0.0469
# Epoch 87/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0481 - mse: 0.0448 - val_loss: 0.0501 - val_mse: 0.0468
# Epoch 88/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0480 - mse: 0.0447 - val_loss: 0.0501 - val_mse: 0.0468
# Epoch 89/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0479 - mse: 0.0447 - val_loss: 0.0501 - val_mse: 0.0468
# Epoch 90/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0479 - mse: 0.0447 - val_loss: 0.0500 - val_mse: 0.0468
# Epoch 91/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0478 - mse: 0.0446 - val_loss: 0.0500 - val_mse: 0.0468
# Epoch 92/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0478 - mse: 0.0446 - val_loss: 0.0500 - val_mse: 0.0468
# Epoch 93/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0477 - mse: 0.0445 - val_loss: 0.0499 - val_mse: 0.0467
# Epoch 94/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0477 - mse: 0.0445 - val_loss: 0.0499 - val_mse: 0.0467
# Epoch 95/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0476 - mse: 0.0445 - val_loss: 0.0499 - val_mse: 0.0467
# Epoch 96/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0476 - mse: 0.0444 - val_loss: 0.0498 - val_mse: 0.0467
# Epoch 97/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0475 - mse: 0.0444 - val_loss: 0.0498 - val_mse: 0.0467
# Epoch 98/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0475 - mse: 0.0443 - val_loss: 0.0498 - val_mse: 0.0467
# Epoch 99/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0474 - mse: 0.0443 - val_loss: 0.0498 - val_mse: 0.0467
# Epoch 100/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0473 - mse: 0.0443 - val_loss: 0.0497 - val_mse: 0.0466
# Epoch 101/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0473 - mse: 0.0442 - val_loss: 0.0497 - val_mse: 0.0466
# Epoch 102/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0472 - mse: 0.0442 - val_loss: 0.0497 - val_mse: 0.0466
# Epoch 103/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0472 - mse: 0.0441 - val_loss: 0.0497 - val_mse: 0.0466
# Epoch 104/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0471 - mse: 0.0441 - val_loss: 0.0496 - val_mse: 0.0466
# Epoch 105/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0471 - mse: 0.0441 - val_loss: 0.0496 - val_mse: 0.0466
# Epoch 106/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0470 - mse: 0.0440 - val_loss: 0.0496 - val_mse: 0.0466
# Epoch 107/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0470 - mse: 0.0440 - val_loss: 0.0496 - val_mse: 0.0466
# Epoch 108/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0470 - mse: 0.0440 - val_loss: 0.0495 - val_mse: 0.0466
# Epoch 109/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0469 - mse: 0.0439 - val_loss: 0.0495 - val_mse: 0.0466
# Epoch 110/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0469 - mse: 0.0439 - val_loss: 0.0495 - val_mse: 0.0465
# Epoch 111/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0468 - mse: 0.0439 - val_loss: 0.0495 - val_mse: 0.0465
# Epoch 112/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0468 - mse: 0.0438 - val_loss: 0.0495 - val_mse: 0.0465
# Epoch 113/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0467 - mse: 0.0438 - val_loss: 0.0494 - val_mse: 0.0465
# Epoch 114/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0467 - mse: 0.0438 - val_loss: 0.0494 - val_mse: 0.0465
# Epoch 115/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0466 - mse: 0.0437 - val_loss: 0.0494 - val_mse: 0.0465
# Epoch 116/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0466 - mse: 0.0437 - val_loss: 0.0494 - val_mse: 0.0465
# Epoch 117/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0465 - mse: 0.0437 - val_loss: 0.0494 - val_mse: 0.0465
# Epoch 118/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0465 - mse: 0.0436 - val_loss: 0.0494 - val_mse: 0.0465
# Epoch 119/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0465 - mse: 0.0436 - val_loss: 0.0493 - val_mse: 0.0465
# Epoch 120/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0464 - mse: 0.0436 - val_loss: 0.0493 - val_mse: 0.0465
# Epoch 121/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0464 - mse: 0.0435 - val_loss: 0.0493 - val_mse: 0.0465
# Epoch 122/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0463 - mse: 0.0435 - val_loss: 0.0493 - val_mse: 0.0465
# Epoch 123/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0463 - mse: 0.0435 - val_loss: 0.0493 - val_mse: 0.0464
# Epoch 124/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0462 - mse: 0.0434 - val_loss: 0.0493 - val_mse: 0.0464
# Epoch 125/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0462 - mse: 0.0434 - val_loss: 0.0492 - val_mse: 0.0464
# Epoch 126/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0462 - mse: 0.0434 - val_loss: 0.0492 - val_mse: 0.0464
# Epoch 127/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0461 - mse: 0.0433 - val_loss: 0.0492 - val_mse: 0.0464
# Epoch 128/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0461 - mse: 0.0433 - val_loss: 0.0492 - val_mse: 0.0464
# Epoch 129/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0460 - mse: 0.0433 - val_loss: 0.0492 - val_mse: 0.0464
# Epoch 130/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0460 - mse: 0.0432 - val_loss: 0.0492 - val_mse: 0.0464
# Epoch 131/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0459 - mse: 0.0432 - val_loss: 0.0491 - val_mse: 0.0464
# Epoch 132/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0459 - mse: 0.0432 - val_loss: 0.0491 - val_mse: 0.0464
# Epoch 133/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0459 - mse: 0.0431 - val_loss: 0.0491 - val_mse: 0.0464
# Epoch 134/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0458 - mse: 0.0431 - val_loss: 0.0491 - val_mse: 0.0464
# Epoch 135/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0458 - mse: 0.0431 - val_loss: 0.0491 - val_mse: 0.0464
# Epoch 136/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0457 - mse: 0.0430 - val_loss: 0.0491 - val_mse: 0.0464
# Epoch 137/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0457 - mse: 0.0430 - val_loss: 0.0491 - val_mse: 0.0464
# Epoch 138/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0457 - mse: 0.0430 - val_loss: 0.0491 - val_mse: 0.0464
# Epoch 139/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0456 - mse: 0.0429 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 140/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0456 - mse: 0.0429 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 141/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0455 - mse: 0.0429 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 142/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0455 - mse: 0.0429 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 143/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0455 - mse: 0.0428 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 144/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0454 - mse: 0.0428 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 145/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0454 - mse: 0.0428 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 146/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0454 - mse: 0.0427 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 147/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0453 - mse: 0.0427 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 148/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0453 - mse: 0.0427 - val_loss: 0.0490 - val_mse: 0.0464
# Epoch 149/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0452 - mse: 0.0426 - val_loss: 0.0489 - val_mse: 0.0464
# Epoch 150/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0452 - mse: 0.0426 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 151/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0452 - mse: 0.0426 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 152/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0451 - mse: 0.0426 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 153/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0451 - mse: 0.0425 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 154/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0451 - mse: 0.0425 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 155/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0450 - mse: 0.0425 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 156/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0450 - mse: 0.0424 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 157/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0450 - mse: 0.0424 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 158/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0449 - mse: 0.0424 - val_loss: 0.0489 - val_mse: 0.0463
# Epoch 159/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0449 - mse: 0.0424 - val_loss: 0.0489 - val_mse: 0.0464
# Epoch 160/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0449 - mse: 0.0423 - val_loss: 0.0489 - val_mse: 0.0464
# Epoch 161/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0448 - mse: 0.0423 - val_loss: 0.0489 - val_mse: 0.0464
# Epoch 162/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0448 - mse: 0.0423 - val_loss: 0.0489 - val_mse: 0.0464
# Epoch 163/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0447 - mse: 0.0422 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 164/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0447 - mse: 0.0422 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 165/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0447 - mse: 0.0422 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 166/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0446 - mse: 0.0422 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 167/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0446 - mse: 0.0421 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 168/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0446 - mse: 0.0421 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 169/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0445 - mse: 0.0421 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 170/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0445 - mse: 0.0421 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 171/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0445 - mse: 0.0420 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 172/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0444 - mse: 0.0420 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 173/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0444 - mse: 0.0420 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 174/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0444 - mse: 0.0419 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 175/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0443 - mse: 0.0419 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 176/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0443 - mse: 0.0419 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 177/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0443 - mse: 0.0419 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 178/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0442 - mse: 0.0418 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 179/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0442 - mse: 0.0418 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 180/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0442 - mse: 0.0418 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 181/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0442 - mse: 0.0418 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 182/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0441 - mse: 0.0417 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 183/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0441 - mse: 0.0417 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 184/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0441 - mse: 0.0417 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 185/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0440 - mse: 0.0417 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 186/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0440 - mse: 0.0416 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 187/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0440 - mse: 0.0416 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 188/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0439 - mse: 0.0416 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 189/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0439 - mse: 0.0416 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 190/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0439 - mse: 0.0415 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 191/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0438 - mse: 0.0415 - val_loss: 0.0488 - val_mse: 0.0464
# Epoch 192/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0438 - mse: 0.0415 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 193/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0438 - mse: 0.0415 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 194/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0437 - mse: 0.0414 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 195/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0437 - mse: 0.0414 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 196/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0437 - mse: 0.0414 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 197/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0437 - mse: 0.0414 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 198/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0436 - mse: 0.0413 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 199/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0436 - mse: 0.0413 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 200/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0436 - mse: 0.0413 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 201/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0435 - mse: 0.0413 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 202/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0435 - mse: 0.0412 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 203/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0435 - mse: 0.0412 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 204/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0434 - mse: 0.0412 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 205/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0434 - mse: 0.0412 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 206/1024
# 380000/380000 [==============================] - 4s 11us/sample - loss: 0.0434 - mse: 0.0411 - val_loss: 0.0488 - val_mse: 0.0465
# Epoch 207/1024
# 380000/380000 [==============================] - 4s 10us/sample - loss: 0.0434 - mse: 0.0411 - val_loss: 0.0488 - val_mse: 0.0465

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('mse loss')
plt.legend()
plt.title('MSE loss')
# Out:
# Text(0.5, 1.0, 'MSE loss')

# %%
class Analysis:
    def __init__(self):
        self.crop = 100
        self.fsize = 6
        self.histogram_bins = 40
        
    def wrap_phi(self, var):
        var = var%(2*np.pi)
        var = var - 2*np.pi*(var > np.pi)
        return var
        
    def predictions_vs_sample(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2, self.fsize*len(names)))
        for i in range(0, len(names)):
            compare_small = compare[:self.crop,i]
            true_small = true[:self.crop,i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            plt.subplot(len(names), 1, i+1)
            plt.plot(range(0,self.crop), compare_small, 'bo', markersize=3, label = 'Predictions')
            plt.plot(range(0,self.crop), true_small, 'ro', markersize=3, label = 'True Value')
            ym, yM = plt.ylim()
            for x in range(self.crop):
                plt.vlines(x, color='g', linestyle='-', alpha=0.2, ymin= 
                            min(compare_small[x], true_small[x]), 
                            ymax= max(compare_small[x], true_small[x]))
            plt.hlines(np.mean(true[:,i]), xmin=-20, xmax=self.crop+20, alpha=0.5)
            MSE = 1/compare[:,i].size*np.sum((compare[:,i]- true[:,i])**2)
            plt.xlabel('Sample')
            plt.xlim(0, self.crop)
            plt.ylabel(names[i])
            plt.title(names[i] + " MSE: " + str(MSE))
            plt.legend()
    
    def display_errors(self, compare, true, names, wrap_phi):
        MSE = 1/compare.size*np.sum((compare- true)**2)
        print("total MSE: " + str(MSE))
        print(" ")
        for i in range(len(names)):
            diff = compare[:,i] -true[:,i]
            if wrap_phi and "phi" in names[i]:
                diff = self.wrap_phi(diff)
            MSE = 1/compare[:,i].size*np.sum((diff)**2)
            print("{0} MSE : ".format(names[i]), '%.10f'%MSE)
    
    def difference_histogram(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            diff = true[:,i] - compare[:,i]
            if wrap_phi and "phi" in names[i]:
                diff = self.wrap_phi(diff)
            # hist0, bin_edges = np.histogram(true[:, i], bins=self.histogram_bins)
            plt.hist(diff, self.histogram_bins, histtype='step', color='purple', label='true - predicted', density=True)
            plt.xlabel("Difference (Mean: {0}, Std: {1})".format(np.mean(diff), np.std(diff)))
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
            
    def variable_histogram(self, compare, true, names, wrap_phi): 
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            compare_small = compare[:, i]
            true_small = true[:, i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            # hist, edges = np.histogram(true_small, self.histogram_bins)
            plt.hist(true_small, self.histogram_bins, histtype='step', color='b', label='true values', density=True)
            plt.hist(compare_small, self.histogram_bins, histtype='step', color='r', label='predictions', density=True)
            plt.xlabel(names[i])
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
    
    def difference_vs_variable(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], true[:, i]-compare[:, i], 'o', color='purple', label='True - Predicted', markersize=2)
            plt.xlabel('True ')
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Difference')
            
    def predicted_vs_true(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], compare[:, i], 'o', color='g', markersize=2)
            line = np.linspace(np.min(true[:, i]), np.max(true[:, i]), 100)
            plt.plot(line, line, color='b')
            plt.xlabel('True')
            plt.title(names[i])
            plt.ylabel('Predicted')

# %%
display = Analysis()

predictions_unscaled = model.predict([testX])
true_unscaled = testY 

total_predictions = model.predict([np.append(trainX,testX,axis=0)])
(Y_total, TO_maxmean0), _ = Scaler.scale_arrays(Y_keys, Y_methods, True)

predictions_origscale = Scaler.invscale_arrays(Y_keys, total_predictions, _, Y_methods, TO_maxmean0)[split:,:]
true_origscale = Scaler.invscale_arrays(Y_keys, Y_total, _, Y_methods, TO_maxmean0)[split:,:]

del Y_total
del TO_maxmean0
del _
del total_predictions

# %% [markdown]
# # Training scale plots

# %%
display.display_errors(predictions_unscaled, true_unscaled, Y_names, False)
# Out:
# total MSE: 0.04715226325045018
#
# th_pt MSE :  0.0162157007
# th_eta MSE :  0.0111194610
# th_phi-sin MSE :  0.1567037146
# th_phi-cos MSE :  0.0666070492
# th_phi-alone MSE :  0.1054401880
# tl_pt MSE :  0.0141381745
# tl_eta MSE :  0.0079968048
# tl_phi-sin MSE :  0.1153123917
# tl_phi-cos MSE :  0.0394049199
# tl_phi-alone MSE :  0.0672900157
# wl_eta MSE :  0.0077938049
# wl_phi-sin MSE :  0.0536515346
# wl_phi-cos MSE :  0.0119686866
# wl_phi-alone MSE :  0.0230939318
# wl_pt MSE :  0.0105475710

# %%
display.predictions_vs_sample(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.variable_histogram(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.difference_histogram(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.predicted_vs_true(predictions_unscaled, true_unscaled, Y_names, False)

# %% [markdown]
#  # Original scale plots

# %%
display.display_errors(predictions_origscale, true_origscale, Y_keys, True)
# Out:
# total MSE: 438.2629692570351
#
# th_pt MSE :  1810.1034590650
# th_eta MSE :  0.6595296569
# th_phi MSE :  0.8704702801
# tl_pt MSE :  1470.4258005151
# tl_eta MSE :  0.5046694652
# tl_phi MSE :  0.5514283649
# wl_eta MSE :  0.3255647834
# wl_phi MSE :  0.2021648450
# wl_pt MSE :  655.2613018371

# %%
display.predictions_vs_sample(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.predictions_vs_sample(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.difference_histogram(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.difference_vs_variable(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.predicted_vs_true(predictions_origscale, true_origscale, Y_keys, True)
