# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers 
import scipy.stats as stats
import os 
import h5py
import sys
import re
# %matplotlib inline

# %%
model_name = "subtract_lepphi_0_2pi"

# %%
# Throw away lepton mass 
# os.chdir('./../../../../../data/hongtao')
be = h5py.File('./../../../../../data/hongtao/variables_tt_re.h5','r')
bmu = h5py.File('./../../../../../data/hongtao/variables_tt_rmu.h5','r')
be1 = h5py.File('./../../../../../data/hongtao/variables_tt_re1.h5','r')
print(be.keys())
print('')
print(be1.keys())
dataset = be1
# Out:
# <KeysViewHDF5 ['j1_eta', 'j1_isbtag', 'j1_m', 'j1_phi', 'j1_pt', 'j2_eta', 'j2_isbtag', 'j2_m', 'j2_phi', 'j2_pt', 'j3_eta', 'j3_isbtag', 'j3_m', 'j3_phi', 'j3_pt', 'j4_eta', 'j4_isbtag', 'j4_m', 'j4_phi', 'j4_pt', 'j5_eta', 'j5_isbtag', 'j5_m', 'j5_phi', 'j5_pt', 'j6_eta', 'j6_isbtag', 'j6_m', 'j6_phi', 'j6_pt', 'j7_eta', 'j7_isbtag', 'j7_m', 'j7_phi', 'j7_pt', 'j8_eta', 'j8_isbtag', 'j8_m', 'j8_phi', 'j8_pt', 'lep_eta', 'lep_m', 'lep_phi', 'lep_pt', 'met_met', 'met_phi', 'mttReco', 'mttTrue']>
#
# <KeysViewHDF5 ['bh_eta', 'bh_phi', 'bh_pt', 'bl_eta', 'bl_phi', 'bl_pt', 'j1_DL1r', 'j1_eta', 'j1_isbtag', 'j1_m', 'j1_phi', 'j1_pt', 'j2_DL1r', 'j2_eta', 'j2_isbtag', 'j2_m', 'j2_phi', 'j2_pt', 'j3_DL1r', 'j3_eta', 'j3_isbtag', 'j3_m', 'j3_phi', 'j3_pt', 'j4_DL1r', 'j4_eta', 'j4_isbtag', 'j4_m', 'j4_phi', 'j4_pt', 'j5_DL1r', 'j5_eta', 'j5_isbtag', 'j5_m', 'j5_phi', 'j5_pt', 'j6_DL1r', 'j6_eta', 'j6_isbtag', 'j6_m', 'j6_phi', 'j6_pt', 'j7_DL1r', 'j7_eta', 'j7_isbtag', 'j7_m', 'j7_phi', 'j7_pt', 'j8_DL1r', 'j8_eta', 'j8_isbtag', 'j8_m', 'j8_phi', 'j8_pt', 'lep_eta', 'lep_m', 'lep_phi', 'lep_pt', 'met_met', 'met_phi', 'mttReco', 'mttTrue', 'th_eta', 'th_phi', 'th_pt', 'tl_eta', 'tl_phi', 'tl_pt', 'wh_eta', 'wh_phi', 'wh_pt', 'wl_eta', 'wl_phi', 'wl_pt']>

# %%
input_keys = ['j1_pt', 'j1_eta', 'j1_phi', 'j1_m', 'j1_DL1r', 'j2_pt', 'j2_eta', 'j2_phi', 'j2_m', 'j2_DL1r', 'j3_pt', 'j3_eta', 'j3_phi', 'j3_m', 'j3_DL1r', 'j4_pt', 'j4_eta', 'j4_phi', 'j4_m', 'j4_DL1r', 'j5_pt', 'j5_eta', 'j5_phi', 'j5_m', 'j5_DL1r', 'j6_pt', 'j6_eta', 'j6_phi', 'j6_m', 'j6_DL1r', 'j7_pt', 'lep_pt', 'lep_eta', 'lep_phi', 'met_met', 'met_phi'] 
output_keys = ['th_pt', 'th_eta','th_phi', 'tl_pt', 'tl_eta', 'tl_phi', 'wl_eta', 'wl_phi', 'wl_pt']
phi_keys = ['j1_phi', 'j2_phi', 'j3_phi','j4_phi','j5_phi','j6_phi', 'lep_phi', 'met_phi', 'th_phi', 'tl_phi', 'wl_phi']
eta_keys = ['j1_eta', 'j2_eta', 'j3_eta', 'j4_eta', 'j5_eta', 'j5_phi', 'j6_eta', 'lep_eta', 'th_eta', 'tl_eta', 'wl_eta']
pt_keys = ['j1_pt', 'j2_pt','j3_pt','j4_pt','j5_pt','j6_pt','lep_pt','th_pt', 'tl_pt', 'wl_pt']
m_keys = ['j1_m','j2_m', 'j3_m', 'j4_m', 'j5_m', 'j6_m']
DL1r_keys = ['j1_DL1r','j2_DL1r','j3_DL1r','j4_DL1r','j5_DL1r','j6_DL1r']

output_length = len(output_keys)
input_length = len(input_keys)
crop0 =  100000

# %%
# plt.figure(figsize=(8,8*output_length))
# for i in range(0, output_length):
#     plt.subplot(output_length, 1, i+1)
#     plt.hist(dataset.get(output_keys[i]), 20, histtype='step')
#     plt.xlabel(output_keys[i])
#     plt.ylabel('Frequency')

# %%
lep_phi = np.array(dataset.get('lep_phi'))[0:crop0]
def phi_transform(arr, max0, mean):
    arr = (arr-mean)
    arr = arr/max0/1.01/2+0.5
    z = stats.norm.ppf(arr)/2.5
    return z 

def invphi_transform(z, max0, mean):
    arr = stats.norm.cdf(2.5*z)
    arr = (arr-0.5)*max0*1.01*2+mean
    return arr 

def jet_existence_dict():
    dic = {}
    for key in phi_keys:
        variable = key.split('_')[0]
        if bool(re.match('^j[0-9]+$', variable)): # If the variable is a jet
            v = np.array(dataset.get(variable + '_pt'))[0:crop0]
            dic[key] = (v>1)*1
        else:
            dic[key] = np.ones(crop0, dtype=int)
    return dic
        
def phi1_transform(arr, max0, mean, exist):
    w = (arr - lep_phi*exist) % (2*np.pi)
    x = w - 2*np.pi*(w>np.pi)
    y = x - (1-exist)*np.pi*1.1
    y = y-mean
    z = y/max0
    return z

def invphi1_transform(z, max0, mean, exist):
    y = z*max0+mean
    x = y+(1-exist)*np.pi*1.1
    w = x + 2*np.pi*(x<0)
    arr = (w + lep_phi*exist) % (2*np.pi)
    arr = arr - 2*np.pi*(arr > np.pi)
    return arr 


def phi2_transform(arr, max0, mean, exist):
    w = (arr - lep_phi*exist) % (2*np.pi)
    # x = w - 2*np.pi*(w>np.pi)
    y = w - (1-exist)*0.2
    z = y/(np.pi)
    return z

def invphi2_transform(z, max0, mean, exist):
    y = z*np.pi
    x = y+(1-exist)*0.2
    # w = x + 2*np.pi*(x<0)
    arr = (x + lep_phi*exist) % (2*np.pi)
    arr = arr - 2*np.pi*(arr > np.pi)
    return arr 


def pt_transform(arr, max0, mean):
    return arr/max0

def invpt_transform(z, max0, mean):
    return z*max0 

def meanmax_transform(arr, max0, mean):
    arr = arr-mean
    z = arr/max0
    return z

def invmeanmax_transform(z, max0, mean):
    return z*max0+mean

def get_maxmean_dict(): 
    to_get = [pt_keys, eta_keys, m_keys, DL1r_keys]
    keys = ['pt', 'eta', 'm','DL1r']
    maxmean= {} 
    
    for i in range(4):
        dset = to_get[i]
        for x in dset:
            arr = []
            arr.append(np.array(dataset.get(x))[0:crop0])
        arr = np.stack(arr,axis=1)
        maxmean[keys[i]] = (np.max(np.abs(arr)), np.mean(arr))
    
    maxmean['phi'] = (np.pi, 0)
    maxmean['met'] = (np.max(np.abs(dataset.get('met_met'))), np.mean(dataset.get('met_met')))
    return maxmean 
    
def scale_arrays(keys, maxmean_dict):
    exist_dict = jet_existence_dict()
    lep_phi = np.array(dataset.get('lep_phi'))[0:crop0]
    
    arrays = []
    for key in keys:
        var = np.array(dataset.get(key))[0:crop0]
        if key in phi_keys:
            max0, mean = maxmean_dict['phi']
            exist = exist_dict[key]
            if False:
                z = phi1_transform(var, max0, mean, exist) 
            else:
                z = phi1_transform(var, max0, mean, exist)
        elif key in pt_keys:
            max0, mean = maxmean_dict['pt']
            z = pt_transform(var, max0, mean)
        elif key in m_keys:
            max0, mean = maxmean_dict['m']
            z = pt_transform(var, max0, mean)
        else:
            max0, mean = maxmean_dict[key.split('_')[1]]
            z = meanmax_transform(var, max0, mean)
        arrays.append(z)
    arrays = np.stack(arrays, axis=1)
    return arrays

def invscale_arrays(keys, arrays, maxmean_dict):
    exist_dict = jet_existence_dict()

    total = []
    for i in range(arrays.shape[1]):
        z=arrays[:,i]
        full_key = keys[i]
        key = keys[i].split('_')[1]
        if key == 'pt':
            max0, mean = maxmean_dict[key]
            total.append(invpt_transform(z, max0, mean))
        elif key=='phi':
            max0, mean = maxmean_dict[key]
            exist = exist_dict[full_key]
            if False:
                total.append(invphi1_transform(z, max0, mean, exist))
            else:
                total.append(invphi1_transform(z, max0, mean, exist))
        elif key=='m':
            max0, mean = maxmean_dict[key]
            total.append(invpt_transform(z, max0, mean))
        else:
            max0, mean = maxmean_dict[key]
            total.append(invmeanmax_transform(z, max0, mean))
            
    return np.stack(total,axis=1)

# %%
# Convert into numpy arrays and mean normalize

maxmean = get_maxmean_dict()
total_input = scale_arrays(input_keys, maxmean)

total_output = scale_arrays(output_keys, maxmean)
out_scaled = invscale_arrays(output_keys, total_output, maxmean)

# %%
# Test inverse scaling

plt.figure(figsize=(8,8*output_length))
for i in range(len(output_keys)):
    plt.subplot(output_length, 1, i+1)
    plt.hist(dataset.get(output_keys[i])[0:crop0] - out_scaled[:, i], 20, histtype='step', color='b')
    plt.xlabel(output_keys[i] + " scaling error")
    plt.ylabel('Frequency')

# %%
# Create input and test array
split = int(np.floor(0.8*crop0)) # 80/20 split 
shuffle = False

if shuffle:
    rng_state = np.random.get_state()
    np.random.shuffle(total_input)
    np.random.set_state(rng_state)
    np.random.shuffle(total_output)

train_input, test_input = total_input[0:split, :], total_input[split:,:]
train_output, test_output = total_output[0:split,:], total_output[split:,:]

# %%
print(train_input.shape, train_output.shape)
print(test_input.shape, test_output.shape)
# Out:
# (80000, 36) (80000, 9)
# (20000, 36) (20000, 9)

# %%
# Histograms of output variables 
show = True

if show:
    plt.figure(figsize=(8,8*output_length))
    for i in range(0, output_length):
        plt.subplot(output_length, 1, i+1)
        plt.hist(train_output[:,i], 20, histtype='step')
        plt.xlabel(output_keys[i])
        plt.ylabel('Frequency')

# %%
# Histograms of input variables 
show = True

if show:
    plt.figure(figsize=(8,8*input_length))
    for i in range(0, input_length):
        plt.subplot(input_length, 1, i+1)
        plt.hist(train_input[:,i], 20, histtype='step')
        plt.xlabel(input_keys[i])
        plt.ylabel('Frequency')

# %%
# Build model

# optimizer = keras.optimizers.RMSprop(learning_rate = 1e-5)
optimizer = keras.optimizers.Adam(learning_rate=1e-6)
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)


def build_model():
    model = keras.Sequential([
        layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0001),
                     input_shape=[len(input_keys)]),
        layers.Dense(256,  activation='relu'),
        layers.Dense(256,  activation='relu'),
        layers.Dense(256,  activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(len(output_keys),  activation='linear')
    ])
    
    model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    return model 

# def build_model():
#     model = keras.Sequential([
#         layers.Dense(6, activation='linear', 
#                      input_shape=[len(input_keys)])])
    
#     model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    
#     return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               18944
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_7 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 348,937
# Trainable params: 348,937
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model

Epochs= 4096

history = model.fit(train_input, train_output, verbose=1, epochs=Epochs, 
                   validation_split=0.2, shuffle=False, callbacks=[callback],
                   batch_size=512)
# Out:
# Epoch 1/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1318 - mse: 0.1251 - val_loss: 0.1304 - val_mse: 0.1236
# Epoch 2/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1301 - mse: 0.1233 - val_loss: 0.1287 - val_mse: 0.1219
# Epoch 3/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1284 - mse: 0.1216 - val_loss: 0.1270 - val_mse: 0.1202
# Epoch 4/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1267 - mse: 0.1199 - val_loss: 0.1253 - val_mse: 0.1186
# Epoch 5/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1250 - mse: 0.1183 - val_loss: 0.1236 - val_mse: 0.1169
# Epoch 6/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1233 - mse: 0.1166 - val_loss: 0.1220 - val_mse: 0.1153
# Epoch 7/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1216 - mse: 0.1149 - val_loss: 0.1203 - val_mse: 0.1136
# Epoch 8/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1200 - mse: 0.1133 - val_loss: 0.1188 - val_mse: 0.1121
# Epoch 9/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1185 - mse: 0.1118 - val_loss: 0.1173 - val_mse: 0.1106
# Epoch 10/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1170 - mse: 0.1104 - val_loss: 0.1159 - val_mse: 0.1092
# Epoch 11/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1157 - mse: 0.1090 - val_loss: 0.1146 - val_mse: 0.1080
# Epoch 12/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1145 - mse: 0.1078 - val_loss: 0.1135 - val_mse: 0.1068
# Epoch 13/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1134 - mse: 0.1068 - val_loss: 0.1125 - val_mse: 0.1058
# Epoch 14/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1124 - mse: 0.1058 - val_loss: 0.1116 - val_mse: 0.1050
# Epoch 15/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1116 - mse: 0.1050 - val_loss: 0.1108 - val_mse: 0.1041
# Epoch 16/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1108 - mse: 0.1042 - val_loss: 0.1100 - val_mse: 0.1034
# Epoch 17/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1101 - mse: 0.1034 - val_loss: 0.1093 - val_mse: 0.1027
# Epoch 18/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1093 - mse: 0.1027 - val_loss: 0.1085 - val_mse: 0.1019
# Epoch 19/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1086 - mse: 0.1020 - val_loss: 0.1078 - val_mse: 0.1012
# Epoch 20/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1078 - mse: 0.1013 - val_loss: 0.1071 - val_mse: 0.1005
# Epoch 21/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1071 - mse: 0.1005 - val_loss: 0.1064 - val_mse: 0.0998
# Epoch 22/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1064 - mse: 0.0998 - val_loss: 0.1057 - val_mse: 0.0991
# Epoch 23/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1057 - mse: 0.0991 - val_loss: 0.1050 - val_mse: 0.0984
# Epoch 24/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1050 - mse: 0.0984 - val_loss: 0.1043 - val_mse: 0.0977
# Epoch 25/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1043 - mse: 0.0977 - val_loss: 0.1036 - val_mse: 0.0970
# Epoch 26/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1036 - mse: 0.0970 - val_loss: 0.1029 - val_mse: 0.0963
# Epoch 27/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1029 - mse: 0.0964 - val_loss: 0.1022 - val_mse: 0.0957
# Epoch 28/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1022 - mse: 0.0957 - val_loss: 0.1015 - val_mse: 0.0950
# Epoch 29/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1015 - mse: 0.0950 - val_loss: 0.1009 - val_mse: 0.0943
# Epoch 30/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1009 - mse: 0.0943 - val_loss: 0.1002 - val_mse: 0.0937
# Epoch 31/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1002 - mse: 0.0937 - val_loss: 0.0995 - val_mse: 0.0930
# Epoch 32/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0995 - mse: 0.0930 - val_loss: 0.0989 - val_mse: 0.0924
# Epoch 33/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0988 - mse: 0.0923 - val_loss: 0.0982 - val_mse: 0.0917
# Epoch 34/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0982 - mse: 0.0917 - val_loss: 0.0976 - val_mse: 0.0911
# Epoch 35/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0975 - mse: 0.0910 - val_loss: 0.0969 - val_mse: 0.0904
# Epoch 36/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0969 - mse: 0.0904 - val_loss: 0.0963 - val_mse: 0.0898
# Epoch 37/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0963 - mse: 0.0898 - val_loss: 0.0957 - val_mse: 0.0892
# Epoch 38/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0957 - mse: 0.0892 - val_loss: 0.0951 - val_mse: 0.0887
# Epoch 39/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0951 - mse: 0.0886 - val_loss: 0.0946 - val_mse: 0.0881
# Epoch 40/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0946 - mse: 0.0881 - val_loss: 0.0941 - val_mse: 0.0876
# Epoch 41/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0940 - mse: 0.0876 - val_loss: 0.0936 - val_mse: 0.0871
# Epoch 42/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0936 - mse: 0.0871 - val_loss: 0.0931 - val_mse: 0.0867
# Epoch 43/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0931 - mse: 0.0867 - val_loss: 0.0927 - val_mse: 0.0863
# Epoch 44/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0927 - mse: 0.0862 - val_loss: 0.0923 - val_mse: 0.0859
# Epoch 45/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0923 - mse: 0.0858 - val_loss: 0.0919 - val_mse: 0.0855
# Epoch 46/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0919 - mse: 0.0855 - val_loss: 0.0916 - val_mse: 0.0852
# Epoch 47/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0916 - mse: 0.0851 - val_loss: 0.0912 - val_mse: 0.0848
# Epoch 48/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0912 - mse: 0.0848 - val_loss: 0.0909 - val_mse: 0.0845
# Epoch 49/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0909 - mse: 0.0845 - val_loss: 0.0907 - val_mse: 0.0843
# Epoch 50/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0907 - mse: 0.0843 - val_loss: 0.0904 - val_mse: 0.0840
# Epoch 51/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0904 - mse: 0.0840 - val_loss: 0.0902 - val_mse: 0.0838
# Epoch 52/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0902 - mse: 0.0838 - val_loss: 0.0899 - val_mse: 0.0836
# Epoch 53/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0899 - mse: 0.0835 - val_loss: 0.0897 - val_mse: 0.0833
# Epoch 54/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0897 - mse: 0.0833 - val_loss: 0.0895 - val_mse: 0.0831
# Epoch 55/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0895 - mse: 0.0831 - val_loss: 0.0893 - val_mse: 0.0830
# Epoch 56/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0893 - mse: 0.0829 - val_loss: 0.0891 - val_mse: 0.0828
# Epoch 57/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0891 - mse: 0.0827 - val_loss: 0.0889 - val_mse: 0.0826
# Epoch 58/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0889 - mse: 0.0826 - val_loss: 0.0888 - val_mse: 0.0824
# Epoch 59/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0887 - mse: 0.0824 - val_loss: 0.0886 - val_mse: 0.0823
# Epoch 60/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0885 - mse: 0.0822 - val_loss: 0.0884 - val_mse: 0.0821
# Epoch 61/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0884 - mse: 0.0820 - val_loss: 0.0883 - val_mse: 0.0819
# Epoch 62/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0882 - mse: 0.0819 - val_loss: 0.0881 - val_mse: 0.0818
# Epoch 63/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0880 - mse: 0.0817 - val_loss: 0.0879 - val_mse: 0.0816
# Epoch 64/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0879 - mse: 0.0816 - val_loss: 0.0878 - val_mse: 0.0815
# Epoch 65/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0877 - mse: 0.0814 - val_loss: 0.0876 - val_mse: 0.0813
# Epoch 66/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0876 - mse: 0.0813 - val_loss: 0.0875 - val_mse: 0.0812
# Epoch 67/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0874 - mse: 0.0811 - val_loss: 0.0873 - val_mse: 0.0811
# Epoch 68/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0873 - mse: 0.0810 - val_loss: 0.0872 - val_mse: 0.0809
# Epoch 69/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0871 - mse: 0.0808 - val_loss: 0.0871 - val_mse: 0.0808
# Epoch 70/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0870 - mse: 0.0807 - val_loss: 0.0869 - val_mse: 0.0806
# Epoch 71/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0868 - mse: 0.0806 - val_loss: 0.0868 - val_mse: 0.0805
# Epoch 72/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0867 - mse: 0.0804 - val_loss: 0.0866 - val_mse: 0.0804
# Epoch 73/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0866 - mse: 0.0803 - val_loss: 0.0865 - val_mse: 0.0802
# Epoch 74/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0864 - mse: 0.0802 - val_loss: 0.0864 - val_mse: 0.0801
# Epoch 75/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0863 - mse: 0.0800 - val_loss: 0.0862 - val_mse: 0.0800
# Epoch 76/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0861 - mse: 0.0799 - val_loss: 0.0861 - val_mse: 0.0799
# Epoch 77/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0860 - mse: 0.0798 - val_loss: 0.0860 - val_mse: 0.0797
# Epoch 78/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0859 - mse: 0.0796 - val_loss: 0.0858 - val_mse: 0.0796
# Epoch 79/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0857 - mse: 0.0795 - val_loss: 0.0857 - val_mse: 0.0795
# Epoch 80/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0856 - mse: 0.0794 - val_loss: 0.0856 - val_mse: 0.0794
# Epoch 81/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0855 - mse: 0.0792 - val_loss: 0.0854 - val_mse: 0.0792
# Epoch 82/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0853 - mse: 0.0791 - val_loss: 0.0853 - val_mse: 0.0791
# Epoch 83/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0852 - mse: 0.0790 - val_loss: 0.0852 - val_mse: 0.0790
# Epoch 84/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0851 - mse: 0.0789 - val_loss: 0.0851 - val_mse: 0.0789
# Epoch 85/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0849 - mse: 0.0787 - val_loss: 0.0849 - val_mse: 0.0788
# Epoch 86/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0848 - mse: 0.0786 - val_loss: 0.0848 - val_mse: 0.0786
# Epoch 87/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0847 - mse: 0.0785 - val_loss: 0.0847 - val_mse: 0.0785
# Epoch 88/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0846 - mse: 0.0784 - val_loss: 0.0846 - val_mse: 0.0784
# Epoch 89/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0844 - mse: 0.0783 - val_loss: 0.0845 - val_mse: 0.0783
# Epoch 90/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0843 - mse: 0.0782 - val_loss: 0.0844 - val_mse: 0.0782
# Epoch 91/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0842 - mse: 0.0780 - val_loss: 0.0842 - val_mse: 0.0781
# Epoch 92/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0841 - mse: 0.0779 - val_loss: 0.0841 - val_mse: 0.0780
# Epoch 93/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0840 - mse: 0.0778 - val_loss: 0.0840 - val_mse: 0.0779
# Epoch 94/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0839 - mse: 0.0777 - val_loss: 0.0839 - val_mse: 0.0778
# Epoch 95/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0838 - mse: 0.0776 - val_loss: 0.0838 - val_mse: 0.0777
# Epoch 96/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0837 - mse: 0.0775 - val_loss: 0.0837 - val_mse: 0.0776
# Epoch 97/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0836 - mse: 0.0774 - val_loss: 0.0836 - val_mse: 0.0775
# Epoch 98/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0835 - mse: 0.0773 - val_loss: 0.0835 - val_mse: 0.0774
# Epoch 99/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0834 - mse: 0.0772 - val_loss: 0.0834 - val_mse: 0.0773
# Epoch 100/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0833 - mse: 0.0771 - val_loss: 0.0834 - val_mse: 0.0772
# Epoch 101/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0832 - mse: 0.0771 - val_loss: 0.0833 - val_mse: 0.0772
# Epoch 102/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0831 - mse: 0.0770 - val_loss: 0.0832 - val_mse: 0.0771
# Epoch 103/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0830 - mse: 0.0769 - val_loss: 0.0831 - val_mse: 0.0770
# Epoch 104/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0829 - mse: 0.0768 - val_loss: 0.0830 - val_mse: 0.0769
# Epoch 105/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0829 - mse: 0.0768 - val_loss: 0.0830 - val_mse: 0.0769
# Epoch 106/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0828 - mse: 0.0767 - val_loss: 0.0829 - val_mse: 0.0768
# Epoch 107/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0827 - mse: 0.0766 - val_loss: 0.0828 - val_mse: 0.0767
# Epoch 108/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0826 - mse: 0.0766 - val_loss: 0.0828 - val_mse: 0.0767
# Epoch 109/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0826 - mse: 0.0765 - val_loss: 0.0827 - val_mse: 0.0766
# Epoch 110/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0825 - mse: 0.0764 - val_loss: 0.0826 - val_mse: 0.0766
# Epoch 111/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0824 - mse: 0.0764 - val_loss: 0.0826 - val_mse: 0.0765
# Epoch 112/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0824 - mse: 0.0763 - val_loss: 0.0825 - val_mse: 0.0765
# Epoch 113/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0823 - mse: 0.0763 - val_loss: 0.0825 - val_mse: 0.0764
# Epoch 114/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0823 - mse: 0.0762 - val_loss: 0.0824 - val_mse: 0.0764
# Epoch 115/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0822 - mse: 0.0762 - val_loss: 0.0824 - val_mse: 0.0763
# Epoch 116/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0821 - mse: 0.0761 - val_loss: 0.0823 - val_mse: 0.0763
# Epoch 117/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0821 - mse: 0.0761 - val_loss: 0.0823 - val_mse: 0.0762
# Epoch 118/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0820 - mse: 0.0760 - val_loss: 0.0822 - val_mse: 0.0762
# Epoch 119/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0820 - mse: 0.0760 - val_loss: 0.0822 - val_mse: 0.0761
# Epoch 120/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0819 - mse: 0.0759 - val_loss: 0.0821 - val_mse: 0.0761
# Epoch 121/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0819 - mse: 0.0759 - val_loss: 0.0821 - val_mse: 0.0761
# Epoch 122/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0818 - mse: 0.0758 - val_loss: 0.0820 - val_mse: 0.0760
# Epoch 123/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0818 - mse: 0.0758 - val_loss: 0.0820 - val_mse: 0.0760
# Epoch 124/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0818 - mse: 0.0757 - val_loss: 0.0820 - val_mse: 0.0760
# Epoch 125/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0817 - mse: 0.0757 - val_loss: 0.0819 - val_mse: 0.0759
# Epoch 126/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0817 - mse: 0.0757 - val_loss: 0.0819 - val_mse: 0.0759
# Epoch 127/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0816 - mse: 0.0756 - val_loss: 0.0818 - val_mse: 0.0759
# Epoch 128/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0816 - mse: 0.0756 - val_loss: 0.0818 - val_mse: 0.0758
# Epoch 129/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0815 - mse: 0.0756 - val_loss: 0.0818 - val_mse: 0.0758
# Epoch 130/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0815 - mse: 0.0755 - val_loss: 0.0817 - val_mse: 0.0758
# Epoch 131/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0815 - mse: 0.0755 - val_loss: 0.0817 - val_mse: 0.0757
# Epoch 132/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0814 - mse: 0.0754 - val_loss: 0.0817 - val_mse: 0.0757
# Epoch 133/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0814 - mse: 0.0754 - val_loss: 0.0816 - val_mse: 0.0757
# Epoch 134/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0813 - mse: 0.0754 - val_loss: 0.0816 - val_mse: 0.0756
# Epoch 135/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0813 - mse: 0.0753 - val_loss: 0.0816 - val_mse: 0.0756
# Epoch 136/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0813 - mse: 0.0753 - val_loss: 0.0815 - val_mse: 0.0756
# Epoch 137/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0812 - mse: 0.0753 - val_loss: 0.0815 - val_mse: 0.0755
# Epoch 138/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0812 - mse: 0.0752 - val_loss: 0.0815 - val_mse: 0.0755
# Epoch 139/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0811 - mse: 0.0752 - val_loss: 0.0814 - val_mse: 0.0755
# Epoch 140/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0811 - mse: 0.0752 - val_loss: 0.0814 - val_mse: 0.0755
# Epoch 141/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0811 - mse: 0.0751 - val_loss: 0.0814 - val_mse: 0.0754
# Epoch 142/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0810 - mse: 0.0751 - val_loss: 0.0813 - val_mse: 0.0754
# Epoch 143/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0810 - mse: 0.0751 - val_loss: 0.0813 - val_mse: 0.0754
# Epoch 144/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0810 - mse: 0.0750 - val_loss: 0.0813 - val_mse: 0.0753
# Epoch 145/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0809 - mse: 0.0750 - val_loss: 0.0812 - val_mse: 0.0753
# Epoch 146/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0809 - mse: 0.0750 - val_loss: 0.0812 - val_mse: 0.0753
# Epoch 147/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0809 - mse: 0.0750 - val_loss: 0.0812 - val_mse: 0.0753
# Epoch 148/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0808 - mse: 0.0749 - val_loss: 0.0811 - val_mse: 0.0752
# Epoch 149/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0808 - mse: 0.0749 - val_loss: 0.0811 - val_mse: 0.0752
# Epoch 150/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0808 - mse: 0.0749 - val_loss: 0.0811 - val_mse: 0.0752
# Epoch 151/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0807 - mse: 0.0748 - val_loss: 0.0810 - val_mse: 0.0752
# Epoch 152/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0807 - mse: 0.0748 - val_loss: 0.0810 - val_mse: 0.0751
# Epoch 153/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0807 - mse: 0.0748 - val_loss: 0.0810 - val_mse: 0.0751
# Epoch 154/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0806 - mse: 0.0747 - val_loss: 0.0810 - val_mse: 0.0751
# Epoch 155/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0806 - mse: 0.0747 - val_loss: 0.0809 - val_mse: 0.0751
# Epoch 156/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0806 - mse: 0.0747 - val_loss: 0.0809 - val_mse: 0.0750
# Epoch 157/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0805 - mse: 0.0747 - val_loss: 0.0809 - val_mse: 0.0750
# Epoch 158/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0805 - mse: 0.0746 - val_loss: 0.0808 - val_mse: 0.0750
# Epoch 159/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0805 - mse: 0.0746 - val_loss: 0.0808 - val_mse: 0.0750
# Epoch 160/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0804 - mse: 0.0746 - val_loss: 0.0808 - val_mse: 0.0749
# Epoch 161/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0804 - mse: 0.0745 - val_loss: 0.0808 - val_mse: 0.0749
# Epoch 162/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0804 - mse: 0.0745 - val_loss: 0.0807 - val_mse: 0.0749
# Epoch 163/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0803 - mse: 0.0745 - val_loss: 0.0807 - val_mse: 0.0749
# Epoch 164/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0803 - mse: 0.0745 - val_loss: 0.0807 - val_mse: 0.0748
# Epoch 165/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0803 - mse: 0.0744 - val_loss: 0.0806 - val_mse: 0.0748
# Epoch 166/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0802 - mse: 0.0744 - val_loss: 0.0806 - val_mse: 0.0748
# Epoch 167/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0802 - mse: 0.0744 - val_loss: 0.0806 - val_mse: 0.0748
# Epoch 168/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0802 - mse: 0.0744 - val_loss: 0.0806 - val_mse: 0.0747
# Epoch 169/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0801 - mse: 0.0743 - val_loss: 0.0805 - val_mse: 0.0747
# Epoch 170/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0801 - mse: 0.0743 - val_loss: 0.0805 - val_mse: 0.0747
# Epoch 171/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0801 - mse: 0.0743 - val_loss: 0.0805 - val_mse: 0.0747
# Epoch 172/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0800 - mse: 0.0742 - val_loss: 0.0804 - val_mse: 0.0746
# Epoch 173/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0800 - mse: 0.0742 - val_loss: 0.0804 - val_mse: 0.0746
# Epoch 174/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0800 - mse: 0.0742 - val_loss: 0.0804 - val_mse: 0.0746
# Epoch 175/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0800 - mse: 0.0742 - val_loss: 0.0804 - val_mse: 0.0746
# Epoch 176/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0799 - mse: 0.0741 - val_loss: 0.0803 - val_mse: 0.0746
# Epoch 177/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0799 - mse: 0.0741 - val_loss: 0.0803 - val_mse: 0.0745
# Epoch 178/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0799 - mse: 0.0741 - val_loss: 0.0803 - val_mse: 0.0745
# Epoch 179/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0798 - mse: 0.0741 - val_loss: 0.0803 - val_mse: 0.0745
# Epoch 180/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0798 - mse: 0.0740 - val_loss: 0.0802 - val_mse: 0.0745
# Epoch 181/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0798 - mse: 0.0740 - val_loss: 0.0802 - val_mse: 0.0744
# Epoch 182/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0797 - mse: 0.0740 - val_loss: 0.0802 - val_mse: 0.0744
# Epoch 183/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0797 - mse: 0.0740 - val_loss: 0.0802 - val_mse: 0.0744
# Epoch 184/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0797 - mse: 0.0739 - val_loss: 0.0801 - val_mse: 0.0744
# Epoch 185/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0797 - mse: 0.0739 - val_loss: 0.0801 - val_mse: 0.0744
# Epoch 186/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0796 - mse: 0.0739 - val_loss: 0.0801 - val_mse: 0.0743
# Epoch 187/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0796 - mse: 0.0739 - val_loss: 0.0801 - val_mse: 0.0743
# Epoch 188/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0796 - mse: 0.0738 - val_loss: 0.0800 - val_mse: 0.0743
# Epoch 189/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0795 - mse: 0.0738 - val_loss: 0.0800 - val_mse: 0.0743
# Epoch 190/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0795 - mse: 0.0738 - val_loss: 0.0800 - val_mse: 0.0743
# Epoch 191/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0795 - mse: 0.0738 - val_loss: 0.0800 - val_mse: 0.0742
# Epoch 192/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0795 - mse: 0.0737 - val_loss: 0.0799 - val_mse: 0.0742
# Epoch 193/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0794 - mse: 0.0737 - val_loss: 0.0799 - val_mse: 0.0742
# Epoch 194/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0794 - mse: 0.0737 - val_loss: 0.0799 - val_mse: 0.0742
# Epoch 195/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0794 - mse: 0.0737 - val_loss: 0.0799 - val_mse: 0.0742
# Epoch 196/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0794 - mse: 0.0737 - val_loss: 0.0798 - val_mse: 0.0741
# Epoch 197/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0793 - mse: 0.0736 - val_loss: 0.0798 - val_mse: 0.0741
# Epoch 198/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0793 - mse: 0.0736 - val_loss: 0.0798 - val_mse: 0.0741
# Epoch 199/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0793 - mse: 0.0736 - val_loss: 0.0798 - val_mse: 0.0741
# Epoch 200/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0792 - mse: 0.0736 - val_loss: 0.0797 - val_mse: 0.0741
# Epoch 201/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0792 - mse: 0.0735 - val_loss: 0.0797 - val_mse: 0.0740
# Epoch 202/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0792 - mse: 0.0735 - val_loss: 0.0797 - val_mse: 0.0740
# Epoch 203/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0792 - mse: 0.0735 - val_loss: 0.0797 - val_mse: 0.0740
# Epoch 204/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0791 - mse: 0.0735 - val_loss: 0.0796 - val_mse: 0.0740
# Epoch 205/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0791 - mse: 0.0734 - val_loss: 0.0796 - val_mse: 0.0740
# Epoch 206/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0791 - mse: 0.0734 - val_loss: 0.0796 - val_mse: 0.0739
# Epoch 207/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0791 - mse: 0.0734 - val_loss: 0.0796 - val_mse: 0.0739
# Epoch 208/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0790 - mse: 0.0734 - val_loss: 0.0796 - val_mse: 0.0739
# Epoch 209/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0790 - mse: 0.0733 - val_loss: 0.0795 - val_mse: 0.0739
# Epoch 210/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0790 - mse: 0.0733 - val_loss: 0.0795 - val_mse: 0.0739
# Epoch 211/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0790 - mse: 0.0733 - val_loss: 0.0795 - val_mse: 0.0738
# Epoch 212/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0789 - mse: 0.0733 - val_loss: 0.0795 - val_mse: 0.0738
# Epoch 213/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0789 - mse: 0.0733 - val_loss: 0.0794 - val_mse: 0.0738
# Epoch 214/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0789 - mse: 0.0732 - val_loss: 0.0794 - val_mse: 0.0738
# Epoch 215/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0788 - mse: 0.0732 - val_loss: 0.0794 - val_mse: 0.0738
# Epoch 216/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0788 - mse: 0.0732 - val_loss: 0.0794 - val_mse: 0.0737
# Epoch 217/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0788 - mse: 0.0732 - val_loss: 0.0794 - val_mse: 0.0737
# Epoch 218/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0788 - mse: 0.0731 - val_loss: 0.0793 - val_mse: 0.0737
# Epoch 219/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0787 - mse: 0.0731 - val_loss: 0.0793 - val_mse: 0.0737
# Epoch 220/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0787 - mse: 0.0731 - val_loss: 0.0793 - val_mse: 0.0737
# Epoch 221/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0787 - mse: 0.0731 - val_loss: 0.0793 - val_mse: 0.0737
# Epoch 222/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0787 - mse: 0.0731 - val_loss: 0.0792 - val_mse: 0.0736
# Epoch 223/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0786 - mse: 0.0730 - val_loss: 0.0792 - val_mse: 0.0736
# Epoch 224/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0786 - mse: 0.0730 - val_loss: 0.0792 - val_mse: 0.0736
# Epoch 225/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0786 - mse: 0.0730 - val_loss: 0.0792 - val_mse: 0.0736
# Epoch 226/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0786 - mse: 0.0730 - val_loss: 0.0792 - val_mse: 0.0736
# Epoch 227/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0785 - mse: 0.0729 - val_loss: 0.0791 - val_mse: 0.0735
# Epoch 228/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0785 - mse: 0.0729 - val_loss: 0.0791 - val_mse: 0.0735
# Epoch 229/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0785 - mse: 0.0729 - val_loss: 0.0791 - val_mse: 0.0735
# Epoch 230/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0785 - mse: 0.0729 - val_loss: 0.0791 - val_mse: 0.0735
# Epoch 231/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0784 - mse: 0.0729 - val_loss: 0.0791 - val_mse: 0.0735
# Epoch 232/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0784 - mse: 0.0728 - val_loss: 0.0790 - val_mse: 0.0735
# Epoch 233/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0784 - mse: 0.0728 - val_loss: 0.0790 - val_mse: 0.0734
# Epoch 234/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0784 - mse: 0.0728 - val_loss: 0.0790 - val_mse: 0.0734
# Epoch 235/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0783 - mse: 0.0728 - val_loss: 0.0790 - val_mse: 0.0734
# Epoch 236/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0783 - mse: 0.0728 - val_loss: 0.0790 - val_mse: 0.0734
# Epoch 237/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0783 - mse: 0.0727 - val_loss: 0.0789 - val_mse: 0.0734
# Epoch 238/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0783 - mse: 0.0727 - val_loss: 0.0789 - val_mse: 0.0734
# Epoch 239/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0782 - mse: 0.0727 - val_loss: 0.0789 - val_mse: 0.0733
# Epoch 240/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0782 - mse: 0.0727 - val_loss: 0.0789 - val_mse: 0.0733
# Epoch 241/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0782 - mse: 0.0727 - val_loss: 0.0788 - val_mse: 0.0733
# Epoch 242/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0782 - mse: 0.0726 - val_loss: 0.0788 - val_mse: 0.0733
# Epoch 243/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0782 - mse: 0.0726 - val_loss: 0.0788 - val_mse: 0.0733
# Epoch 244/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0781 - mse: 0.0726 - val_loss: 0.0788 - val_mse: 0.0733
# Epoch 245/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0781 - mse: 0.0726 - val_loss: 0.0788 - val_mse: 0.0732
# Epoch 246/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0781 - mse: 0.0725 - val_loss: 0.0787 - val_mse: 0.0732
# Epoch 247/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0781 - mse: 0.0725 - val_loss: 0.0787 - val_mse: 0.0732
# Epoch 248/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0780 - mse: 0.0725 - val_loss: 0.0787 - val_mse: 0.0732
# Epoch 249/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0780 - mse: 0.0725 - val_loss: 0.0787 - val_mse: 0.0732
# Epoch 250/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0780 - mse: 0.0725 - val_loss: 0.0787 - val_mse: 0.0731
# Epoch 251/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0780 - mse: 0.0724 - val_loss: 0.0786 - val_mse: 0.0731
# Epoch 252/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0779 - mse: 0.0724 - val_loss: 0.0786 - val_mse: 0.0731
# Epoch 253/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0779 - mse: 0.0724 - val_loss: 0.0786 - val_mse: 0.0731
# Epoch 254/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0779 - mse: 0.0724 - val_loss: 0.0786 - val_mse: 0.0731
# Epoch 255/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0779 - mse: 0.0724 - val_loss: 0.0786 - val_mse: 0.0731
# Epoch 256/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0778 - mse: 0.0723 - val_loss: 0.0785 - val_mse: 0.0730
# Epoch 257/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0778 - mse: 0.0723 - val_loss: 0.0785 - val_mse: 0.0730
# Epoch 258/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0778 - mse: 0.0723 - val_loss: 0.0785 - val_mse: 0.0730
# Epoch 259/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0778 - mse: 0.0723 - val_loss: 0.0785 - val_mse: 0.0730
# Epoch 260/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0777 - mse: 0.0723 - val_loss: 0.0785 - val_mse: 0.0730
# Epoch 261/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0777 - mse: 0.0722 - val_loss: 0.0785 - val_mse: 0.0730
# Epoch 262/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0777 - mse: 0.0722 - val_loss: 0.0784 - val_mse: 0.0729
# Epoch 263/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0777 - mse: 0.0722 - val_loss: 0.0784 - val_mse: 0.0729
# Epoch 264/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0777 - mse: 0.0722 - val_loss: 0.0784 - val_mse: 0.0729
# Epoch 265/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0776 - mse: 0.0722 - val_loss: 0.0784 - val_mse: 0.0729
# Epoch 266/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0776 - mse: 0.0721 - val_loss: 0.0784 - val_mse: 0.0729
# Epoch 267/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0776 - mse: 0.0721 - val_loss: 0.0783 - val_mse: 0.0729
# Epoch 268/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0776 - mse: 0.0721 - val_loss: 0.0783 - val_mse: 0.0729
# Epoch 269/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0775 - mse: 0.0721 - val_loss: 0.0783 - val_mse: 0.0728
# Epoch 270/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0775 - mse: 0.0721 - val_loss: 0.0783 - val_mse: 0.0728
# Epoch 271/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0775 - mse: 0.0720 - val_loss: 0.0783 - val_mse: 0.0728
# Epoch 272/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0775 - mse: 0.0720 - val_loss: 0.0782 - val_mse: 0.0728
# Epoch 273/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0774 - mse: 0.0720 - val_loss: 0.0782 - val_mse: 0.0728
# Epoch 274/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0774 - mse: 0.0720 - val_loss: 0.0782 - val_mse: 0.0728
# Epoch 275/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0774 - mse: 0.0720 - val_loss: 0.0782 - val_mse: 0.0727
# Epoch 276/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0774 - mse: 0.0719 - val_loss: 0.0782 - val_mse: 0.0727
# Epoch 277/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0774 - mse: 0.0719 - val_loss: 0.0781 - val_mse: 0.0727
# Epoch 278/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0773 - mse: 0.0719 - val_loss: 0.0781 - val_mse: 0.0727
# Epoch 279/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0773 - mse: 0.0719 - val_loss: 0.0781 - val_mse: 0.0727
# Epoch 280/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0773 - mse: 0.0719 - val_loss: 0.0781 - val_mse: 0.0727
# Epoch 281/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0773 - mse: 0.0718 - val_loss: 0.0781 - val_mse: 0.0726
# Epoch 282/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0772 - mse: 0.0718 - val_loss: 0.0781 - val_mse: 0.0726
# Epoch 283/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0772 - mse: 0.0718 - val_loss: 0.0780 - val_mse: 0.0726
# Epoch 284/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0772 - mse: 0.0718 - val_loss: 0.0780 - val_mse: 0.0726
# Epoch 285/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0772 - mse: 0.0718 - val_loss: 0.0780 - val_mse: 0.0726
# Epoch 286/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0772 - mse: 0.0717 - val_loss: 0.0780 - val_mse: 0.0726
# Epoch 287/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0771 - mse: 0.0717 - val_loss: 0.0780 - val_mse: 0.0726
# Epoch 288/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0771 - mse: 0.0717 - val_loss: 0.0779 - val_mse: 0.0725
# Epoch 289/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0771 - mse: 0.0717 - val_loss: 0.0779 - val_mse: 0.0725
# Epoch 290/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0771 - mse: 0.0717 - val_loss: 0.0779 - val_mse: 0.0725
# Epoch 291/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0770 - mse: 0.0716 - val_loss: 0.0779 - val_mse: 0.0725
# Epoch 292/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0770 - mse: 0.0716 - val_loss: 0.0779 - val_mse: 0.0725
# Epoch 293/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0770 - mse: 0.0716 - val_loss: 0.0779 - val_mse: 0.0725
# Epoch 294/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0770 - mse: 0.0716 - val_loss: 0.0778 - val_mse: 0.0724
# Epoch 295/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0770 - mse: 0.0716 - val_loss: 0.0778 - val_mse: 0.0724
# Epoch 296/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0769 - mse: 0.0716 - val_loss: 0.0778 - val_mse: 0.0724
# Epoch 297/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0769 - mse: 0.0715 - val_loss: 0.0778 - val_mse: 0.0724
# Epoch 298/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0769 - mse: 0.0715 - val_loss: 0.0778 - val_mse: 0.0724
# Epoch 299/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0769 - mse: 0.0715 - val_loss: 0.0778 - val_mse: 0.0724
# Epoch 300/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0769 - mse: 0.0715 - val_loss: 0.0777 - val_mse: 0.0724
# Epoch 301/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0768 - mse: 0.0715 - val_loss: 0.0777 - val_mse: 0.0723
# Epoch 302/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0768 - mse: 0.0714 - val_loss: 0.0777 - val_mse: 0.0723
# Epoch 303/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0768 - mse: 0.0714 - val_loss: 0.0777 - val_mse: 0.0723
# Epoch 304/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0768 - mse: 0.0714 - val_loss: 0.0777 - val_mse: 0.0723
# Epoch 305/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0767 - mse: 0.0714 - val_loss: 0.0776 - val_mse: 0.0723
# Epoch 306/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0767 - mse: 0.0714 - val_loss: 0.0776 - val_mse: 0.0723
# Epoch 307/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0767 - mse: 0.0713 - val_loss: 0.0776 - val_mse: 0.0723
# Epoch 308/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0767 - mse: 0.0713 - val_loss: 0.0776 - val_mse: 0.0722
# Epoch 309/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0767 - mse: 0.0713 - val_loss: 0.0776 - val_mse: 0.0722
# Epoch 310/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0766 - mse: 0.0713 - val_loss: 0.0776 - val_mse: 0.0722
# Epoch 311/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0766 - mse: 0.0713 - val_loss: 0.0775 - val_mse: 0.0722
# Epoch 312/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0766 - mse: 0.0713 - val_loss: 0.0775 - val_mse: 0.0722
# Epoch 313/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0766 - mse: 0.0712 - val_loss: 0.0775 - val_mse: 0.0722
# Epoch 314/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0766 - mse: 0.0712 - val_loss: 0.0775 - val_mse: 0.0722
# Epoch 315/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0765 - mse: 0.0712 - val_loss: 0.0775 - val_mse: 0.0721
# Epoch 316/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0765 - mse: 0.0712 - val_loss: 0.0775 - val_mse: 0.0721
# Epoch 317/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0765 - mse: 0.0712 - val_loss: 0.0774 - val_mse: 0.0721
# Epoch 318/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0765 - mse: 0.0711 - val_loss: 0.0774 - val_mse: 0.0721
# Epoch 319/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0764 - mse: 0.0711 - val_loss: 0.0774 - val_mse: 0.0721
# Epoch 320/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0764 - mse: 0.0711 - val_loss: 0.0774 - val_mse: 0.0721
# Epoch 321/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0764 - mse: 0.0711 - val_loss: 0.0774 - val_mse: 0.0721
# Epoch 322/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0764 - mse: 0.0711 - val_loss: 0.0774 - val_mse: 0.0720
# Epoch 323/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0764 - mse: 0.0710 - val_loss: 0.0773 - val_mse: 0.0720
# Epoch 324/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0763 - mse: 0.0710 - val_loss: 0.0773 - val_mse: 0.0720
# Epoch 325/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0763 - mse: 0.0710 - val_loss: 0.0773 - val_mse: 0.0720
# Epoch 326/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0763 - mse: 0.0710 - val_loss: 0.0773 - val_mse: 0.0720
# Epoch 327/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0763 - mse: 0.0710 - val_loss: 0.0773 - val_mse: 0.0720
# Epoch 328/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0763 - mse: 0.0710 - val_loss: 0.0773 - val_mse: 0.0720
# Epoch 329/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0762 - mse: 0.0709 - val_loss: 0.0772 - val_mse: 0.0719
# Epoch 330/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0762 - mse: 0.0709 - val_loss: 0.0772 - val_mse: 0.0719
# Epoch 331/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0762 - mse: 0.0709 - val_loss: 0.0772 - val_mse: 0.0719
# Epoch 332/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0762 - mse: 0.0709 - val_loss: 0.0772 - val_mse: 0.0719
# Epoch 333/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0762 - mse: 0.0709 - val_loss: 0.0772 - val_mse: 0.0719
# Epoch 334/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0761 - mse: 0.0709 - val_loss: 0.0772 - val_mse: 0.0719
# Epoch 335/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0761 - mse: 0.0708 - val_loss: 0.0771 - val_mse: 0.0719
# Epoch 336/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0761 - mse: 0.0708 - val_loss: 0.0771 - val_mse: 0.0718
# Epoch 337/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0761 - mse: 0.0708 - val_loss: 0.0771 - val_mse: 0.0718
# Epoch 338/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0761 - mse: 0.0708 - val_loss: 0.0771 - val_mse: 0.0718
# Epoch 339/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0760 - mse: 0.0708 - val_loss: 0.0771 - val_mse: 0.0718
# Epoch 340/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0760 - mse: 0.0707 - val_loss: 0.0771 - val_mse: 0.0718
# Epoch 341/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0760 - mse: 0.0707 - val_loss: 0.0770 - val_mse: 0.0718
# Epoch 342/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0760 - mse: 0.0707 - val_loss: 0.0770 - val_mse: 0.0718
# Epoch 343/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0760 - mse: 0.0707 - val_loss: 0.0770 - val_mse: 0.0717
# Epoch 344/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0759 - mse: 0.0707 - val_loss: 0.0770 - val_mse: 0.0717
# Epoch 345/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0759 - mse: 0.0707 - val_loss: 0.0770 - val_mse: 0.0717
# Epoch 346/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0759 - mse: 0.0706 - val_loss: 0.0770 - val_mse: 0.0717
# Epoch 347/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0759 - mse: 0.0706 - val_loss: 0.0770 - val_mse: 0.0717
# Epoch 348/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0759 - mse: 0.0706 - val_loss: 0.0769 - val_mse: 0.0717
# Epoch 349/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0758 - mse: 0.0706 - val_loss: 0.0769 - val_mse: 0.0717
# Epoch 350/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0758 - mse: 0.0706 - val_loss: 0.0769 - val_mse: 0.0717
# Epoch 351/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0758 - mse: 0.0705 - val_loss: 0.0769 - val_mse: 0.0716
# Epoch 352/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0758 - mse: 0.0705 - val_loss: 0.0769 - val_mse: 0.0716
# Epoch 353/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0758 - mse: 0.0705 - val_loss: 0.0769 - val_mse: 0.0716
# Epoch 354/4096
# ...
# Epoch 1555/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0592 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1556/4096
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0635 - mse: 0.0592 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1557/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0592 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1558/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0592 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1559/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0592 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1560/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0592 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1561/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0592 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1562/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0592 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1563/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1564/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1565/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1566/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0635 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1567/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1568/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1569/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1570/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1571/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1572/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1573/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1574/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1575/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1576/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1577/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0591 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1578/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1579/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1580/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1581/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0634 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1582/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1583/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1584/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1585/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1586/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1587/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1588/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1589/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1590/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1591/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1592/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0590 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1593/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1594/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1595/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0633 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1596/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1597/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1598/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1599/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1600/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1601/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1602/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1603/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1604/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1605/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1606/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0589 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1607/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1608/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1609/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0632 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1610/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1611/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1612/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1613/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1614/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1615/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1616/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1617/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1618/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1619/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1620/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1621/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0588 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1622/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1623/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0631 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1624/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1625/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1626/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1627/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1628/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1629/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1630/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1631/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1632/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1633/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1634/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1635/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1636/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0587 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1637/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1638/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0630 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1639/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1640/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1641/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1642/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1643/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1644/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1645/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1646/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1647/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1648/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1649/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1650/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1651/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0586 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1652/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0629 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1653/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1654/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1655/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1656/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1657/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1658/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1659/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1660/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1661/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1662/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1663/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1664/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1665/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1666/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1667/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0628 - mse: 0.0585 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1668/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0627 - mse: 0.0584 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1669/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0627 - mse: 0.0584 - val_loss: 0.0716 - val_mse: 0.0673
# Epoch 1670/4096
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0627 - mse: 0.0584 - val_loss: 0.0716 - val_mse: 0.0673

# %%
history.history.keys()
model.save(model_name)
# Out:
# WARNING:tensorflow:From /home/hongtao/miniconda3/envs/top-ml/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: subtract_lepphi_0_2pi/assets

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('mse loss')
plt.legend()
plt.title('MSE loss')
# Out:
# Text(0.5, 1.0, 'MSE loss')

# %%
predictions = model.predict(test_input)

# %%
# Training 
crop = 100 

train_small = model.predict(train_input[0:100,:])
output_small = train_output[0:100,:]

def comparison_plot(compare, true):
    plt.figure(figsize=(8,8*output_length))
    for i in range(0,output_length):
        plt.subplot(output_length,1,i+1)
        plt.plot(range(0,crop), compare[:,i], 'bo', markersize=3, label = 'Predictions')
        plt.plot(range(0,crop), true[:,i], 'ro', markersize=3, label = 'True Value')
        ym, yM = plt.ylim()
        for x in range(100):
            plt.vlines(x, color='g', linestyle='-', alpha=0.2, ymin= 
                        min(compare[x,i], true[x,i]), 
                        ymax= max(compare[x,i], true[x,i]))
        plt.hlines(np.mean(true[:,i]), xmin=-20, xmax=crop+20, alpha=0.5)
        MSE = 1/compare[:,i].size*np.sum((compare[:,i]- true[:,i])**2)
        plt.xlabel('Epoch')
        plt.ylabel(output_keys[i])
        plt.xlim(0, crop)
        plt.title(output_keys[i] + " MSE: " + str(MSE))
        plt.legend()

comparison_plot(train_small, output_small)

# %%
# Predictions

predictions_small = predictions[0:100,:]
test_output_small = test_output[0:100,:]

MSE = 1/predictions.size*np.sum((predictions- test_output)**2)
print("total MSE: " + str(MSE))

for i in range(output_length):
    MSE = 1/predictions[:,i].size*np.sum((predictions[:,i] -test_output[:,i])**2)
    print("{0} MSE : ".format(output_keys[i]), '%.10f'%MSE)
# Out:
# total MSE: 0.06648270411138278
# th_pt MSE :  0.0068211654
# th_eta MSE :  0.0205613396
# th_phi MSE :  0.4251403045
# tl_pt MSE :  0.0059706642
# tl_eta MSE :  0.0153306874
# tl_phi MSE :  0.0820078540
# wl_eta MSE :  0.0099262038
# wl_phi MSE :  0.0293730430
# wl_pt MSE :  0.0032130751

# %%
# Unscaled Histograms 

plt.figure(figsize=(8,8*output_length))
for i in range(len(output_keys)):
    plt.subplot(output_length, 1, i+1)
    hist0, bin_edges = np.histogram(test_output[:, i], bins=20)
    plt.hist(test_output[:,i], bin_edges, histtype='step', color='b', label='true values', density=True)
    plt.hist(predictions[:,i], bin_edges, histtype='step', color='r', label='predictions', density=True)
    plt.xlabel(output_keys[i] +" " +str(np.max(predictions[:,i])) + " " + str(np.min(predictions[:,i])))
    plt.legend()
    plt.ylabel('Frequency')

# %%
total_output = scale_arrays(output_keys, maxmean)
out_scaled = invscale_arrays(output_keys, total_output, maxmean)[split:,:]

total_predictions = model.predict(total_input)
predict_scaled = invscale_arrays(output_keys, total_predictions, maxmean)[split:,:]

# %%
# Histograms to the original scale 

# out_scaled = invscale_arrays(output_keys, out_max0, out_mean, total_output)
# out_scaled = invscale_arrays(output_keys, test_output, maxmean)
# predict_scaled = invscale_arrays(output_keys, out_max0, out_mean, total_predictions)[split:,:]


plt.figure(figsize=(8,8*output_length))
for i in range(len(output_keys)):
    plt.subplot(output_length, 1, i+1)
    # hist0, bin_edges = np.histogram(out_scaled[:, i], bins=20)
    plt.hist(out_scaled[:, i], 20, histtype='step', color='b', label='true values', density=True)
    plt.hist(predict_scaled[:, i], 20, histtype='step', color='r', label='predictions', density=True)
    plt.xlabel(output_keys[i])
    plt.legend()
    plt.ylabel('Frequency')

# %%
for i in range(output_length):
    if output_keys[i].split("_")[1] == 'phi':
        mod_pi = (predict_scaled[:,i] - out_scaled[:,i]) % (2*np.pi)
        mod_pi = mod_pi - 2*np.pi*(mod_pi > np.pi)
        MSE = 1/predict_scaled[:,i].size*np.sum((mod_pi)**2)
    else:
        MSE = 1/predict_scaled[:,i].size*np.sum((predict_scaled[:,i] - out_scaled[:,i])**2)
    print("Original Scale {0} MSE : ".format(output_keys[i]), '%.10f'%MSE)
# Out:
# Original Scale th_pt MSE :  2132.6944765460
# Original Scale th_eta MSE :  0.7363407456
# Original Scale th_phi MSE :  2.9880660677
# Original Scale tl_pt MSE :  1866.7781708907
# Original Scale tl_eta MSE :  0.5490211238
# Original Scale tl_phi MSE :  0.7902703490
# Original Scale wl_eta MSE :  0.3554762694
# Original Scale wl_phi MSE :  0.2821125726
# Original Scale wl_pt MSE :  1004.5948319576

# %%
plt.figure(figsize=(8,8*output_length))
for i in range(output_length):
    plt.subplot(output_length, 1, i+1)
    # hist0, bin_edges = np.histogram(out_scaled[:, i], bins=20)
    plt.plot(out_scaled[:, i], predict_scaled[:, i]-out_scaled[:, i], 'o', color='purple', label='True - Predicted', markersize=2)
    plt.xlabel('True: ' + output_keys[i])
    plt.legend()
    plt.ylabel('Difference')
