# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers 
import h5py

# %matplotlib inline 

dataset = h5py.File('./../../../../../data/hongtao/variables_tt_re2.h5','r')

X_keys = ['j1_pt', 'j1_eta', 'j1_phi', 'j1_m', 'j1_DL1r', 'j2_pt', 'j2_eta', 'j2_phi', 'j2_m', 'j2_DL1r', 'j3_pt', 'j3_eta', 'j3_phi', 'j3_m', 'j3_DL1r', 'j4_pt', 'j4_eta', 'j4_phi', 'j4_m', 'j4_DL1r', 'j5_pt', 'j5_eta', 'j5_phi', 'j5_m', 'j5_DL1r', 'j6_pt', 'j6_eta', 'j6_phi', 'j6_m', 'j6_DL1r', 'lep_pt', 'lep_eta', 'lep_phi', 'met_met', 'met_phi'] 
# Y_keys = ['th_pt', 'th_eta','th_phi', 'tl_pt', 'tl_eta', 'tl_phi', 'wl_eta', 'wl_phi', 'wl_pt']
Y_keys = ['th_pt', 'th_eta', 'th_phi', 'th_m']
phi_keys = ['j1_phi', 'j2_phi', 'j3_phi','j4_phi','j5_phi','j6_phi', 'lep_phi', 'met_phi', 'th_phi', 'tl_phi', 'wl_phi']
eta_keys = ['j1_eta', 'j2_eta', 'j3_eta', 'j4_eta', 'j5_eta', 'j5_phi', 'j6_eta', 'lep_eta', 'th_eta', 'tl_eta', 'wl_eta']
pt_keys = ['j1_pt', 'j2_pt','j3_pt','j4_pt','j5_pt','j6_pt','lep_pt','th_pt', 'tl_pt', 'wl_pt']
m_keys = ['j1_m','j2_m', 'j3_m', 'j4_m', 'j5_m', 'j6_m', 'wl_m']
DL1r_keys = ['j1_DL1r','j2_DL1r','j3_DL1r','j4_DL1r','j5_DL1r','j6_DL1r']

Y_length = len(Y_keys)
X_length = len(X_keys)
crop0 =  100000

# %%
import scale_variables

# How to scale each input/output
def get_methods(keys):
    types = {'pt':'raw_cart', 'eta':'meanmax', 'phi':'sincos', 'DL1r':'meanmax', 'm':'boxcox', 'met':'meanmax'}
    var_types = [key.split('_')[1] for key in keys]
    methods = [types[var] for var in var_types]
    return methods

X_methods = get_methods(X_keys)
Y_methods = get_methods(Y_keys)

Scaler = scale_variables.Scale_variables()
(X_total, X_maxmean), X_names = Scaler.scale_arrays(X_keys, X_methods, True)
(Y_total, Y_maxmean), Y_names = Scaler.scale_arrays(Y_keys, Y_methods, True)

error = Scaler.test_inverse(Y_keys, Y_methods, True)
print('Max scaling error: {}'.format(error))
# Out:
# Max scaling error: 6.540765132599257

# %%
# Create X and test array
split = int(np.floor(0.9*crop0))
shuffle = False

if shuffle:
    rng_state = np.random.get_state()
    np.random.shuffle(X_total)
    np.random.set_state(rng_state)
    np.random.shuffle(Y_total)

trainX, testX = X_total[0:split, :], X_total[split:,:]
trainY, testY = Y_total[0:split,:], Y_total[split:,:]

# sin = trainY[:, Y_names.index('th_phi-sin')]
# tr_weights = 1+10*sin**2
# del sin 

print(trainX.shape, trainY.shape)
print(testX.shape, testY.shape)
# Out:
# (90000, 35) (90000, 4)
# (10000, 35) (10000, 4)

# %%
# Histograms of Y variables 
show = True

if show:
    plt.figure(figsize=(6,6*trainY.shape[1]))
    for i in range(0, trainY.shape[1]):
        plt.subplot(trainY.shape[1], 1, i+1)
        plt.hist(trainY[:,i], 20, histtype='step')
        plt.xlabel(Y_names[i])
        plt.ylabel('Frequency')

# %%
# Histograms of X variables 
show = True

if show:
    plt.figure(figsize=(6,6*trainX.shape[1]))
    for i in range(0, trainX.shape[1]):
        plt.subplot(trainX.shape[1], 1, i+1)
        plt.hist(trainX[:,i], 20, histtype='step')
        plt.xlabel(X_names[i])
        plt.ylabel('Frequency')

# %%
# Build model

# optimizer = keras.optimizers.RMSprop(learning_rate = 1e-5)
optimizer = keras.optimizers.Adam(learning_rate=1e-6)
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)


def build_model():
    model = keras.Sequential([
        layers.Dense(512, activation='relu',
                     input_shape=[len(X_names)]),
        layers.Dense(256,  activation='relu'),
        layers.Dense(256,  activation='relu'),
        layers.Dense(128,  activation='relu'),
        layers.Dense(len(Y_names),  activation='linear')
    ])
    
    model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    return model 

# def build_model():
#     model = keras.Sequential([
#         layers.Dense(6, activation='linear', 
#                      X_shape=[len(X_keys)])])
    
#     model.compile(loss='mse', optimizer= optimizer, metrics=['mse'])
    
#     return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               18432
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 248,964
# Trainable params: 248,964
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model

Epochs= 1024

history = model.fit(trainX, trainY, verbose=1, epochs=Epochs, 
                   validation_split=0.2, shuffle=False, callbacks=[callback],
                   batch_size=512)
# Out:
# Train on 72000 samples, validate on 18000 samples
# Epoch 1/1024
# 72000/72000 [==============================] - 2s 21us/sample - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0168 - val_mse: 0.0168
# Epoch 2/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 3/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 4/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 5/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 6/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 7/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 8/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 9/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 10/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 11/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 12/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 13/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 14/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 15/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 16/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 17/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 18/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 19/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 20/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 21/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 22/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 23/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 24/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 25/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 26/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 27/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 28/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 29/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 30/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 31/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 32/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 33/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 34/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 35/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 36/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 37/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 38/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 39/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 40/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 41/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 42/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 43/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 44/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 45/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 46/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 47/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 48/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 49/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 50/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 51/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 52/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 53/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 54/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 55/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 56/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 57/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 58/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 59/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 60/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 61/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 62/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 63/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 64/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 65/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 66/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 67/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 68/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 69/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 70/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 71/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 72/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 73/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 74/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 75/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 76/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 77/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 78/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 79/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 80/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 81/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 82/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 83/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 84/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 85/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 86/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 87/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 88/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 89/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 90/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 91/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 92/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 93/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 94/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 95/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 96/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 97/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 98/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 99/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 100/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 101/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 102/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 103/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 104/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 105/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 106/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 107/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 108/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 109/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 110/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 111/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 112/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 113/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 114/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 115/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 116/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 117/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 118/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 119/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 120/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 121/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 122/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 123/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 124/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 125/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 126/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 127/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 128/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 129/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 130/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 131/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 132/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 133/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 134/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 135/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 136/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 137/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 138/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 139/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 140/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 141/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 142/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 143/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 144/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 145/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 146/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 147/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 148/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 149/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 150/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 151/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 152/1024
# 72000/72000 [==============================] - 1s 13us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 153/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 154/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 155/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 156/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 157/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 158/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 159/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 160/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 161/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 162/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 163/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 164/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 165/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 166/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 167/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 168/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 169/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 170/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 171/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 172/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 173/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 174/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 175/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 176/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 177/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 178/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 179/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 180/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 181/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 182/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 183/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 184/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 185/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 186/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 187/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 188/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 189/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 190/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 191/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 192/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 193/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 194/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 195/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 196/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 197/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 198/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 199/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 200/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 201/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 202/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 203/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 204/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 205/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 206/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 207/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 208/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 209/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 210/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 211/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 212/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 213/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 214/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 215/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 216/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 217/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 218/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 219/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 220/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 221/1024
# 72000/72000 [==============================] - 1s 13us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 222/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 223/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 224/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 225/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 226/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 227/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 228/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 229/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 230/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 231/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 232/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 233/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 234/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 235/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 236/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 237/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 238/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 239/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 240/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 241/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 242/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 243/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 244/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 245/1024
# 72000/72000 [==============================] - 1s 7us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 246/1024
# 72000/72000 [==============================] - 1s 11us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 247/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 248/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 249/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 250/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 251/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 252/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 253/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 254/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 255/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 256/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 257/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 258/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 259/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 260/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 261/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 262/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 263/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 264/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 265/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 266/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 267/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 268/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 269/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 270/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 271/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 272/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 273/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 274/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 275/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 276/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 277/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 278/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 279/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 280/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 281/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 282/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 283/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 284/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 285/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 286/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 287/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 288/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 289/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 290/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 291/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 292/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 293/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 294/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 295/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 296/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 297/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 298/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 299/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 300/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 301/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 302/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 303/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 304/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 305/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 306/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 307/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 308/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 309/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 310/1024
# 72000/72000 [==============================] - 1s 12us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 311/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 312/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 313/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 314/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 315/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 316/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 317/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 318/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 319/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 320/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 321/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 322/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 323/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 324/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 325/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 326/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 327/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 328/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 329/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 330/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 331/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 332/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 333/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 334/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 335/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 336/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 337/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 338/1024
# ...
# Epoch 914/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 915/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 916/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 917/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 918/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 919/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 920/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 921/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 922/1024
# 72000/72000 [==============================] - 1s 8us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 923/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 924/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 925/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 926/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 927/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 928/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 929/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 930/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 931/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 932/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 933/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 934/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 935/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 936/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 937/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 938/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 939/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 940/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 941/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 942/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 943/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 944/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 945/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 946/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 947/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 948/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 949/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 950/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 951/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 952/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 953/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 954/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 955/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 956/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 957/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 958/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 959/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 960/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 961/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 962/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 963/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 964/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 965/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 966/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 967/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 968/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 969/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 970/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 971/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 972/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 973/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 974/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 975/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 976/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 977/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 978/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 979/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 980/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 981/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 982/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 983/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 984/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 985/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 986/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 987/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 988/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 989/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 990/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 991/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 992/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 993/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 994/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 995/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 996/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 997/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 998/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 999/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1000/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1001/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1002/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1003/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1004/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1005/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1006/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1007/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1008/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1009/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1010/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1011/1024
# 72000/72000 [==============================] - 1s 9us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1012/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1013/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1014/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1015/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1016/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1017/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1018/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1019/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1020/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1021/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1022/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1023/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 1024/1024
# 72000/72000 [==============================] - 1s 10us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0062 - val_mse: 0.0062

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('epoch')
plt.ylabel('mse loss')
plt.legend()
plt.title('MSE loss')
# Out:
# Text(0.5, 1.0, 'MSE loss')

# %%
class Analysis:
    def __init__(self):
        self.crop = 100
        self.fsize = 6
        self.histogram_bins = 40
        
    def wrap_phi(self, var):
        var = var%(2*np.pi)
        var = var - 2*np.pi*(var > np.pi)
        return var
        
    def predictions_vs_sample(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2, self.fsize*len(names)))
        for i in range(0, len(names)):
            compare_small = compare[:self.crop,i]
            true_small = true[:self.crop,i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            plt.subplot(len(names), 1, i+1)
            plt.plot(range(0,self.crop), compare_small, 'bo', markersize=3, label = 'Predictions')
            plt.plot(range(0,self.crop), true_small, 'ro', markersize=3, label = 'True Value')
            ym, yM = plt.ylim()
            for x in range(self.crop):
                plt.vlines(x, color='g', linestyle='-', alpha=0.2, ymin= 
                            min(compare_small[x], true_small[x]), 
                            ymax= max(compare_small[x], true_small[x]))
            plt.hlines(np.mean(true[:,i]), xmin=-20, xmax=self.crop+20, alpha=0.5)
            MSE = 1/compare[:,i].size*np.sum((compare[:,i]- true[:,i])**2)
            plt.xlabel('Sample')
            plt.xlim(0, self.crop)
            plt.ylabel(names[i])
            plt.title(names[i] + " MSE: " + str(MSE))
            plt.legend()
    
    def display_errors(self, compare, true, names, wrap_phi):
        MSE = 1/compare.size*np.sum((compare- true)**2)
        print("total MSE: " + str(MSE))
        print(" ")
        for i in range(len(names)):
            diff = compare[:,i] -true[:,i]
            if wrap_phi and "phi" in names[i]:
                diff = self.wrap_phi(diff)
            MSE = 1/compare[:,i].size*np.sum((diff)**2)
            print("{0} MSE : ".format(names[i]), '%.10f'%MSE)
    
    def difference_histogram(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            diff = true[:,i] - compare[:,i]
            if wrap_phi and "phi" in names[i]:
                diff = self.wrap_phi(diff)
            hist0, bin_edges = np.histogram(true[:, i], bins=self.histogram_bins)
            plt.hist(diff, self.histogram_bins, histtype='step', color='purple', label='true - predicted', density=True)
            plt.xlabel("Difference (Mean: {0}, Std: {1})".format(np.mean(diff), np.std(diff)))
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
            
    def variable_histogram(self, compare, true, names, wrap_phi): 
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            compare_small = compare[:, i]
            true_small = true[:, i]
            if wrap_phi and "phi" in names[i]:
                compare_small = self.wrap_phi(compare_small)
                true_small = self.wrap_phi(true_small)
            # hist, edges = np.histogram(true_small, self.histogram_bins)
            plt.hist(true_small, self.histogram_bins, histtype='step', color='b', label='true values', density=True)
            plt.hist(compare_small, self.histogram_bins, histtype='step', color='r', label='predictions', density=True)
            plt.xlabel(names[i])
            plt.title(names[i])
            plt.legend()
            plt.ylabel('Frequency')
    
    def difference_vs_variable(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], true[:, i]-compare[:, i], 'o', color='purple', label='True - Predicted', markersize=2)
            plt.xlabel('True ' + names[i])
            plt.legend()
            plt.ylabel('Difference')
    
    def predicted_vs_true(self, compare, true, names, wrap_phi):
        plt.figure(figsize=(self.fsize*2,self.fsize*len(names)))
        for i in range(len(names)):
            plt.subplot(len(names), 1, i+1)
            plt.plot(true[:, i], compare[:, i], 'o', color='g', markersize=2)
            line = np.linspace(np.min(true[:, i]), np.max(true[:, i]), 100)
            plt.plot(line, line, color='b')
            plt.xlabel('True')
            plt.title(names[i])
            plt.ylabel('Predicted')

# %%
display = Analysis()

predictions_unscaled = model.predict([testX])
true_unscaled = testY 

total_predictions = model.predict([np.append(trainX,testX,axis=0)])
(Y_total, TO_maxmean0), _ = Scaler.scale_arrays(Y_keys, Y_methods, True)

predictions_origscale = Scaler.invscale_arrays(Y_keys, total_predictions, _, Y_methods, TO_maxmean0)[split:,:]
true_origscale = Scaler.invscale_arrays(Y_keys, Y_total, _, Y_methods, TO_maxmean0)[split:,:]

del Y_total
del TO_maxmean0
del _
del total_predictions

# %% [markdown]
# # Training scale plots

# %%
display.display_errors(predictions_unscaled, true_unscaled, Y_names, False)
# Out:
# total MSE: 0.006006092564177141
#
# th_px MSE :  0.0105814514
# th_py MSE :  0.0093086548
# th_pz MSE :  0.0021436973
# th_m MSE :  0.0019905667

# %%
display.predictions_vs_sample(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.variable_histogram(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.difference_histogram(predictions_unscaled, true_unscaled, Y_names, False)

# %%
display.predicted_vs_true(predictions_unscaled, true_unscaled, Y_names, False)

# %% [markdown]
#  # Original scale plots

# %%
display.display_errors(predictions_origscale, true_origscale, Y_keys, True)
# Out:
# total MSE: 907.3843871690864
#
# th_pt MSE :  3590.8430230189
# th_eta MSE :  0.2212310167
# th_phi MSE :  0.9688868392
# th_m MSE :  35.2113127778

# %%
display.predictions_vs_sample(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.predictions_vs_sample(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.difference_histogram(predictions_origscale, true_origscale, Y_keys, True)

# %%
display.predicted_vs_true(predictions_origscale, true_origscale, Y_keys, True)
